# %% [markdown]
# ##### Relational Algebra, Groupby Review
#
#
# *Example from Data100*
#
# Let's start with some toy data about superheroes.  The heroes come from Arrowverse.  In the `first_seen_on` column, `a` stands for Arrow and `f` for The Flash.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import pprint

import requests
import json
from pathlib import Path
import yaml
from datetime import datetime

# %%
heroes = pd.DataFrame(
    data={'color': ['red', 'green', 'black', 
                    'blue', 'black', 'red'],
          'first_seen_on': ['a', 'a', 'f', 'a', 'a', 'f'],
          'first_season': [2, 1, 2, 3, 3, 1]},
    index=['flash', 'arrow', 'vibe', 
           'atom', 'canary', 'firestorm']
)

identities = pd.DataFrame(
    data={'ego': ['barry allen', 'oliver queen', 'cisco ramon',
                  'ray palmer', 'sara lance', 
                  'martin stein', 'ronnie raymond'],
          'alter-ego': ['flash', 'arrow', 'vibe', 'atom',
                        'canary', 'firestorm', 'firestorm']}
)

teams = pd.DataFrame(
    data={'team': ['flash', 'arrow', 'flash', 'legends', 
                   'flash', 'legends', 'arrow'],
          'hero': ['flash', 'arrow', 'vibe', 'atom', 
                   'killer frost', 'firestorm', 'speedy']})

# %%
heroes
# Out:
#            color first_seen_on  first_season
# flash        red             a             2
# arrow      green             a             1
# vibe       black             f             2
# atom        blue             a             3
# canary     black             a             3
# firestorm    red             f             1

# %%
identities
# Out:
#               ego  alter-ego
# 0     barry allen      flash
# 1    oliver queen      arrow
# 2     cisco ramon       vibe
# 3      ray palmer       atom
# 4      sara lance     canary
# 5    martin stein  firestorm
# 6  ronnie raymond  firestorm

# %%
teams
# Out:
#       team          hero
# 0    flash         flash
# 1    arrow         arrow
# 2    flash          vibe
# 3  legends          atom
# 4    flash  killer frost
# 5  legends     firestorm
# 6    arrow        speedy

# %% [markdown]
# ### `IsIn`
#
# An often used operation is a test-of-membership.  The `Series.isin(values)` method returns a boolean array denoting whether each element of `Series` is in `values`.  We can then use the array to subset our DataFrame.  For example, if we wanted to see which rows of `heroes` had `first_season` values in $\{1, 3\}$, we would use:

# %%
heroes[heroes['first_season'].isin([1, 3])]
# Out:
#            color first_seen_on  first_season
# arrow      green             a             1
# atom        blue             a             3
# canary     black             a             3
# firestorm    red             f             1

# %% [markdown]
# ## Joining Tables on One Column
#
# Suppose we have another table, `teams`, that classifies superheroes into their respective teams.  Note, that `canary` is not in the `teams` data set and that `killer frost` and `speedy` are not in the original `heroes` set.
#
# For simplicity of the example, we'll convert the index of the `heroes` DataFrame into an explicit column called `hero`.  A careful examination of the `merge` [documentation](http://pandas.pydata.org/pandas-docs/version/0.19.1/generated/pandas.DataFrame.merge.html) will reveal that joining on a mixture of the index and columns is possible.

# %%
heroes['hero'] = heroes.index
heroes
# Out:
#            color first_seen_on  first_season       hero
# flash        red             a             2      flash
# arrow      green             a             1      arrow
# vibe       black             f             2       vibe
# atom        blue             a             3       atom
# canary     black             a             3     canary
# firestorm    red             f             1  firestorm

# %%
teams
# Out:
#       team          hero
# 0    flash         flash
# 1    arrow         arrow
# 2    flash          vibe
# 3  legends          atom
# 4    flash  killer frost
# 5  legends     firestorm
# 6    arrow        speedy

# %% [markdown]
# To understand the different types of join or `merge` in `pandas`, we will use the examples given:
#
# * Natural join: Keep only rows that match from the data frames, `how='inner'`
# * Full outer join: Keep all rows taht match from both data frames `how='outer'`
# * Left outer join: Include all rows of your data frame `x` and only those from `y` that match, `how='left'`
# * Right outer join: Include all rows of your data frame `y` and only those from `x` that match `how='right'`
#
# <img src="https://pages.mtu.edu/~lebrown/un5550-f20/week8/join-or-merge-in-pandas.png">

# %% [markdown]
# ### Inner Join
#
# The inner join returns rows representing the heroes that appear in both data frames.

# %%
pd.merge(heroes, teams, how="inner", on="hero")
# Out:
#    color first_seen_on  first_season       hero     team
# 0    red             a             2      flash    flash
# 1  green             a             1      arrow    arrow
# 2  black             f             2       vibe    flash
# 3   blue             a             3       atom  legends
# 4    red             f             1  firestorm  legends

# %% [markdown]
# ### Left Join
#
# The left join returns rows reprsenting `heroes` in the "left" data frame augmented by information found in the `teams` data frame.
#
# Note, the `team` value for `canary` is `NaN`, representing missing value.*italicized text*

# %%
pd.merge(heroes, teams, how="left", on="hero")
# Out:
#    color first_seen_on  first_season       hero     team
# 0    red             a             2      flash    flash
# 1  green             a             1      arrow    arrow
# 2  black             f             2       vibe    flash
# 3   blue             a             3       atom  legends
# 4  black             a             3     canary      NaN
# 5    red             f             1  firestorm  legends

# %% [markdown]
# The right join returns the `hero` values in the `teams` data frame.

# %%
pd.merge(heroes, teams, how="right", on="hero")
# Out:
#    color first_seen_on  first_season          hero     team
# 0    red             a           2.0         flash    flash
# 1  green             a           1.0         arrow    arrow
# 2  black             f           2.0          vibe    flash
# 3   blue             a           3.0          atom  legends
# 4    NaN           NaN           NaN  killer frost    flash
# 5    red             f           1.0     firestorm  legends
# 6    NaN           NaN           NaN        speedy    arrow

# %% [markdown]
# ### Outer Join
#
# An outer join on `hero` will return all heroes found in both the left and right data frames.  Any missing values are filled in with `NaN`

# %%
pd.merge(heroes, teams, how="outer", on="hero")
# Out:
#    color first_seen_on  first_season          hero     team
# 0    red             a           2.0         flash    flash
# 1  green             a           1.0         arrow    arrow
# 2  black             f           2.0          vibe    flash
# 3   blue             a           3.0          atom  legends
# 4  black             a           3.0        canary      NaN
# 5    red             f           1.0     firestorm  legends
# 6    NaN           NaN           NaN  killer frost    flash
# 7    NaN           NaN           NaN        speedy    arrow

# %% [markdown]
# Note, the join operations can also be run using the following notation.

# %%
heroes.merge(teams, how="outer", on="hero")
# Out:
#    color first_seen_on  first_season          hero     team
# 0    red             a           2.0         flash    flash
# 1  green             a           1.0         arrow    arrow
# 2  black             f           2.0          vibe    flash
# 3   blue             a           3.0          atom  legends
# 4  black             a           3.0        canary      NaN
# 5    red             f           1.0     firestorm  legends
# 6    NaN           NaN           NaN  killer frost    flash
# 7    NaN           NaN           NaN        speedy    arrow

# %% [markdown]
# ## Example: Legislators
#
# Let's go back to our legislator example.  We can get information about current committee and committee membership for each legislator.
#
# First, let's load in this data from the YAML files.
#
# ### From prior lesson
#
# Here's an example: a group of people collected information about US congressional legislators in YAML format.
#
# https://github.com/unitedstates/congress-legislators
#
# Here's one of the data files:
#
# https://github.com/unitedstates/congress-legislators/blob/master/legislators-current.yaml

# %%
# import requests
# import json
# from pathlib import Path

legislators_path = 'legislators-current.yaml'
base_url = 'https://theunitedstates.io/congress-legislators/'

def download(url, path):
    """Download the contents of a URL to a local file."""
    path = Path(path) # If path was a string, now it's a Path
    if not path.exists():
        print('Downloading...', end=' ')
        resp = requests.get(url)
        with path.open('wb') as f:
            f.write(resp.content)
        print('Done!')
        
download(base_url + legislators_path, legislators_path)
# Out:
# Downloading... Done!

# %% [markdown]
# The code above will download the YAML file storing current legislators information and store it locally.
#
# Then we can just open the local file to look at the information.
#
# Note, we can also see the file in the files directory and look at it.

# %%
#import yaml

legislators = yaml.load(open(legislators_path), Loader=yaml.SafeLoader)
len(legislators)
# Out:
# 539

# %%
#from datetime import datetime

def to_date(s):
    return datetime.strptime(s, '%Y-%m-%d')

# %%
leg_df = pd.DataFrame(
    columns=['id', 'first', 'last', 'birthday'],
    data=[[x['id']['bioguide'], 
           x['name']['first'],
           x['name']['last'],
           to_date(x['bio']['birthday'])] for x in legislators])

leg_df['age'] = (datetime.now() - leg_df['birthday']).apply(lambda age: age.days/365)
leg_df.head()
# Out:
#         id     first      last   birthday        age
# 0  B000944   Sherrod     Brown 1952-11-09  70.983562
# 1  C000127     Maria  Cantwell 1958-10-13  65.054795
# 2  C000141  Benjamin    Cardin 1943-10-05  80.087671
# 3  C000174    Thomas    Carper 1947-01-23  76.783562
# 4  C001070    Robert     Casey 1960-04-13  63.553425

# %% [markdown]
# ### New Legislator Data
#
# Let's load the new data on committees and committee memberships.

# %%
comm_path = 'committees-current.yaml'
comm_membership_path = 'committee-membership-current.yaml'
for p in [comm_path, comm_membership_path]:
    download(base_url + p, p)
comms = yaml.load(open(comm_path), Loader=yaml.SafeLoader)
comm_membership = yaml.load(open(comm_membership_path), Loader=yaml.SafeLoader)
print(len(comms), len(comm_membership))
# Out:
# Downloading... Done!
# Downloading... Done!
# 50 229

# %% [markdown]
# We can inspect a given committee description.

# %%
comms[0]
# Out:
# {'type': 'house',
#  'name': 'House Committee on Agriculture',
#  'url': 'https://agriculture.house.gov/',
#  'minority_url': 'https://republicans-agriculture.house.gov',
#  'thomas_id': 'HSAG',
#  'house_committee_id': 'AG',
#  'subcommittees': [{'name': 'Forestry',
#    'thomas_id': '15',
#    'address': '1301 LHOB; Washington, DC 20515',
#    'phone': '(202) 225-2171'},
#   {'name': 'Commodity Markets, Digital Assets, and Rural Development',
#    'thomas_id': '22',
#    'address': '1301 LHOB; Washington, DC 20515',
#    'phone': '(202) 225-2171'},
#   {'name': 'General Farm Commodities, Risk Management, and Credit',
#    'thomas_id': '16',
#    'address': '1301 LHOB; Washington, DC 20515',
#    'phone': '(202) 225-2171'},
#   {'name': 'Livestock, Dairy, and Poultry',
#    'thomas_id': '29',
#    'address': '1301 LHOB; Washington, DC 20515',
#    'phone': '(202) 225-2171'},
#   {'name': 'Conservation, Research, and Biotechnology',
#    'thomas_id': '14',
#    'address': '1301 LHOB; Washington, DC 20515',
#    'phone': '(202) 225-2171'},
#   {'name': 'Nutrition, Foreign Agriculture, and Horticulture',
#    'thomas_id': '03',
#    'address': '1301 LHOB; Washington, DC 20515',
#    'phone': '(202) 225-2171'}],
#  'address': '1301 LHOB; Washington, DC 20515-6001',
#  'phone': '(202) 225-2171',
#  'rss_url': 'https://agriculture.house.gov/Rss.aspx?GroupID=1',
#  'jurisdiction': 'The House Committee on Agriculture has legislative jurisdiction over agriculture, food, rural development, and forestry.',
#  'youtube_id': 'UCOWh2WJxPywHIaccDWb8Mvg'}

# %% [markdown]
# ### Pull Information into DataFrame
#
# Let's pull some of this committee information into a DataFrame about committees.

# %%
comm_df = pd.DataFrame(
    columns=['name', 'thomas_id', 'type'],
    data=[[c['name'], c['thomas_id'], c['type']] for c in comms]
)
comm_df.head()
# Out:
#                                     name thomas_id   type
# 0         House Committee on Agriculture      HSAG  house
# 1      House Committee on Appropriations      HSAP  house
# 2      House Committee on Armed Services      HSAS  house
# 3  House Committee on Financial Services      HSBA  house
# 4          House Committee on the Budget      HSBU  house

# %% [markdown]
# Next, let's look at the committee membership data.

# %%
comm_membership
# Out:
# {'HSII': [{'name': 'Bruce Westerman',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chair',
#    'bioguide': 'W000821'},
#   {'name': 'Raúl M. Grijalva',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'G000551'},
#   {'name': 'Doug Lamborn',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'L000564'},
#   {'name': 'Grace F. Napolitano',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'N000179'},
#   {'name': 'Robert J. Wittman',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'W000804'},
#   {'name': 'Gregorio Kilili Camacho Sablan',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'S001177'},
#   {'name': 'Tom McClintock',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'M001177'},
#   {'name': 'Jared Huffman',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'H001068'},
#   {'name': 'Paul A. Gosar',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'G000565'},
#   {'name': 'Ruben Gallego',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'G000574'},
#   {'name': 'Garret Graves',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'G000577'},
#   {'name': 'Joe Neguse',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'N000191'},
#   {'name': 'Aumua Amata Coleman Radewagen',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'R000600'},
#   {'name': 'Mike Levin',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'L000593'},
#   {'name': 'Doug LaMalfa',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'L000578'},
#   {'name': 'Katie Porter',
#    'party': 'minority',
#    'rank': 8,
#    'bioguide': 'P000618'},
#   {'name': 'Daniel Webster',
#    'party': 'majority',
#    'rank': 9,
#    'bioguide': 'W000806'},
#   {'name': 'Teresa Leger Fernandez',
#    'party': 'minority',
#    'rank': 9,
#    'bioguide': 'L000273'},
#   {'name': 'Jenniffer González-Colón',
#    'party': 'majority',
#    'rank': 10,
#    'bioguide': 'G000582'},
#   {'name': 'Melanie A. Stansbury',
#    'party': 'minority',
#    'rank': 10,
#    'bioguide': 'S001218'},
#   {'name': 'Russ Fulcher',
#    'party': 'majority',
#    'rank': 11,
#    'bioguide': 'F000469'},
#   {'name': 'Mary Sattler Peltola',
#    'party': 'minority',
#    'rank': 11,
#    'bioguide': 'P000619'},
#   {'name': 'Pete Stauber',
#    'party': 'majority',
#    'rank': 12,
#    'bioguide': 'S001212'},
#   {'name': 'Alexandria Ocasio-Cortez',
#    'party': 'minority',
#    'rank': 12,
#    'bioguide': 'O000172'},
#   {'name': 'John R. Curtis',
#    'party': 'majority',
#    'rank': 13,
#    'bioguide': 'C001114'},
#   {'name': 'Kevin Mullin',
#    'party': 'minority',
#    'rank': 13,
#    'bioguide': 'M001225'},
#   {'name': 'Thomas P. Tiffany',
#    'party': 'majority',
#    'rank': 14,
#    'bioguide': 'T000165'},
#   {'name': 'Val T. Hoyle',
#    'party': 'minority',
#    'rank': 14,
#    'bioguide': 'H001094'},
#   {'name': 'Jerry L. Carl',
#    'party': 'majority',
#    'rank': 15,
#    'bioguide': 'C001054'},
#   {'name': 'Sydney Kamlager-Dove',
#    'party': 'minority',
#    'rank': 15,
#    'bioguide': 'K000400'},
#   {'name': 'Matthew M. Rosendale, Sr.',
#    'party': 'majority',
#    'rank': 16,
#    'bioguide': 'R000103'},
#   {'name': 'Seth Magaziner',
#    'party': 'minority',
#    'rank': 16,
#    'bioguide': 'M001223'},
#   {'name': 'Lauren Boebert',
#    'party': 'majority',
#    'rank': 17,
#    'bioguide': 'B000825'},
#   {'name': 'Nydia M. Velázquez',
#    'party': 'minority',
#    'rank': 17,
#    'bioguide': 'V000081'},
#   {'name': 'Cliff Bentz',
#    'party': 'majority',
#    'rank': 18,
#    'bioguide': 'B000668'},
#   {'name': 'Ed Case', 'party': 'minority', 'rank': 18, 'bioguide': 'C001055'},
#   {'name': 'Jennifer Kiggans',
#    'party': 'majority',
#    'rank': 19,
#    'bioguide': 'K000399'},
#   {'name': 'Debbie Dingell',
#    'party': 'minority',
#    'rank': 19,
#    'bioguide': 'D000624'},
#   {'name': 'James C. Moylan',
#    'party': 'majority',
#    'rank': 20,
#    'bioguide': 'M001219'},
#   {'name': 'Susie Lee',
#    'party': 'minority',
#    'rank': 20,
#    'bioguide': 'L000590'},
#   {'name': 'Wesley Hunt',
#    'party': 'majority',
#    'rank': 21,
#    'bioguide': 'H001095'},
#   {'name': 'Mike Collins',
#    'party': 'majority',
#    'rank': 22,
#    'bioguide': 'C001129'},
#   {'name': 'Anna Paulina Luna',
#    'party': 'majority',
#    'rank': 23,
#    'bioguide': 'L000596'},
#   {'name': 'John S. Duarte',
#    'party': 'majority',
#    'rank': 24,
#    'bioguide': 'D000633'},
#   {'name': 'Harriet M. Hageman',
#    'party': 'majority',
#    'rank': 25,
#    'bioguide': 'H001096'}],
#  'HSPW': [{'name': 'Sam Graves',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chair',
#    'bioguide': 'G000546'},
#   {'name': 'Rick Larsen',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'L000560'},
#   {'name': 'Eric A. "Rick" Crawford',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'C001087'},
#   {'name': 'Eleanor Holmes Norton',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'N000147'},
#   {'name': 'Daniel Webster',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'W000806'},
#   {'name': 'Grace F. Napolitano',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'N000179'},
#   {'name': 'Thomas Massie',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'M001184'},
#   {'name': 'Steve Cohen',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'C001068'},
#   {'name': 'Scott Perry',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'P000605'},
#   {'name': 'John Garamendi',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'G000559'},
#   {'name': 'Brian Babin',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'B001291'},
#   {'name': 'Henry C. "Hank" Johnson, Jr.',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'J000288'},
#   {'name': 'Garret Graves',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'G000577'},
#   {'name': 'André Carson',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'C001072'},
#   {'name': 'David Rouzer',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'R000603'},
#   {'name': 'Dina Titus',
#    'party': 'minority',
#    'rank': 8,
#    'bioguide': 'T000468'},
#   {'name': 'Mike Bost', 'party': 'majority', 'rank': 9, 'bioguide': 'B001295'},
#   {'name': 'Jared Huffman',
#    'party': 'minority',
#    'rank': 9,
#    'bioguide': 'H001068'},
#   {'name': 'Doug LaMalfa',
#    'party': 'majority',
#    'rank': 10,
#    'bioguide': 'L000578'},
#   {'name': 'Julia Brownley',
#    'party': 'minority',
#    'rank': 10,
#    'bioguide': 'B001285'},
#   {'name': 'Bruce Westerman',
#    'party': 'majority',
#    'rank': 11,
#    'bioguide': 'W000821'},
#   {'name': 'Frederica S. Wilson',
#    'party': 'minority',
#    'rank': 11,
#    'bioguide': 'W000808'},
#   {'name': 'Brian J. Mast',
#    'party': 'majority',
#    'rank': 12,
#    'bioguide': 'M001199'},
#   {'name': 'Donald M. Payne, Jr.',
#    'party': 'minority',
#    'rank': 12,
#    'bioguide': 'P000604'},
#   {'name': 'Jenniffer González-Colón',
#    'party': 'majority',
#    'rank': 13,
#    'bioguide': 'G000582'},
#   {'name': 'Mark DeSaulnier',
#    'party': 'minority',
#    'rank': 13,
#    'bioguide': 'D000623'},
#   {'name': 'Pete Stauber',
#    'party': 'majority',
#    'rank': 14,
#    'bioguide': 'S001212'},
#   {'name': 'Salud O. Carbajal',
#    'party': 'minority',
#    'rank': 14,
#    'bioguide': 'C001112'},
#   {'name': 'Tim Burchett',
#    'party': 'majority',
#    'rank': 15,
#    'bioguide': 'B001309'},
#   {'name': 'Greg Stanton',
#    'party': 'minority',
#    'rank': 15,
#    'bioguide': 'S001211'},
#   {'name': 'Dusty Johnson',
#    'party': 'majority',
#    'rank': 16,
#    'bioguide': 'J000301'},
#   {'name': 'Colin Z. Allred',
#    'party': 'minority',
#    'rank': 16,
#    'bioguide': 'A000376'},
#   {'name': 'Jefferson Van Drew',
#    'party': 'majority',
#    'rank': 17,
#    'bioguide': 'V000133'},
#   {'name': 'Sharice Davids',
#    'party': 'minority',
#    'rank': 17,
#    'bioguide': 'D000629'},
#   {'name': 'Troy E. Nehls',
#    'party': 'majority',
#    'rank': 18,
#    'bioguide': 'N000026'},
#   {'name': 'Jesús G. "Chuy" García',
#    'party': 'minority',
#    'rank': 18,
#    'bioguide': 'G000586'},
#   {'name': 'Lance Gooden',
#    'party': 'majority',
#    'rank': 19,
#    'bioguide': 'G000589'},
#   {'name': 'Chris Pappas',
#    'party': 'minority',
#    'rank': 19,
#    'bioguide': 'P000614'},
#   {'name': 'Tracey Mann',
#    'party': 'majority',
#    'rank': 20,
#    'bioguide': 'M000871'},
#   {'name': 'Seth Moulton',
#    'party': 'minority',
#    'rank': 20,
#    'bioguide': 'M001196'},
#   {'name': 'Burgess Owens',
#    'party': 'majority',
#    'rank': 21,
#    'bioguide': 'O000086'},
#   {'name': 'Jake Auchincloss',
#    'party': 'minority',
#    'rank': 21,
#    'bioguide': 'A000148'},
#   {'name': 'Rudy Yakym III',
#    'party': 'majority',
#    'rank': 22,
#    'bioguide': 'Y000067'},
#   {'name': 'Marilyn Strickland',
#    'party': 'minority',
#    'rank': 22,
#    'bioguide': 'S001159'},
#   {'name': 'Lori Chavez-DeRemer',
#    'party': 'majority',
#    'rank': 23,
#    'bioguide': 'C001135'},
#   {'name': 'Troy A. Carter',
#    'party': 'minority',
#    'rank': 23,
#    'bioguide': 'C001125'},
#   {'name': 'Chuck Edwards',
#    'party': 'majority',
#    'rank': 24,
#    'bioguide': 'E000246'},
#   {'name': 'Patrick Ryan',
#    'party': 'minority',
#    'rank': 24,
#    'bioguide': 'R000579'},
#   {'name': 'Thomas H. Kean, Jr.',
#    'party': 'majority',
#    'rank': 25,
#    'bioguide': 'K000398'},
#   {'name': 'Mary Sattler Peltola',
#    'party': 'minority',
#    'rank': 25,
#    'bioguide': 'P000619'},
#   {'name': 'Anthony D’Esposito',
#    'party': 'majority',
#    'rank': 26,
#    'bioguide': 'D000632'},
#   {'name': 'Robert Menendez',
#    'party': 'minority',
#    'rank': 26,
#    'bioguide': 'M001226'},
#   {'name': 'Eric Burlison',
#    'party': 'majority',
#    'rank': 27,
#    'bioguide': 'B001316'},
#   {'name': 'Val T. Hoyle',
#    'party': 'minority',
#    'rank': 27,
#    'bioguide': 'H001094'},
#   {'name': 'John James',
#    'party': 'majority',
#    'rank': 28,
#    'bioguide': 'J000307'},
#   {'name': 'Emilia Strong Sykes',
#    'party': 'minority',
#    'rank': 28,
#    'bioguide': 'S001223'},
#   {'name': 'Derrick Van Orden',
#    'party': 'majority',
#    'rank': 29,
#    'bioguide': 'V000135'},
#   {'name': 'Hillary J. Scholten',
#    'party': 'minority',
#    'rank': 29,
#    'bioguide': 'S001221'},
#   {'name': 'Brandon Williams',
#    'party': 'majority',
#    'rank': 30,
#    'bioguide': 'W000828'},
#   {'name': 'Valerie P. Foushee',
#    'party': 'minority',
#    'rank': 30,
#    'bioguide': 'F000477'},
#   {'name': 'Marcus J. Molinaro',
#    'party': 'majority',
#    'rank': 31,
#    'bioguide': 'M001221'},
#   {'name': 'Mike Collins',
#    'party': 'majority',
#    'rank': 32,
#    'bioguide': 'C001129'},
#   {'name': 'Mike Ezell',
#    'party': 'majority',
#    'rank': 33,
#    'bioguide': 'E000235'},
#   {'name': 'John S. Duarte',
#    'party': 'majority',
#    'rank': 34,
#    'bioguide': 'D000633'},
#   {'name': 'Aaron Bean',
#    'party': 'majority',
#    'rank': 35,
#    'bioguide': 'B001314'}],
#  'HSII13': [{'name': 'Cliff Bentz',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'B000668'},
#   {'name': 'Jared Huffman',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'H001068'},
#   {'name': 'Robert J. Wittman',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'W000804'},
#   {'name': 'Grace F. Napolitano',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'N000179'},
#   {'name': 'Tom McClintock',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'M001177'},
#   {'name': 'Mike Levin',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'L000593'},
#   {'name': 'Garret Graves',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'G000577'},
#   {'name': 'Mary Sattler Peltola',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'P000619'},
#   {'name': 'Aumua Amata Coleman Radewagen',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'R000600'},
#   {'name': 'Kevin Mullin',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'M001225'},
#   {'name': 'Doug LaMalfa',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'L000578'},
#   {'name': 'Val T. Hoyle',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'H001094'},
#   {'name': 'Daniel Webster',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'W000806'},
#   {'name': 'Seth Magaziner',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'M001223'},
#   {'name': 'Jenniffer González-Colón',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'G000582'},
#   {'name': 'Debbie Dingell',
#    'party': 'minority',
#    'rank': 8,
#    'bioguide': 'D000624'},
#   {'name': 'Jerry L. Carl',
#    'party': 'majority',
#    'rank': 9,
#    'bioguide': 'C001054'},
#   {'name': 'Ruben Gallego',
#    'party': 'minority',
#    'rank': 9,
#    'bioguide': 'G000574'},
#   {'name': 'Lauren Boebert',
#    'party': 'majority',
#    'rank': 10,
#    'bioguide': 'B000825'},
#   {'name': 'Joe Neguse',
#    'party': 'minority',
#    'rank': 10,
#    'bioguide': 'N000191'},
#   {'name': 'Jennifer Kiggans',
#    'party': 'majority',
#    'rank': 11,
#    'title': 'Vice Chair',
#    'bioguide': 'K000399'},
#   {'name': 'Katie Porter',
#    'party': 'minority',
#    'rank': 11,
#    'bioguide': 'P000618'},
#   {'name': 'Anna Paulina Luna',
#    'party': 'majority',
#    'rank': 12,
#    'bioguide': 'L000596'},
#   {'name': 'Ed Case', 'party': 'minority', 'rank': 12, 'bioguide': 'C001055'},
#   {'name': 'John S. Duarte',
#    'party': 'majority',
#    'rank': 13,
#    'bioguide': 'D000633'},
#   {'name': 'Harriet M. Hageman',
#    'party': 'majority',
#    'rank': 14,
#    'bioguide': 'H001096'}],
#  'HSII24': [{'name': 'Harriet M. Hageman',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chair',
#    'bioguide': 'H001096'},
#   {'name': 'Teresa Leger Fernandez',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'L000273'},
#   {'name': 'Aumua Amata Coleman Radewagen',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'R000600'},
#   {'name': 'Gregorio Kilili Camacho Sablan',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'S001177'},
#   {'name': 'Doug LaMalfa',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'L000578'},
#   {'name': 'Ruben Gallego',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'G000574'},
#   {'name': 'Jenniffer González-Colón',
#    'party': 'majority',
#    'rank': 4,
#    'title': 'Vice Chair',
#    'bioguide': 'G000582'},
#   {'name': 'Nydia M. Velázquez',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'V000081'},
#   {'name': 'Jerry L. Carl',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'C001054'},
#   {'name': 'Ed Case', 'party': 'minority', 'rank': 5, 'bioguide': 'C001055'},
#   {'name': 'James C. Moylan',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'M001219'}],
#  'HSPW05': [{'name': 'Garret Graves',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'G000577'},
#   {'name': 'Steve Cohen',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'C001068'},
#   {'name': 'Eric A. "Rick" Crawford',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'C001087'},
#   {'name': 'Henry C. "Hank" Johnson, Jr.',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'J000288'},
#   {'name': 'Thomas Massie',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'M001184'},
#   {'name': 'André Carson',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'C001072'},
#   {'name': 'Scott Perry',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'P000605'},
#   {'name': 'Julia Brownley',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'B001285'},
#   {'name': 'Bruce Westerman',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'W000821'},
#   {'name': 'Mark DeSaulnier',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'D000623'},
#   {'name': 'Brian J. Mast',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'M001199'},
#   {'name': 'Greg Stanton',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'S001211'},
#   {'name': 'Pete Stauber',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'S001212'},
#   {'name': 'Colin Z. Allred',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'A000376'},
#   {'name': 'Tim Burchett',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'B001309'},
#   {'name': 'Sharice Davids',
#    'party': 'minority',
#    'rank': 8,
#    'bioguide': 'D000629'},
#   {'name': 'Dusty Johnson',
#    'party': 'majority',
#    'rank': 9,
#    'bioguide': 'J000301'},
#   {'name': 'Jesús G. "Chuy" García',
#    'party': 'minority',
#    'rank': 9,
#    'bioguide': 'G000586'},
#   {'name': 'Jefferson Van Drew',
#    'party': 'majority',
#    'rank': 10,
#    'bioguide': 'V000133'},
#   {'name': 'Jake Auchincloss',
#    'party': 'minority',
#    'rank': 10,
#    'bioguide': 'A000148'},
#   {'name': 'Lance Gooden',
#    'party': 'majority',
#    'rank': 11,
#    'bioguide': 'G000589'},
#   {'name': 'Mary Sattler Peltola',
#    'party': 'minority',
#    'rank': 11,
#    'bioguide': 'P000619'},
#   {'name': 'Tracey Mann',
#    'party': 'majority',
#    'rank': 12,
#    'bioguide': 'M000871'},
#   {'name': 'Hillary J. Scholten',
#    'party': 'minority',
#    'rank': 12,
#    'bioguide': 'S001221'},
#   {'name': 'Burgess Owens',
#    'party': 'majority',
#    'rank': 13,
#    'bioguide': 'O000086'},
#   {'name': 'Dina Titus',
#    'party': 'minority',
#    'rank': 13,
#    'bioguide': 'T000468'},
#   {'name': 'Rudy Yakym III',
#    'party': 'majority',
#    'rank': 14,
#    'bioguide': 'Y000067'},
#   {'name': 'Donald M. Payne, Jr.',
#    'party': 'minority',
#    'rank': 14,
#    'bioguide': 'P000604'},
#   {'name': 'Lori Chavez-DeRemer',
#    'party': 'majority',
#    'rank': 15,
#    'bioguide': 'C001135'},
#   {'name': 'Salud O. Carbajal',
#    'party': 'minority',
#    'rank': 15,
#    'bioguide': 'C001112'},
#   {'name': 'Thomas H. Kean, Jr.',
#    'party': 'majority',
#    'rank': 16,
#    'bioguide': 'K000398'},
#   {'name': 'Robert Menendez',
#    'party': 'minority',
#    'rank': 16,
#    'bioguide': 'M001226'},
#   {'name': 'Anthony D’Esposito',
#    'party': 'majority',
#    'rank': 17,
#    'bioguide': 'D000632'},
#   {'name': 'Eleanor Holmes Norton',
#    'party': 'minority',
#    'rank': 17,
#    'bioguide': 'N000147'},
#   {'name': 'John James',
#    'party': 'majority',
#    'rank': 18,
#    'bioguide': 'J000307'},
#   {'name': 'Frederica S. Wilson',
#    'party': 'minority',
#    'rank': 18,
#    'bioguide': 'W000808'},
#   {'name': 'Marcus J. Molinaro',
#    'party': 'majority',
#    'rank': 19,
#    'bioguide': 'M001221'},
#   {'name': 'Mike Collins',
#    'party': 'majority',
#    'rank': 20,
#    'bioguide': 'C001129'},
#   {'name': 'Aaron Bean',
#    'party': 'majority',
#    'rank': 21,
#    'bioguide': 'B001314'}],
#  'HSPW07': [{'name': 'Daniel Webster',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'W000806'},
#   {'name': 'Salud O. Carbajal',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'C001112'},
#   {'name': 'Brian Babin',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'B001291'},
#   {'name': 'John Garamendi',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'G000559'},
#   {'name': 'Brian J. Mast',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'M001199'},
#   {'name': 'Chris Pappas',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'P000614'},
#   {'name': 'Jenniffer González-Colón',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'G000582'},
#   {'name': 'Jake Auchincloss',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'A000148'},
#   {'name': 'Jefferson Van Drew',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'V000133'},
#   {'name': 'Mary Sattler Peltola',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'P000619'},
#   {'name': 'Mike Ezell',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'E000235'},
#   {'name': 'Hillary J. Scholten',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'S001221'},
#   {'name': 'Aaron Bean',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'B001314'}],
#  'HSPW12': [{'name': 'Eric A. "Rick" Crawford',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'C001087'},
#   {'name': 'Eleanor Holmes Norton',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'N000147'},
#   {'name': 'Daniel Webster',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'W000806'},
#   {'name': 'Jared Huffman',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'H001068'},
#   {'name': 'Thomas Massie',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'M001184'},
#   {'name': 'Chris Pappas',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'P000614'},
#   {'name': 'Mike Bost', 'party': 'majority', 'rank': 4, 'bioguide': 'B001295'},
#   {'name': 'Marilyn Strickland',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'S001159'},
#   {'name': 'Doug LaMalfa',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'L000578'},
#   {'name': 'Patrick Ryan',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'R000579'},
#   {'name': 'Pete Stauber',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'S001212'},
#   {'name': 'Robert Menendez',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'M001226'},
#   {'name': 'Tim Burchett',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'B001309'},
#   {'name': 'Val T. Hoyle',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'H001094'},
#   {'name': 'Dusty Johnson',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'J000301'},
#   {'name': 'Valerie P. Foushee',
#    'party': 'minority',
#    'rank': 8,
#    'bioguide': 'F000477'},
#   {'name': 'Jefferson Van Drew',
#    'party': 'majority',
#    'rank': 9,
#    'bioguide': 'V000133'},
#   {'name': 'Grace F. Napolitano',
#    'party': 'minority',
#    'rank': 9,
#    'bioguide': 'N000179'},
#   {'name': 'Troy E. Nehls',
#    'party': 'majority',
#    'rank': 10,
#    'bioguide': 'N000026'},
#   {'name': 'Steve Cohen',
#    'party': 'minority',
#    'rank': 10,
#    'bioguide': 'C001068'},
#   {'name': 'Lance Gooden',
#    'party': 'majority',
#    'rank': 11,
#    'bioguide': 'G000589'},
#   {'name': 'Henry C. "Hank" Johnson, Jr.',
#    'party': 'minority',
#    'rank': 11,
#    'bioguide': 'J000288'},
#   {'name': 'Tracey Mann',
#    'party': 'majority',
#    'rank': 12,
#    'bioguide': 'M000871'},
#   {'name': 'Julia Brownley',
#    'party': 'minority',
#    'rank': 12,
#    'bioguide': 'B001285'},
#   {'name': 'Burgess Owens',
#    'party': 'majority',
#    'rank': 13,
#    'bioguide': 'O000086'},
#   {'name': 'Greg Stanton',
#    'party': 'minority',
#    'rank': 13,
#    'bioguide': 'S001211'},
#   {'name': 'Rudy Yakym III',
#    'party': 'majority',
#    'rank': 14,
#    'bioguide': 'Y000067'},
#   {'name': 'Colin Z. Allred',
#    'party': 'minority',
#    'rank': 14,
#    'bioguide': 'A000376'},
#   {'name': 'Lori Chavez-DeRemer',
#    'party': 'majority',
#    'rank': 15,
#    'bioguide': 'C001135'},
#   {'name': 'Jesús G. "Chuy" García',
#    'party': 'minority',
#    'rank': 15,
#    'bioguide': 'G000586'},
#   {'name': 'Chuck Edwards',
#    'party': 'majority',
#    'rank': 16,
#    'bioguide': 'E000246'},
#   {'name': 'Seth Moulton',
#    'party': 'minority',
#    'rank': 16,
#    'bioguide': 'M001196'},
#   {'name': 'Thomas H. Kean, Jr.',
#    'party': 'majority',
#    'rank': 17,
#    'bioguide': 'K000398'},
#   {'name': 'Emilia Strong Sykes',
#    'party': 'minority',
#    'rank': 17,
#    'bioguide': 'S001223'},
#   {'name': 'Anthony D’Esposito',
#    'party': 'majority',
#    'rank': 18,
#    'bioguide': 'D000632'},
#   {'name': 'John Garamendi',
#    'party': 'minority',
#    'rank': 18,
#    'bioguide': 'G000559'},
#   {'name': 'Eric Burlison',
#    'party': 'majority',
#    'rank': 19,
#    'bioguide': 'B001316'},
#   {'name': 'Dina Titus',
#    'party': 'minority',
#    'rank': 19,
#    'bioguide': 'T000468'},
#   {'name': 'Derrick Van Orden',
#    'party': 'majority',
#    'rank': 20,
#    'bioguide': 'V000135'},
#   {'name': 'Salud O. Carbajal',
#    'party': 'minority',
#    'rank': 20,
#    'bioguide': 'C001112'},
#   {'name': 'Brandon Williams',
#    'party': 'majority',
#    'rank': 21,
#    'bioguide': 'W000828'},
#   {'name': 'Jake Auchincloss',
#    'party': 'minority',
#    'rank': 21,
#    'bioguide': 'A000148'},
#   {'name': 'Marcus J. Molinaro',
#    'party': 'majority',
#    'rank': 22,
#    'bioguide': 'M001221'},
#   {'name': 'Mark DeSaulnier',
#    'party': 'minority',
#    'rank': 22,
#    'bioguide': 'D000623'},
#   {'name': 'Mike Collins',
#    'party': 'majority',
#    'rank': 23,
#    'bioguide': 'C001129'},
#   {'name': 'John S. Duarte',
#    'party': 'majority',
#    'rank': 24,
#    'bioguide': 'D000633'},
#   {'name': 'Aaron Bean',
#    'party': 'majority',
#    'rank': 25,
#    'bioguide': 'B001314'}],
#  'HSAS': [{'name': 'Mike Rogers',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chair',
#    'bioguide': 'R000575'},
#   {'name': 'Adam Smith',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'S000510'},
#   {'name': 'Joe Wilson',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'W000795'},
#   {'name': 'Joe Courtney',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'C001069'},
#   {'name': 'Michael R. Turner',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'T000463'},
#   {'name': 'John Garamendi',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'G000559'},
#   {'name': 'Doug Lamborn',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'L000564'},
#   {'name': 'Donald Norcross',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'N000188'},
#   {'name': 'Robert J. Wittman',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'W000804'},
#   {'name': 'Ruben Gallego',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'G000574'},
#   {'name': 'Austin Scott',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'S001189'},
#   {'name': 'Seth Moulton',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'M001196'},
#   {'name': 'Sam Graves',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'G000546'},
#   {'name': 'Salud O. Carbajal',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'C001112'},
#   {'name': 'Elise M. Stefanik',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'S001196'},
#   {'name': 'Ro Khanna', 'party': 'minority', 'rank': 8, 'bioguide': 'K000389'},
#   {'name': 'Scott DesJarlais',
#    'party': 'majority',
#    'rank': 9,
#    'bioguide': 'D000616'},
#   {'name': 'William R. Keating',
#    'party': 'minority',
#    'rank': 9,
#    'bioguide': 'K000375'},
#   {'name': 'Trent Kelly',
#    'party': 'majority',
#    'rank': 10,
#    'bioguide': 'K000388'},
#   {'name': 'Andy Kim', 'party': 'minority', 'rank': 10, 'bioguide': 'K000394'},
#   {'name': 'Mike Gallagher',
#    'party': 'majority',
#    'rank': 11,
#    'bioguide': 'G000579'},
#   {'name': 'Chrissy Houlahan',
#    'party': 'minority',
#    'rank': 11,
#    'bioguide': 'H001085'},
#   {'name': 'Matt Gaetz',
#    'party': 'majority',
#    'rank': 12,
#    'bioguide': 'G000578'},
#   {'name': 'Elissa Slotkin',
#    'party': 'minority',
#    'rank': 12,
#    'bioguide': 'S001208'},
#   {'name': 'Don Bacon',
#    'party': 'majority',
#    'rank': 13,
#    'bioguide': 'B001298'},
#   {'name': 'Mikie Sherrill',
#    'party': 'minority',
#    'rank': 13,
#    'bioguide': 'S001207'},
#   {'name': 'Jim Banks',
#    'party': 'majority',
#    'rank': 14,
#    'bioguide': 'B001299'},
#   {'name': 'Veronica Escobar',
#    'party': 'minority',
#    'rank': 14,
#    'bioguide': 'E000299'},
#   {'name': 'Jack Bergman',
#    'party': 'majority',
#    'rank': 15,
#    'bioguide': 'B001301'},
#   {'name': 'Jared F. Golden',
#    'party': 'minority',
#    'rank': 15,
#    'bioguide': 'G000592'},
#   {'name': 'Michael Waltz',
#    'party': 'majority',
#    'rank': 16,
#    'bioguide': 'W000823'},
#   {'name': 'Sara Jacobs',
#    'party': 'minority',
#    'rank': 16,
#    'bioguide': 'J000305'},
#   {'name': 'Mike Johnson',
#    'party': 'majority',
#    'rank': 17,
#    'bioguide': 'J000299'},
#   {'name': 'Marilyn Strickland',
#    'party': 'minority',
#    'rank': 17,
#    'bioguide': 'S001159'},
#   {'name': 'Lisa C. McClain',
#    'party': 'majority',
#    'rank': 18,
#    'bioguide': 'M001136'},
#   {'name': 'Patrick Ryan',
#    'party': 'minority',
#    'rank': 18,
#    'bioguide': 'R000579'},
#   {'name': 'Ronny Jackson',
#    'party': 'majority',
#    'rank': 19,
#    'bioguide': 'J000304'},
#   {'name': 'Jeff Jackson',
#    'party': 'minority',
#    'rank': 19,
#    'bioguide': 'J000308'},
#   {'name': 'Pat Fallon',
#    'party': 'majority',
#    'rank': 20,
#    'bioguide': 'F000246'},
#   {'name': 'Gabe Vasquez',
#    'party': 'minority',
#    'rank': 20,
#    'bioguide': 'V000136'},
#   {'name': 'Carlos A. Gimenez',
#    'party': 'majority',
#    'rank': 21,
#    'bioguide': 'G000593'},
#   {'name': 'Christopher R. Deluzio',
#    'party': 'minority',
#    'rank': 21,
#    'bioguide': 'D000530'},
#   {'name': 'Nancy Mace',
#    'party': 'majority',
#    'rank': 22,
#    'bioguide': 'M000194'},
#   {'name': 'Jill N. Tokuda',
#    'party': 'minority',
#    'rank': 22,
#    'bioguide': 'T000487'},
#   {'name': 'Brad Finstad',
#    'party': 'majority',
#    'rank': 23,
#    'bioguide': 'F000475'},
#   {'name': 'Donald G. Davis',
#    'party': 'minority',
#    'rank': 23,
#    'bioguide': 'D000230'},
#   {'name': 'Dale W. Strong',
#    'party': 'majority',
#    'rank': 24,
#    'bioguide': 'S001220'},
#   {'name': 'Jennifer L. McClellan',
#    'party': 'minority',
#    'rank': 24,
#    'bioguide': 'M001227'},
#   {'name': 'Morgan Luttrell',
#    'party': 'majority',
#    'rank': 25,
#    'bioguide': 'L000603'},
#   {'name': 'Terri A. Sewell',
#    'party': 'minority',
#    'rank': 25,
#    'bioguide': 'S001185'},
#   {'name': 'Jennifer Kiggans',
#    'party': 'majority',
#    'rank': 26,
#    'bioguide': 'K000399'},
#   {'name': 'Steven Horsford',
#    'party': 'minority',
#    'rank': 26,
#    'bioguide': 'H001066'},
#   {'name': 'Nick LaLota',
#    'party': 'majority',
#    'rank': 27,
#    'bioguide': 'L000598'},
#   {'name': 'Jimmy Panetta',
#    'party': 'minority',
#    'rank': 27,
#    'bioguide': 'P000613'},
#   {'name': 'James C. Moylan',
#    'party': 'majority',
#    'rank': 28,
#    'bioguide': 'M001219'},
#   {'name': 'Marc A. Veasey',
#    'party': 'minority',
#    'rank': 28,
#    'bioguide': 'V000131'},
#   {'name': 'Mark Alford',
#    'party': 'majority',
#    'rank': 29,
#    'bioguide': 'A000379'},
#   {'name': 'Cory Mills',
#    'party': 'majority',
#    'rank': 30,
#    'bioguide': 'M001216'},
#   {'name': 'Richard McCormick',
#    'party': 'majority',
#    'rank': 31,
#    'bioguide': 'M001218'}],
#  'HSAS02': [{'name': 'Jim Banks',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'B001299'},
#   {'name': 'Andy Kim',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'K000394'},
#   {'name': 'Elise M. Stefanik',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'S001196'},
#   {'name': 'Chrissy Houlahan',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'H001085'},
#   {'name': 'Matt Gaetz',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'G000578'},
#   {'name': 'Veronica Escobar',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'E000299'},
#   {'name': 'Jack Bergman',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'B001301'},
#   {'name': 'Marilyn Strickland',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'S001159'},
#   {'name': 'Michael Waltz',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'W000823'},
#   {'name': 'Jill N. Tokuda',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'T000487'},
#   {'name': 'Brad Finstad',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'F000475'},
#   {'name': 'Donald G. Davis',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'D000230'},
#   {'name': 'James C. Moylan',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'M001219'},
#   {'name': 'Terri A. Sewell',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'S001185'},
#   {'name': 'Mark Alford',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'A000379'},
#   {'name': 'Steven Horsford',
#    'party': 'minority',
#    'rank': 8,
#    'bioguide': 'H001066'},
#   {'name': 'Cory Mills',
#    'party': 'majority',
#    'rank': 9,
#    'bioguide': 'M001216'}],
#  'HSAS28': [{'name': 'Trent Kelly',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'K000388'},
#   {'name': 'Joe Courtney',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'C001069'},
#   {'name': 'Robert J. Wittman',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'W000804'},
#   {'name': 'John Garamendi',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'G000559'},
#   {'name': 'Scott DesJarlais',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'D000616'},
#   {'name': 'Donald Norcross',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'N000188'},
#   {'name': 'Mike Gallagher',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'G000579'},
#   {'name': 'Jared F. Golden',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'G000592'},
#   {'name': 'Jack Bergman',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'B001301'},
#   {'name': 'Sara Jacobs',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'J000305'},
#   {'name': 'Mike Johnson',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'J000299'},
#   {'name': 'Christopher R. Deluzio',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'D000530'},
#   {'name': 'Ronny Jackson',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'J000304'},
#   {'name': 'Jennifer L. McClellan',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'M001227'},
#   {'name': 'Nancy Mace',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'M000194'},
#   {'name': 'Jimmy Panetta',
#    'party': 'minority',
#    'rank': 8,
#    'bioguide': 'P000613'},
#   {'name': 'Jennifer Kiggans',
#    'party': 'majority',
#    'rank': 9,
#    'bioguide': 'K000399'},
#   {'name': 'Mark Alford',
#    'party': 'majority',
#    'rank': 10,
#    'bioguide': 'A000379'}],
#  'HSAG': [{'name': 'Glenn Thompson',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chair',
#    'bioguide': 'T000467'},
#   {'name': 'David Scott',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'S001157'},
#   {'name': 'Frank D. Lucas',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'L000491'},
#   {'name': 'Jim Costa', 'party': 'minority', 'rank': 2, 'bioguide': 'C001059'},
#   {'name': 'Austin Scott',
#    'party': 'majority',
#    'rank': 3,
#    'title': 'Vice Chairman',
#    'bioguide': 'S001189'},
#   {'name': 'James P. McGovern',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'M000312'},
#   {'name': 'Eric A. "Rick" Crawford',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'C001087'},
#   {'name': 'Alma S. Adams',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'A000370'},
#   {'name': 'Scott DesJarlais',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'D000616'},
#   {'name': 'Abigail Davis Spanberger',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'S001209'},
#   {'name': 'Doug LaMalfa',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'L000578'},
#   {'name': 'Jahana Hayes',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'H001081'},
#   {'name': 'David Rouzer',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'R000603'},
#   {'name': 'Shontel M. Brown',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'B001313'},
#   {'name': 'Trent Kelly',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'K000388'},
#   {'name': 'Sharice Davids',
#    'party': 'minority',
#    'rank': 8,
#    'bioguide': 'D000629'},
#   {'name': 'Don Bacon', 'party': 'majority', 'rank': 9, 'bioguide': 'B001298'},
#   {'name': 'Elissa Slotkin',
#    'party': 'minority',
#    'rank': 9,
#    'bioguide': 'S001208'},
#   {'name': 'Mike Bost',
#    'party': 'majority',
#    'rank': 10,
#    'bioguide': 'B001295'},
#   {'name': 'Yadira Caraveo',
#    'party': 'minority',
#    'rank': 10,
#    'bioguide': 'C001134'},
#   {'name': 'Dusty Johnson',
#    'party': 'majority',
#    'rank': 11,
#    'bioguide': 'J000301'},
#   {'name': 'Andrea Salinas',
#    'party': 'minority',
#    'rank': 11,
#    'bioguide': 'S001226'},
#   {'name': 'James R. Baird',
#    'party': 'majority',
#    'rank': 12,
#    'bioguide': 'B001307'},
#   {'name': 'Marie Gluesenkamp Perez',
#    'party': 'minority',
#    'rank': 12,
#    'bioguide': 'G000600'},
#   {'name': 'Tracey Mann',
#    'party': 'majority',
#    'rank': 13,
#    'bioguide': 'M000871'},
#   {'name': 'Donald G. Davis',
#    'party': 'minority',
#    'rank': 13,
#    'bioguide': 'D000230'},
#   {'name': 'Randy Feenstra',
#    'party': 'majority',
#    'rank': 14,
#    'bioguide': 'F000446'},
#   {'name': 'Jill N. Tokuda',
#    'party': 'minority',
#    'rank': 14,
#    'bioguide': 'T000487'},
#   {'name': 'Mary E. Miller',
#    'party': 'majority',
#    'rank': 15,
#    'bioguide': 'M001211'},
#   {'name': 'Nikki Budzinski',
#    'party': 'minority',
#    'rank': 15,
#    'bioguide': 'B001315'},
#   {'name': 'Barry Moore',
#    'party': 'majority',
#    'rank': 16,
#    'bioguide': 'M001212'},
#   {'name': 'Eric Sorensen',
#    'party': 'minority',
#    'rank': 16,
#    'bioguide': 'S001225'},
#   {'name': 'Kat Cammack',
#    'party': 'majority',
#    'rank': 17,
#    'bioguide': 'C001039'},
#   {'name': 'Gabe Vasquez',
#    'party': 'minority',
#    'rank': 17,
#    'bioguide': 'V000136'},
#   {'name': 'Brad Finstad',
#    'party': 'majority',
#    'rank': 18,
#    'bioguide': 'F000475'},
#   {'name': 'Jasmine Crockett',
#    'party': 'minority',
#    'rank': 18,
#    'bioguide': 'C001130'},
#   {'name': 'John W. Rose',
#    'party': 'majority',
#    'rank': 19,
#    'bioguide': 'R000612'},
#   {'name': 'Jonathan L. Jackson',
#    'party': 'minority',
#    'rank': 19,
#    'bioguide': 'J000309'},
#   {'name': 'Ronny Jackson',
#    'party': 'majority',
#    'rank': 20,
#    'bioguide': 'J000304'},
#   {'name': 'Greg Casar',
#    'party': 'minority',
#    'rank': 20,
#    'bioguide': 'C001131'},
#   {'name': 'Marcus J. Molinaro',
#    'party': 'majority',
#    'rank': 21,
#    'bioguide': 'M001221'},
#   {'name': 'Chellie Pingree',
#    'party': 'minority',
#    'rank': 21,
#    'bioguide': 'P000597'},
#   {'name': 'Monica De La Cruz',
#    'party': 'majority',
#    'rank': 22,
#    'bioguide': 'D000594'},
#   {'name': 'Salud O. Carbajal',
#    'party': 'minority',
#    'rank': 22,
#    'bioguide': 'C001112'},
#   {'name': 'Nicholas A. Langworthy',
#    'party': 'majority',
#    'rank': 23,
#    'bioguide': 'L000600'},
#   {'name': 'Angie Craig',
#    'party': 'minority',
#    'rank': 23,
#    'bioguide': 'C001119'},
#   {'name': 'John S. Duarte',
#    'party': 'majority',
#    'rank': 24,
#    'bioguide': 'D000633'},
#   {'name': 'Darren Soto',
#    'party': 'minority',
#    'rank': 24,
#    'bioguide': 'S001200'},
#   {'name': 'Zachary Nunn',
#    'party': 'majority',
#    'rank': 25,
#    'bioguide': 'N000193'},
#   {'name': 'Sanford D. Bishop, Jr.',
#    'party': 'minority',
#    'rank': 25,
#    'bioguide': 'B000490'},
#   {'name': 'Mark Alford',
#    'party': 'majority',
#    'rank': 26,
#    'bioguide': 'A000379'},
#   {'name': 'Derrick Van Orden',
#    'party': 'majority',
#    'rank': 27,
#    'bioguide': 'V000135'},
#   {'name': 'Lori Chavez-DeRemer',
#    'party': 'majority',
#    'rank': 28,
#    'bioguide': 'C001135'},
#   {'name': 'Max L. Miller',
#    'party': 'majority',
#    'rank': 29,
#    'bioguide': 'M001222'}],
#  'HSVR': [{'name': 'Mike Bost',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chair',
#    'bioguide': 'B001295'},
#   {'name': 'Mark Takano',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'T000472'},
#   {'name': 'Aumua Amata Coleman Radewagen',
#    'party': 'majority',
#    'rank': 2,
#    'title': 'Vice Chair',
#    'bioguide': 'R000600'},
#   {'name': 'Julia Brownley',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'B001285'},
#   {'name': 'Jack Bergman',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'B001301'},
#   {'name': 'Mike Levin',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'L000593'},
#   {'name': 'Nancy Mace',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'M000194'},
#   {'name': 'Chris Pappas',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'P000614'},
#   {'name': 'Matthew M. Rosendale, Sr.',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'R000103'},
#   {'name': 'Frank J. Mrvan',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'M001214'},
#   {'name': 'Mariannette Miller-Meeks',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'M001215'},
#   {'name': 'Sheila Cherfilus-McCormick',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'C001127'},
#   {'name': 'Gregory F. Murphy',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'M001210'},
#   {'name': 'Christopher R. Deluzio',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'D000530'},
#   {'name': 'C. Scott Franklin',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'F000472'},
#   {'name': 'Morgan McGarvey',
#    'party': 'minority',
#    'rank': 8,
#    'bioguide': 'M001220'},
#   {'name': 'Derrick Van Orden',
#    'party': 'majority',
#    'rank': 9,
#    'bioguide': 'V000135'},
#   {'name': 'Delia C. Ramirez',
#    'party': 'minority',
#    'rank': 9,
#    'bioguide': 'R000617'},
#   {'name': 'Morgan Luttrell',
#    'party': 'majority',
#    'rank': 10,
#    'bioguide': 'L000603'},
#   {'name': 'Greg Landsman',
#    'party': 'minority',
#    'rank': 10,
#    'bioguide': 'L000601'},
#   {'name': 'Juan Ciscomani',
#    'party': 'majority',
#    'rank': 11,
#    'bioguide': 'C001133'},
#   {'name': 'Nikki Budzinski',
#    'party': 'minority',
#    'rank': 11,
#    'bioguide': 'B001315'},
#   {'name': 'Elijah Crane',
#    'party': 'majority',
#    'rank': 12,
#    'bioguide': 'C001132'},
#   {'name': 'Keith Self',
#    'party': 'majority',
#    'rank': 13,
#    'bioguide': 'S001224'},
#   {'name': 'Jennifer Kiggans',
#    'party': 'majority',
#    'rank': 14,
#    'bioguide': 'K000399'}],
#  'HSAG15': [{'name': 'Doug LaMalfa',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'L000578'},
#   {'name': 'Andrea Salinas',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'S001226'},
#   {'name': 'Trent Kelly',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'K000388'},
#   {'name': 'Marie Gluesenkamp Perez',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'G000600'},
#   {'name': 'Barry Moore',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'M001212'},
#   {'name': 'Gabe Vasquez',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'V000136'},
#   {'name': 'John S. Duarte',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'D000633'},
#   {'name': 'Chellie Pingree',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'P000597'},
#   {'name': 'Lori Chavez-DeRemer',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'C001135'}],
#  'HSAG29': [{'name': 'Tracey Mann',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'M000871'},
#   {'name': 'Jim Costa',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'C001059'},
#   {'name': 'Scott DesJarlais',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'D000616'},
#   {'name': 'Abigail Davis Spanberger',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'S001209'},
#   {'name': 'Trent Kelly',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'K000388'},
#   {'name': 'Jahana Hayes',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'H001081'},
#   {'name': 'Don Bacon', 'party': 'majority', 'rank': 4, 'bioguide': 'B001298'},
#   {'name': 'Yadira Caraveo',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'C001134'},
#   {'name': 'James R. Baird',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'B001307'},
#   {'name': 'Jill N. Tokuda',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'T000487'},
#   {'name': 'Randy Feenstra',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'F000446'},
#   {'name': 'Chellie Pingree',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'P000597'},
#   {'name': 'Barry Moore',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'M001212'},
#   {'name': 'Darren Soto',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'S001200'},
#   {'name': 'Ronny Jackson',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'J000304'},
#   {'name': 'Donald G. Davis',
#    'party': 'minority',
#    'rank': 8,
#    'bioguide': 'D000230'},
#   {'name': 'Marcus J. Molinaro',
#    'party': 'majority',
#    'rank': 9,
#    'bioguide': 'M001221'},
#   {'name': 'Mark Alford',
#    'party': 'majority',
#    'rank': 10,
#    'bioguide': 'A000379'},
#   {'name': 'Derrick Van Orden',
#    'party': 'majority',
#    'rank': 11,
#    'bioguide': 'V000135'}],
#  'HSVR09': [{'name': 'Morgan Luttrell',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'L000603'},
#   {'name': 'Chris Pappas',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'P000614'},
#   {'name': 'C. Scott Franklin',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'F000472'},
#   {'name': 'Christopher R. Deluzio',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'D000530'},
#   {'name': 'Juan Ciscomani',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'C001133'},
#   {'name': 'Morgan McGarvey',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'M001220'},
#   {'name': 'Elijah Crane',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'C001132'},
#   {'name': 'Delia C. Ramirez',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'R000617'},
#   {'name': 'Keith Self',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'S001224'}],
#  'HSVR10': [{'name': 'Derrick Van Orden',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'V000135'},
#   {'name': 'Mike Levin',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'L000593'},
#   {'name': 'Nancy Mace',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'M000194'},
#   {'name': 'Frank J. Mrvan',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'M001214'},
#   {'name': 'C. Scott Franklin',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'F000472'},
#   {'name': 'Morgan McGarvey',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'M001220'},
#   {'name': 'Juan Ciscomani',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'C001133'},
#   {'name': 'Delia C. Ramirez',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'R000617'},
#   {'name': 'Elijah Crane',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'C001132'}],
#  'HSAP': [{'name': 'Kay Granger',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chair',
#    'bioguide': 'G000377'},
#   {'name': 'Rosa L. DeLauro',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'D000216'},
#   {'name': 'Harold Rogers',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'R000395'},
#   {'name': 'Steny H. Hoyer',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'H000874'},
#   {'name': 'Robert B. Aderholt',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'A000055'},
#   {'name': 'Marcy Kaptur',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'K000009'},
#   {'name': 'Michael K. Simpson',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'S001148'},
#   {'name': 'Sanford D. Bishop, Jr.',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'B000490'},
#   {'name': 'John R. Carter',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'C001051'},
#   {'name': 'Barbara Lee',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'L000551'},
#   {'name': 'Ken Calvert',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'C000059'},
#   {'name': 'Betty McCollum',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'M001143'},
#   {'name': 'Tom Cole', 'party': 'majority', 'rank': 7, 'bioguide': 'C001053'},
#   {'name': 'C. A. Dutch Ruppersberger',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'R000576'},
#   {'name': 'Mario Diaz-Balart',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'D000600'},
#   {'name': 'Debbie Wasserman Schultz',
#    'party': 'minority',
#    'rank': 8,
#    'bioguide': 'W000797'},
#   {'name': 'Steve Womack',
#    'party': 'majority',
#    'rank': 9,
#    'bioguide': 'W000809'},
#   {'name': 'Henry Cuellar',
#    'party': 'minority',
#    'rank': 9,
#    'bioguide': 'C001063'},
#   {'name': 'Charles J. "Chuck" Fleischmann',
#    'party': 'majority',
#    'rank': 10,
#    'bioguide': 'F000459'},
#   {'name': 'Chellie Pingree',
#    'party': 'minority',
#    'rank': 10,
#    'bioguide': 'P000597'},
#   {'name': 'David P. Joyce',
#    'party': 'majority',
#    'rank': 11,
#    'bioguide': 'J000295'},
#   {'name': 'Mike Quigley',
#    'party': 'minority',
#    'rank': 11,
#    'bioguide': 'Q000023'},
#   {'name': 'Andy Harris',
#    'party': 'majority',
#    'rank': 12,
#    'bioguide': 'H001052'},
#   {'name': 'Derek Kilmer',
#    'party': 'minority',
#    'rank': 12,
#    'bioguide': 'K000381'},
#   {'name': 'Mark E. Amodei',
#    'party': 'majority',
#    'rank': 13,
#    'bioguide': 'A000369'},
#   {'name': 'Matt Cartwright',
#    'party': 'minority',
#    'rank': 13,
#    'bioguide': 'C001090'},
#   {'name': 'David G. Valadao',
#    'party': 'majority',
#    'rank': 14,
#    'bioguide': 'V000129'},
#   {'name': 'Grace Meng',
#    'party': 'minority',
#    'rank': 14,
# ...
#   {'name': 'Brian Schatz',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'S001194'},
#   {'name': 'Jeanne Shaheen',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'S001181'},
#   {'name': 'James Lankford',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Vice Chairman',
#    'bioguide': 'L000575'},
#   {'name': 'James E. Risch',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'R000584'},
#   {'name': 'Deb Fischer',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'F000463'}],
#  'SLIN': [{'name': 'Mark R. Warner',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'W000805'},
#   {'name': 'Ron Wyden', 'party': 'majority', 'rank': 2, 'bioguide': 'W000779'},
#   {'name': 'Martin Heinrich',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'H001046'},
#   {'name': 'Angus S. King, Jr.',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'K000383'},
#   {'name': 'Michael F. Bennet',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'B001267'},
#   {'name': 'Robert P. Casey, Jr.',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'C001070'},
#   {'name': 'Kirsten E. Gillibrand',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'G000555'},
#   {'name': 'Jon Ossoff',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'O000174'},
#   {'name': 'Jack Reed',
#    'party': 'majority',
#    'rank': 9,
#    'title': 'Ex Officio',
#    'bioguide': 'R000122'},
#   {'name': 'Charles E. Schumer',
#    'party': 'majority',
#    'rank': 10,
#    'title': 'Ex Officio',
#    'bioguide': 'S000148'},
#   {'name': 'Marco Rubio',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Vice Chairman',
#    'bioguide': 'R000595'},
#   {'name': 'James E. Risch',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'R000584'},
#   {'name': 'Susan M. Collins',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'C001035'},
#   {'name': 'Tom Cotton',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'C001095'},
#   {'name': 'John Cornyn',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'C001056'},
#   {'name': 'Jerry Moran',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'M000934'},
#   {'name': 'James Lankford',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'L000575'},
#   {'name': 'Mike Rounds',
#    'party': 'minority',
#    'rank': 8,
#    'bioguide': 'R000605'},
#   {'name': 'Mitch McConnell',
#    'party': 'minority',
#    'rank': 9,
#    'title': 'Ex Officio',
#    'bioguide': 'M000355'},
#   {'name': 'Roger F. Wicker',
#    'party': 'minority',
#    'rank': 10,
#    'title': 'Ex Officio',
#    'bioguide': 'W000437'}],
#  'SPAG': [{'name': 'Robert P. Casey, Jr.',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'C001070'},
#   {'name': 'Kirsten E. Gillibrand',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'G000555'},
#   {'name': 'Richard Blumenthal',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'B001277'},
#   {'name': 'Elizabeth Warren',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'W000817'},
#   {'name': 'Mark Kelly',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'K000377'},
#   {'name': 'Raphael G. Warnock',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'W000790'},
#   {'name': 'John Fetterman',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'F000479'},
#   {'name': 'Mike Braun',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'B001310'},
#   {'name': 'Tim Scott', 'party': 'minority', 'rank': 2, 'bioguide': 'S001184'},
#   {'name': 'Marco Rubio',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'R000595'},
#   {'name': 'Rick Scott',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'S001217'},
#   {'name': 'J.D. Vance',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'V000137'},
#   {'name': 'Pete Ricketts',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'R000618'}],
#  'SCNC': [{'name': 'Sheldon Whitehouse',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'W000802'},
#   {'name': 'Richard Blumenthal',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'B001277'},
#   {'name': 'Margaret Wood Hassan',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'H001076'},
#   {'name': 'Ben Ray Luján',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'L000570'},
#   {'name': 'Chuck Grassley',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Vice Chairman',
#    'bioguide': 'G000386'},
#   {'name': 'John Cornyn',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'C001056'},
#   {'name': 'James E. Risch',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'R000584'}],
#  'JCSE': [{'name': 'Benjamin L. Cardin',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Cochairman',
#    'bioguide': 'C000141',
#    'chamber': 'senate'},
#   {'name': 'Sheldon Whitehouse',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'W000802',
#    'chamber': 'senate'},
#   {'name': 'Jeanne Shaheen',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'S001181',
#    'chamber': 'senate'},
#   {'name': 'Richard Blumenthal',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'B001277',
#    'chamber': 'senate'},
#   {'name': 'Tina Smith',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'S001203',
#    'chamber': 'senate'},
#   {'name': 'Roger F. Wicker',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Cochairman',
#    'bioguide': 'W000437',
#    'chamber': 'senate'},
#   {'name': 'John Boozman',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'B001236',
#    'chamber': 'senate'},
#   {'name': 'Thom Tillis',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'T000476',
#    'chamber': 'senate'},
#   {'name': 'Tim Scott',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'S001184',
#    'chamber': 'senate'}],
#  'HLIG01': [{'name': 'Eric A. "Rick" Crawford',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'C001087'},
#   {'name': 'André Carson',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'C001072'},
#   {'name': 'Elise M. Stefanik',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'S001196'},
#   {'name': 'Joaquin Castro',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'C001091'},
#   {'name': 'Mike Gallagher',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'G000579'},
#   {'name': 'Raja Krishnamoorthi',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'K000391'},
#   {'name': 'Austin Scott',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'S001189'},
#   {'name': 'Jason Crow',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'C001121'},
#   {'name': 'Dan Crenshaw',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'C001120'},
#   {'name': 'Michael Waltz',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'W000823'}],
#  'HLIG04': [{'name': 'Trent Kelly',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'K000388'},
#   {'name': 'Chrissy Houlahan',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'H001085'},
#   {'name': 'Brad R. Wenstrup',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'W000815'},
#   {'name': 'Jason Crow',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'C001121'},
#   {'name': 'Eric A. "Rick" Crawford',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'C001087'},
#   {'name': 'Stacey E. Plaskett',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'P000610'},
#   {'name': 'Brian K. Fitzpatrick',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'F000466'},
#   {'name': 'Abigail Davis Spanberger',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'S001209'},
#   {'name': 'Mike Garcia',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'G000061'}],
#  'HSFA06': [{'name': 'Christopher H. Smith',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chair',
#    'bioguide': 'S000522'},
#   {'name': 'Susan Wild',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'W000826'},
#   {'name': 'Maria Elvira Salazar',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'S000168'},
#   {'name': 'Ami Bera', 'party': 'minority', 'rank': 2, 'bioguide': 'B001287'},
#   {'name': 'Aumua Amata Coleman Radewagen',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'R000600'},
#   {'name': 'Sara Jacobs',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'J000305'},
#   {'name': 'J. French Hill',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'H001072'},
#   {'name': 'Kathy E. Manning',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'M001135'},
#   {'name': 'Richard McCormick',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'M001218'},
#   {'name': 'John James',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'J000307'}],
#  'HLIG02': [{'name': 'Darin LaHood',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'L000585'},
#   {'name': 'Josh Gottheimer',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'G000583'},
#   {'name': 'Mike Gallagher',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'G000579'},
#   {'name': 'Joaquin Castro',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'C001091'},
#   {'name': 'Austin Scott',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'S001189'},
#   {'name': 'Ami Bera', 'party': 'minority', 'rank': 3, 'bioguide': 'B001287'},
#   {'name': 'J. French Hill',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'H001072'},
#   {'name': 'Jimmy Gomez',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'G000585'},
#   {'name': 'Michael Waltz',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'W000823'},
#   {'name': 'Mike Garcia',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'G000061'}],
#  'HSSM22': [{'name': 'Marcus J. Molinaro',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'M001221'},
#   {'name': 'Morgan McGarvey',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'M001220'},
#   {'name': 'Tracey Mann',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'M000871'},
#   {'name': 'Shri Thanedar',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'T000488'},
#   {'name': 'Maria Elvira Salazar',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'S000168'},
#   {'name': 'Chris Pappas',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'P000614'},
#   {'name': 'Jake Ellzey',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'E000071'},
#   {'name': 'Dean Phillips',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'P000616'},
#   {'name': 'Elijah Crane',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'C001132'},
#   {'name': 'Judy Chu', 'party': 'minority', 'rank': 5, 'bioguide': 'C001080'}],
#  'HSGO27': [{'name': 'Lisa C. McClain',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairwoman',
#    'bioguide': 'M001136'},
#   {'name': 'Katie Porter',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'P000618'},
#   {'name': 'Paul A. Gosar',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'G000565'},
#   {'name': 'Alexandria Ocasio-Cortez',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'O000172'},
#   {'name': 'Virginia Foxx',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'F000450'},
#   {'name': 'Jimmy Gomez',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'G000585'},
#   {'name': 'Glenn Grothman',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'G000576'},
#   {'name': 'Greg Casar',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'C001131'},
#   {'name': 'Russell Fry',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'F000478'},
#   {'name': 'Summer L. Lee',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'L000602'},
#   {'name': 'Anna Paulina Luna',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'L000596'},
#   {'name': 'Jasmine Crockett',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'C001130'},
#   {'name': 'Nicholas A. Langworthy',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'L000600'},
#   {'name': 'Eric Burlison',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'B001316'}],
#  'HSGO12': [{'name': 'Nancy Mace',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairwoman',
#    'bioguide': 'M000194'},
#   {'name': 'Gerald E. Connolly',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'C001078'},
#   {'name': 'William R. Timmons IV',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'T000480'},
#   {'name': 'Ro Khanna', 'party': 'minority', 'rank': 2, 'bioguide': 'K000389'},
#   {'name': 'Tim Burchett',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'B001309'},
#   {'name': 'Stephen F. Lynch',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'L000562'},
#   {'name': 'Marjorie Taylor Greene',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'G000596'},
#   {'name': 'Kweisi Mfume',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'M000687'},
#   {'name': 'Anna Paulina Luna',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'L000596'},
#   {'name': 'Jimmy Gomez',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'G000585'},
#   {'name': 'Chuck Edwards',
#    'party': 'majority',
#    'rank': 6,
#    'bioguide': 'E000246'},
#   {'name': 'Jared Moskowitz',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'M001217'},
#   {'name': 'Nicholas A. Langworthy',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'L000600'},
#   {'name': 'Eric Burlison',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'B001316'}],
#  'HLIG09': [{'name': 'Jimmy Gomez',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'G000585'}],
#  'HSSM21': [{'name': 'Wesley Hunt',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'H001095'},
#   {'name': 'Marie Gluesenkamp Perez',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'G000600'},
#   {'name': 'Blaine Luetkemeyer',
#    'party': 'majority',
#    'rank': 2,
#    'bioguide': 'L000569'},
#   {'name': 'Jared F. Golden',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'G000592'},
#   {'name': 'Pete Stauber',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'S001212'},
#   {'name': 'Hillary J. Scholten',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'S001221'},
#   {'name': 'Daniel Meuser',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'M001204'},
#   {'name': 'Greg Landsman',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'L000601'},
#   {'name': 'Tracey Mann',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'M000871'}],
#  'HSBA10': [{'name': 'Blaine Luetkemeyer',
#    'party': 'majority',
#    'rank': 1,
#    'title': 'Chairman',
#    'bioguide': 'L000569'},
#   {'name': 'Joyce Beatty',
#    'party': 'minority',
#    'rank': 1,
#    'title': 'Ranking Member',
#    'bioguide': 'B001281'},
#   {'name': 'Andy Barr', 'party': 'majority', 'rank': 2, 'bioguide': 'B001282'},
#   {'name': 'Vicente Gonzalez',
#    'party': 'minority',
#    'rank': 2,
#    'bioguide': 'G000581'},
#   {'name': 'Roger Williams',
#    'party': 'majority',
#    'rank': 3,
#    'bioguide': 'W000816'},
#   {'name': 'Wiley Nickel',
#    'party': 'minority',
#    'rank': 3,
#    'bioguide': 'N000194'},
#   {'name': 'Barry Loudermilk',
#    'party': 'majority',
#    'rank': 4,
#    'bioguide': 'L000583'},
#   {'name': 'Brittany Pettersen',
#    'party': 'minority',
#    'rank': 4,
#    'bioguide': 'P000620'},
#   {'name': 'Daniel Meuser',
#    'party': 'majority',
#    'rank': 5,
#    'bioguide': 'M001204'},
#   {'name': 'Bill Foster',
#    'party': 'minority',
#    'rank': 5,
#    'bioguide': 'F000454'},
#   {'name': 'Young Kim',
#    'party': 'majority',
#    'rank': 6,
#    'title': 'Vice Chairman',
#    'bioguide': 'K000397'},
#   {'name': 'Juan Vargas',
#    'party': 'minority',
#    'rank': 6,
#    'bioguide': 'V000130'},
#   {'name': 'Zachary Nunn',
#    'party': 'majority',
#    'rank': 7,
#    'bioguide': 'N000193'},
#   {'name': 'Josh Gottheimer',
#    'party': 'minority',
#    'rank': 7,
#    'bioguide': 'G000583'},
#   {'name': 'Monica De La Cruz',
#    'party': 'majority',
#    'rank': 8,
#    'bioguide': 'D000594'},
#   {'name': 'Andrew Ogles',
#    'party': 'majority',
#    'rank': 9,
#    'bioguide': 'O000175'}]}

# %% [markdown]
# The committee membership is structured about committee id (thomas id).

# %%
comm_membership.keys()
# Out:
# dict_keys(['HSII', 'HSPW', 'HSII13', 'HSII24', 'HSPW05', 'HSPW07', 'HSPW12', 'HSAS', 'HSAS02', 'HSAS28', 'HSAG', 'HSVR', 'HSAG15', 'HSAG29', 'HSVR09', 'HSVR10', 'HSAP', 'HSAP01', 'HSAP02', 'HSAP19', 'HSSY', 'HSAS29', 'HSAS35', 'HSSY16', 'HSIF', 'HSIF02', 'HSIF03', 'HSIF18', 'HSWM', 'HSWM01', 'HSWM02', 'HSWM05', 'HLIG', 'HSAG03', 'HSAG14', 'HSAG16', 'HLIG06', 'HSPW14', 'HSBA', 'HSBA01', 'HSBA04', 'HSBA16', 'HSAP20', 'HSAP23', 'HSPW02', 'HSVR03', 'HSVR08', 'HSIF16', 'HSAP10', 'HSED', 'HSED13', 'HSED14', 'HSGO', 'HSGO06', 'HSII06', 'HSII15', 'HSJU', 'HSGO24', 'HSJU01', 'HSJU08', 'JSEC', 'HSAS25', 'HSAS26', 'HSII10', 'HSIF17', 'HSJU03', 'HSAG22', 'HSAS03', 'HSPW13', 'HSBU', 'HSJU10', 'JSTX', 'HSIF14', 'HSFA', 'HSFA05', 'HSFA16', 'HSSY21', 'HSSY20', 'HSAP06', 'HSAP07', 'HSRU', 'HSED02', 'HSGO05', 'HSAP04', 'HSHM', 'HSHM05', 'HSJU05', 'HSFA14', 'HSHA', 'JSLC', 'JSPR', 'HSWM03', 'HSWM04', 'HSAP18', 'HSSM', 'HSSM24', 'HSSM27', 'HSWM06', 'HSFA13', 'HSFA17', 'HSAP15', 'HSHA08', 'HSRU04', 'HSED10', 'HSVR11', 'HSVC', 'HSHM11', 'HSHM09', 'HSFA07', 'HSRU02', 'HSHM12', 'HSSO', 'HSSY15', 'HSSY18', 'HSHM07', 'HSSM23', 'HSBA09', 'HSHM08', 'HSAP24', 'HSBA21', 'HSFD', 'HSZS', 'HSBA20', 'HSHA06', 'HSHA27', 'HSJU13', 'SSAF', 'SSAF13', 'SSAF14', 'SSAF16', 'SSAF17', 'SSAF15', 'SSAP', 'SSAP01', 'SSAP16', 'SSAP02', 'SSAP22', 'SSAP23', 'SSAP14', 'SSAP17', 'SSAP18', 'SSAP08', 'SSAP19', 'SSAP20', 'SSAP24', 'SSAS', 'SSAS14', 'SSAS21', 'SSAS20', 'SSAS17', 'SSAS15', 'SSAS13', 'SSAS16', 'SSBK', 'SSBK12', 'SSBK08', 'SSBK09', 'SSBK05', 'SSBK04', 'SSCM', 'SSCM33', 'SSCM34', 'SSCM35', 'SSCM36', 'SSCM37', 'SSCM38', 'SSCM39', 'SSEG', 'SSEG01', 'SSEG04', 'SSEG03', 'SSEG07', 'SSEV', 'SSEV09', 'SSEV10', 'SSEV15', 'SSEV08', 'SSFI', 'SSFI12', 'SSFI14', 'SSFI10', 'SSFI13', 'SSFI02', 'SSFI11', 'SSFR', 'SSFR09', 'SSFR02', 'SSFR01', 'SSFR15', 'SSFR07', 'SSFR14', 'SSFR06', 'SSHR', 'SSHR09', 'SSHR11', 'SSHR12', 'SSGA', 'SSGA01', 'SSGA20', 'SSGA22', 'SLIA', 'SSRA', 'SSSB', 'SSBU', 'SSJU', 'SSJU01', 'SSJU22', 'SSJU25', 'SSJU27', 'SSJU04', 'SSJU26', 'SSJU28', 'SSJU21', 'SSVA', 'SLET', 'SLIN', 'SPAG', 'SCNC', 'JCSE', 'HLIG01', 'HLIG04', 'HSFA06', 'HLIG02', 'HSSM22', 'HSGO27', 'HSGO12', 'HLIG09', 'HSSM21', 'HSBA10'])

# %% [markdown]
# We can look at the membership of a certain committee.

# %%
comm_membership['HSAG']
# Out:
# [{'name': 'Glenn Thompson',
#   'party': 'majority',
#   'rank': 1,
#   'title': 'Chair',
#   'bioguide': 'T000467'},
#  {'name': 'David Scott',
#   'party': 'minority',
#   'rank': 1,
#   'title': 'Ranking Member',
#   'bioguide': 'S001157'},
#  {'name': 'Frank D. Lucas',
#   'party': 'majority',
#   'rank': 2,
#   'bioguide': 'L000491'},
#  {'name': 'Jim Costa', 'party': 'minority', 'rank': 2, 'bioguide': 'C001059'},
#  {'name': 'Austin Scott',
#   'party': 'majority',
#   'rank': 3,
#   'title': 'Vice Chairman',
#   'bioguide': 'S001189'},
#  {'name': 'James P. McGovern',
#   'party': 'minority',
#   'rank': 3,
#   'bioguide': 'M000312'},
#  {'name': 'Eric A. "Rick" Crawford',
#   'party': 'majority',
#   'rank': 4,
#   'bioguide': 'C001087'},
#  {'name': 'Alma S. Adams',
#   'party': 'minority',
#   'rank': 4,
#   'bioguide': 'A000370'},
#  {'name': 'Scott DesJarlais',
#   'party': 'majority',
#   'rank': 5,
#   'bioguide': 'D000616'},
#  {'name': 'Abigail Davis Spanberger',
#   'party': 'minority',
#   'rank': 5,
#   'bioguide': 'S001209'},
#  {'name': 'Doug LaMalfa',
#   'party': 'majority',
#   'rank': 6,
#   'bioguide': 'L000578'},
#  {'name': 'Jahana Hayes',
#   'party': 'minority',
#   'rank': 6,
#   'bioguide': 'H001081'},
#  {'name': 'David Rouzer',
#   'party': 'majority',
#   'rank': 7,
#   'bioguide': 'R000603'},
#  {'name': 'Shontel M. Brown',
#   'party': 'minority',
#   'rank': 7,
#   'bioguide': 'B001313'},
#  {'name': 'Trent Kelly',
#   'party': 'majority',
#   'rank': 8,
#   'bioguide': 'K000388'},
#  {'name': 'Sharice Davids',
#   'party': 'minority',
#   'rank': 8,
#   'bioguide': 'D000629'},
#  {'name': 'Don Bacon', 'party': 'majority', 'rank': 9, 'bioguide': 'B001298'},
#  {'name': 'Elissa Slotkin',
#   'party': 'minority',
#   'rank': 9,
#   'bioguide': 'S001208'},
#  {'name': 'Mike Bost', 'party': 'majority', 'rank': 10, 'bioguide': 'B001295'},
#  {'name': 'Yadira Caraveo',
#   'party': 'minority',
#   'rank': 10,
#   'bioguide': 'C001134'},
#  {'name': 'Dusty Johnson',
#   'party': 'majority',
#   'rank': 11,
#   'bioguide': 'J000301'},
#  {'name': 'Andrea Salinas',
#   'party': 'minority',
#   'rank': 11,
#   'bioguide': 'S001226'},
#  {'name': 'James R. Baird',
#   'party': 'majority',
#   'rank': 12,
#   'bioguide': 'B001307'},
#  {'name': 'Marie Gluesenkamp Perez',
#   'party': 'minority',
#   'rank': 12,
#   'bioguide': 'G000600'},
#  {'name': 'Tracey Mann',
#   'party': 'majority',
#   'rank': 13,
#   'bioguide': 'M000871'},
#  {'name': 'Donald G. Davis',
#   'party': 'minority',
#   'rank': 13,
#   'bioguide': 'D000230'},
#  {'name': 'Randy Feenstra',
#   'party': 'majority',
#   'rank': 14,
#   'bioguide': 'F000446'},
#  {'name': 'Jill N. Tokuda',
#   'party': 'minority',
#   'rank': 14,
#   'bioguide': 'T000487'},
#  {'name': 'Mary E. Miller',
#   'party': 'majority',
#   'rank': 15,
#   'bioguide': 'M001211'},
#  {'name': 'Nikki Budzinski',
#   'party': 'minority',
#   'rank': 15,
#   'bioguide': 'B001315'},
#  {'name': 'Barry Moore',
#   'party': 'majority',
#   'rank': 16,
#   'bioguide': 'M001212'},
#  {'name': 'Eric Sorensen',
#   'party': 'minority',
#   'rank': 16,
#   'bioguide': 'S001225'},
#  {'name': 'Kat Cammack',
#   'party': 'majority',
#   'rank': 17,
#   'bioguide': 'C001039'},
#  {'name': 'Gabe Vasquez',
#   'party': 'minority',
#   'rank': 17,
#   'bioguide': 'V000136'},
#  {'name': 'Brad Finstad',
#   'party': 'majority',
#   'rank': 18,
#   'bioguide': 'F000475'},
#  {'name': 'Jasmine Crockett',
#   'party': 'minority',
#   'rank': 18,
#   'bioguide': 'C001130'},
#  {'name': 'John W. Rose',
#   'party': 'majority',
#   'rank': 19,
#   'bioguide': 'R000612'},
#  {'name': 'Jonathan L. Jackson',
#   'party': 'minority',
#   'rank': 19,
#   'bioguide': 'J000309'},
#  {'name': 'Ronny Jackson',
#   'party': 'majority',
#   'rank': 20,
#   'bioguide': 'J000304'},
#  {'name': 'Greg Casar',
#   'party': 'minority',
#   'rank': 20,
#   'bioguide': 'C001131'},
#  {'name': 'Marcus J. Molinaro',
#   'party': 'majority',
#   'rank': 21,
#   'bioguide': 'M001221'},
#  {'name': 'Chellie Pingree',
#   'party': 'minority',
#   'rank': 21,
#   'bioguide': 'P000597'},
#  {'name': 'Monica De La Cruz',
#   'party': 'majority',
#   'rank': 22,
#   'bioguide': 'D000594'},
#  {'name': 'Salud O. Carbajal',
#   'party': 'minority',
#   'rank': 22,
#   'bioguide': 'C001112'},
#  {'name': 'Nicholas A. Langworthy',
#   'party': 'majority',
#   'rank': 23,
#   'bioguide': 'L000600'},
#  {'name': 'Angie Craig',
#   'party': 'minority',
#   'rank': 23,
#   'bioguide': 'C001119'},
#  {'name': 'John S. Duarte',
#   'party': 'majority',
#   'rank': 24,
#   'bioguide': 'D000633'},
#  {'name': 'Darren Soto',
#   'party': 'minority',
#   'rank': 24,
#   'bioguide': 'S001200'},
#  {'name': 'Zachary Nunn',
#   'party': 'majority',
#   'rank': 25,
#   'bioguide': 'N000193'},
#  {'name': 'Sanford D. Bishop, Jr.',
#   'party': 'minority',
#   'rank': 25,
#   'bioguide': 'B000490'},
#  {'name': 'Mark Alford',
#   'party': 'majority',
#   'rank': 26,
#   'bioguide': 'A000379'},
#  {'name': 'Derrick Van Orden',
#   'party': 'majority',
#   'rank': 27,
#   'bioguide': 'V000135'},
#  {'name': 'Lori Chavez-DeRemer',
#   'party': 'majority',
#   'rank': 28,
#   'bioguide': 'C001135'},
#  {'name': 'Max L. Miller',
#   'party': 'majority',
#   'rank': 29,
#   'bioguide': 'M001222'}]

# %%
# or look at a single member 
comm_membership['HSAG'][5]
# Out:
# {'name': 'James P. McGovern',
#  'party': 'minority',
#  'rank': 3,
#  'bioguide': 'M000312'}

# %% [markdown]
# ### Create DataFrame linking Committee with Members
#
# Next, we can create a DataFrame that links committee id with legislator's ids.

# %%
member_df = pd.DataFrame(
    columns=['comm_id', 'leg_id'],
    data=[[c, m['bioguide']] for c, members in comm_membership.items() for m in members]
)
member_df.head()
# Out:
#   comm_id   leg_id
# 0    HSII  W000821
# 1    HSII  G000551
# 2    HSII  L000564
# 3    HSII  N000179
# 4    HSII  W000804

# %% [markdown]
# ### Merge DataFrames
#
# Now we can merge this `member_df` with the `comm_df`

# %%
member_comm = member_df.merge(comm_df, left_on='comm_id', right_on='thomas_id')
member_comm.head()
# Out:
#   comm_id   leg_id                                  name thomas_id   type
# 0    HSII  W000821  House Committee on Natural Resources      HSII  house
# 1    HSII  G000551  House Committee on Natural Resources      HSII  house
# 2    HSII  L000564  House Committee on Natural Resources      HSII  house
# 3    HSII  N000179  House Committee on Natural Resources      HSII  house
# 4    HSII  W000804  House Committee on Natural Resources      HSII  house

# %%
member_comm2 = pd.merge(member_df, comm_df, left_on='comm_id', right_on='thomas_id')
member_comm2.head()
# Out:
#   comm_id   leg_id                                  name thomas_id   type
# 0    HSII  W000821  House Committee on Natural Resources      HSII  house
# 1    HSII  G000551  House Committee on Natural Resources      HSII  house
# 2    HSII  L000564  House Committee on Natural Resources      HSII  house
# 3    HSII  N000179  House Committee on Natural Resources      HSII  house
# 4    HSII  W000804  House Committee on Natural Resources      HSII  house

# %%
comm_sizes = member_comm['name'].value_counts()
comm_sizes.head()
# Out:
# name
# House Committee on Transportation and Infrastructure    65
# House Committee on Appropriations                       60
# House Committee on Armed Services                       59
# House Committee on Agriculture                          54
# House Committee on Financial Services                   52
# Name: count, dtype: int64

# %% [markdown]
# Alternatively, we can merge the member_comm with the legislators data frame.

# %%
df = member_comm.merge(leg_df, left_on='leg_id', right_on='id')
df.head()
# Out:
#   comm_id   leg_id                                               name  \
# 0    HSII  W000821               House Committee on Natural Resources
# 1    HSPW  W000821  House Committee on Transportation and Infrastr...
# 2    HSII  G000551               House Committee on Natural Resources
# 3    HSED  G000551     House Committee on Education and the Workforce
# 4    HSII  L000564               House Committee on Natural Resources
#
#   thomas_id   type       id  first       last   birthday        age
# 0      HSII  house  W000821  Bruce  Westerman 1967-11-18  55.950685
# 1      HSPW  house  W000821  Bruce  Westerman 1967-11-18  55.950685
# 2      HSII  house  G000551   Raúl   Grijalva 1948-02-19  75.709589
# 3      HSED  house  G000551   Raúl   Grijalva 1948-02-19  75.709589
# 4      HSII  house  L000564   Doug    Lamborn 1954-05-24  69.446575

# %% [markdown]
# Now we can look at things like, what is the mean age for members of each committee.

# %%
comm_ages = df['age'].groupby(df['name']).mean().sort_values()
comm_ages.head()
# Out:
# name
# House Permanent Select Committee on Intelligence                                                                 52.131849
# House Select Committee on the Strategic Competition Between the United States and the Chinese Communist Party    52.275799
# House Committee on Oversight and Accountability                                                                  52.588108
# House Committee on Armed Services                                                                                53.910193
# House Committee on Agriculture                                                                                   53.983511
# Name: age, dtype: float64

# %% [markdown]
# Or, the overall mean age for all legislators.

# %%
leg_df['age'].mean()
# Out:
# 59.37353800798028

# %% [markdown]
# ### Calculate number of committees each legislator is on
#
# Let's calculate the number of committees a given legislator is on.

# %%
member_count = member_df['leg_id'].value_counts().to_frame().reset_index()
member_count.columns = ['id', 'num_comms']
member_count.head()
# Out:
#         id  num_comms
# 0  F000463         22
# 1  R000122         21
# 2  C001088         20
# 3  W000437         20
# 4  P000595         19

# %% [markdown]
# We can merge the legislator Data Frame, with the `member_count` DataFrame to have the name, age, and number of committees for each legislator.

# %%
df = leg_df.merge(member_count, left_on='id', right_on='id')
df.head()
# Out:
#         id     first      last   birthday        age  num_comms
# 0  B000944   Sherrod     Brown 1952-11-09  70.983562         13
# 1  C000127     Maria  Cantwell 1958-10-13  65.054795         13
# 2  C000141  Benjamin    Cardin 1943-10-05  80.087671         18
# 3  C000174    Thomas    Carper 1947-01-23  76.783562         12
# 4  C001070    Robert     Casey 1960-04-13  63.553425          9

# %% [markdown]
# Finally, we can plot the age of a legislator versus the number of committees they serve on.

# %%
sns.lmplot(x='age', y='num_comms', data=df, fit_reg=True);

# %% [markdown]
# # Review of Grouping Data
#
# For most of the course so far, we have been working with a single data file at a time.
#
# Let's look at how we can do grouping within a single data set and also working across multiple data sets.

# %%
df = pd.read_csv("elections.csv")
df.head()
# Out:
#   Candidate        Party  Perc  Year Result
# 0    Reagan   Republican  50.7  1980    win
# 1    Carter   Democratic  41.0  1980   loss
# 2  Anderson  Independent   6.6  1980   loss
# 3    Reagan   Republican  58.8  1984    win
# 4   Mondale   Democratic  37.6  1984   loss

# %% [markdown]
# ## Grouping a Series by a Series
#
# Let's group the 'Perc' Series by the `Party` Series. We have seen a call to [`groupby`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html) do this.

# %%
percent_grouped_by_party = df['Perc'].groupby(df['Party'])
type(percent_grouped_by_party)
# Out:
# pandas.core.groupby.generic.SeriesGroupBy

# %% [markdown]
# As we see, `percent_grouped_by_party` is **NOT** a DataFrame, Series, or Index. Instead, it's a `SeriesGroupBy` object. A `SeriesGroupBy` consists of `groups`, one for each of the distinct values of the `Party` column. If we ask to see these groups, we'll be able to see which indices in the original DataFrame correspond to each group.

# %%
import pprint
pprint.pprint(percent_grouped_by_party.groups)
# Out:
# {'Democratic': [1, 4, 6, 7, 10, 13, 15, 17, 19, 21], 'Independent': [2, 9, 12], 'Republican': [0, 3, 5, 8, 11, 14, 16, 18, 20, 22]}

# %% [markdown]
# The `percent_grouped_by_party` object is capable of making computations across all these groups.
#
# For example, if we call the `mean` method of the `SeriesGroupBy` class.  We'll get a new `Series` containing the mean of the "Democratic" `Series`, the mean of the "Independent" `Series`, and the mean of the "Republican" `Series`.

# %%
percent_grouped_by_party.mean()
# Out:
# Party
# Democratic     46.53
# Independent    11.30
# Republican     47.86
# Name: Perc, dtype: float64

# %% [markdown]
# We can iterate over a `SeriesGroupBy` object.  Each element is a pair of `(name, group)`, where `name` is a String label for the group and `group` is a `Series` corresponding to all the values from that group.

# %%
from IPython.display import display  # like print, but for complex objects

for name, group in percent_grouped_by_party:
    print('Name:', name)
    print(type(group))
    display(group.head())
    print('\n')
# Out:
# Name: Democratic
# <class 'pandas.core.series.Series'>
# 1     41.0
# 4     37.6
# 6     45.6
# 7     43.0
# 10    49.2
# Name: Perc, dtype: float64
# Name: Independent
# <class 'pandas.core.series.Series'>
# 2      6.6
# 9     18.9
# 12     8.4
# Name: Perc, dtype: float64
# Name: Republican
# <class 'pandas.core.series.Series'>
# 0     50.7
# 3     58.8
# 5     53.4
# 8     37.4
# 11    40.7
# Name: Perc, dtype: float64

# %% [markdown]
# ## Grouping a Series by Multiple Series
#
# We can also group a Series by multiple Series.  For example, suppose we want to track all combinations of `{'Democratic', 'Republican', and 'Independent'}` and `{'win', 'loss'}`.

# %%
percent_grouped_by_party_and_result = df['Perc'].groupby([df['Party'], df['Result']])
percent_grouped_by_party_and_result.groups
# Out:
# {('Democratic', 'loss'): [1, 4, 6, 13, 15, 21], ('Democratic', 'win'): [7, 10, 17, 19], ('Independent', 'loss'): [2, 9, 12], ('Republican', 'loss'): [8, 11, 18, 20], ('Republican', 'win'): [0, 3, 5, 14, 16, 22]}

# %%
pprint.pprint(percent_grouped_by_party_and_result.groups)
# Out:
# {('Democratic', 'loss'): [1, 4, 6, 13, 15, 21], ('Democratic', 'win'): [7, 10, 17, 19], ('Independent', 'loss'): [2, 9, 12], ('Republican', 'loss'): [8, 11, 18, 20], ('Republican', 'win'): [0, 3, 5, 14, 16, 22]}

# %% [markdown]
# Given this groupby object, we can compute the average percentage earned every time each of the parties won and lost the presidential election. We see that at least between 1980 and 2016, the Republicans have typically lost and won their elections by wider margins.

# %%
party_result_mean = percent_grouped_by_party_and_result.mean()
party_result_mean
# Out:
# Party        Result
# Democratic   loss      44.850000
#              win       49.050000
# Independent  loss      11.300000
# Republican   loss      42.750000
#              win       51.266667
# Name: Perc, dtype: float64

# %% [markdown]
# The careful reader will note that the returned object looks a little funny. It seems to have two indexes! If we check the type of this object, we'll see it's just a regular Series.

# %%
type(party_result_mean)
# Out:
# pandas.core.series.Series

# %% [markdown]
# However if we request to see the index of this Series, we see that it is a "MultiIndex", which is a special type of index used for data that is indexed in two or more ways.

# %%
party_result_mean.index
# Out:
# MultiIndex([( 'Democratic', 'loss'),
#             ( 'Democratic',  'win'),
#             ('Independent', 'loss'),
#             ( 'Republican', 'loss'),
#             ( 'Republican',  'win')],
#            names=['Party', 'Result'])

# %% [markdown]
# Selecting an element of a multi-index gives you a series with just an index.

# %%
party_result_mean['Republican']
# Out:
# Result
# loss    42.750000
# win     51.266667
# Name: Perc, dtype: float64

# %% [markdown]
# Or, you can select both levels at once.

# %%
party_result_mean['Democratic', 'win']
# Out:
# 49.05

# %% [markdown]
# ## Grouping a DataFrame by a Series
#
# We can also group an entire dataframe by one or more Series. The result is a DataFrameGroupBy object:

# %%
everything_grouped_by_party = df.groupby('Party')
everything_grouped_by_party

# %% [markdown]
# As in our previous example, this object contains three group objects, one for each party label.

# %%
pprint.pprint(everything_grouped_by_party.groups)
# Out:
# {'Democratic': [1, 4, 6, 7, 10, 13, 15, 17, 19, 21], 'Independent': [2, 9, 12], 'Republican': [0, 3, 5, 8, 11, 14, 16, 18, 20, 22]}

# %% [markdown]
# Just as with SeriesGroupBy objects, we can iterate over a DataFrameGroupBy object to understand what is effectively inside.

# %%
for n, g in everything_grouped_by_party:
    print('name:', n)
    display(g.head())
# Out:
# name: Democratic
#    Candidate       Party  Perc  Year Result
# 1     Carter  Democratic  41.0  1980   loss
# 4    Mondale  Democratic  37.6  1984   loss
# 6    Dukakis  Democratic  45.6  1988   loss
# 7    Clinton  Democratic  43.0  1992    win
# 10   Clinton  Democratic  49.2  1996    win
# name: Independent
#    Candidate        Party  Perc  Year Result
# 2   Anderson  Independent   6.6  1980   loss
# 9      Perot  Independent  18.9  1992   loss
# 12     Perot  Independent   8.4  1996   loss
# name: Republican
#    Candidate       Party  Perc  Year Result
# 0     Reagan  Republican  50.7  1980    win
# 3     Reagan  Republican  58.8  1984    win
# 5       Bush  Republican  53.4  1988    win
# 8       Bush  Republican  37.4  1992   loss
# 11      Dole  Republican  40.7  1996   loss

# %% [markdown]
# And just like SeriesGroupBy objects, we can apply methods like mean to compute the mean of each group. Since a DataFrameGroupBy is linked to the entire original dataframe (instead of to a single column from the dataframe), we calculate a mean for every numerical column.

# %%
everything_grouped_by_party[['Perc', 'Year']].mean()
# Out:
#               Perc         Year
# Party
# Democratic   46.53  1998.000000
# Independent  11.30  1989.333333
# Republican   47.86  1998.000000

# %% [markdown]
# ## Grouping a DataFrame by MultipleSeries
#
# DataFrames may also be grouped by multiple series at once. For example, we can repeat what we did with a Series above and group the entire DataFrame by Party and Result. After aggregation, we end up with a DataFrame that has a MultiIndex.

# %%
everything_grouped_by_party_and_result=df.groupby([df['Party'], df['Result']])
everything_grouped_by_party_and_result.max()
# Out:
#                    Candidate  Perc  Year
# Party       Result
# Democratic  loss     Mondale  48.4  2016
#             win        Obama  52.9  2012
# Independent loss       Perot  18.9  1996
# Republican  loss      Romney  47.2  2012
#             win        Trump  58.8  2016

# %% [markdown]
# The resulting DataFrame above is pretty strange. We'll observe that Walter Mondale did not run for office in 2016! Make sure you understand why this is happening, as this sort of thing is a common mistake made by people who don't fully understand how pandas works.

# %% [markdown]
# **Question:** How do you generate a table like the one above, except that each entry should represent all attributes of the candidate who got the maximum vote in that category? For example, the Republican Win category should feature Reagan in 1984 with 58.8% of the vote. *Hint:* Try sorting.

# %%
(df.sort_values("Perc", ascending=False).
    groupby([df['Party'], df['Result']]).
    first())
# Out:
#                    Candidate        Party  Perc  Year Result
# Party       Result
# Democratic  loss        Gore   Democratic  48.4  2000   loss
#             win        Obama   Democratic  52.9  2008    win
# Independent loss       Perot  Independent  18.9  1992   loss
# Republican  loss      Romney   Republican  47.2  2012   loss
#             win       Reagan   Republican  58.8  1984    win

# %% [markdown]
# ## Custom Aggregation Functions
#
# As described above, both `SeriesGroupBy` and `DataFrameGroupBy` objects have lots of handy methods for computing aggregate values for groups, e.g.

# %%
percent_grouped_by_party.min()
# Out:
# Party
# Democratic     37.6
# Independent     6.6
# Republican     37.4
# Name: Perc, dtype: float64

# %%
everything_grouped_by_party['Perc'].median()
# Out:
# Party
# Democratic     48.25
# Independent     8.40
# Republican     47.55
# Name: Perc, dtype: float64

# %% [markdown]
# It turns out that all of these GroupBy methods are just shorthand for a more powerful and universal method of our GroupBy objects called `agg`. For example, `.min()` is just shorthand for `.agg(min)`, where `min` refers to the function `min`.

# %%
percent_grouped_by_party.agg(min)
# Out:
# Party
# Democratic     37.6
# Independent     6.6
# Republican     37.4
# Name: Perc, dtype: float64

# %% [markdown]
# Naturally, we can define our own custom aggregation functions. For example, the function below returns the first item in a series.

# %%
def average_of_first_and_last(series):
    return (series.iloc[0] + series.iloc[-1])/2

# %% [markdown]
# We can supply this function as a custom aggregation function for each series. As you can see, nuisance columns are automatically removed.

# %%
percent_grouped_by_party_and_result.agg(average_of_first_and_last)
# Out:
# Party        Result
# Democratic   loss      44.60
#              win       47.05
# Independent  loss       7.50
# Republican   loss      42.30
#              win       48.40
# Name: Perc, dtype: float64

# %% [markdown]
# `agg` is fundamental to our use of GroupBy objects. Indeed, you will rarely call `groupby` without also calling `agg`, at least implicitly. We can summarize the grouping process with the following diagram, inspired by a similar diagram created by DS100 instructor Joey Gonzales. Diagram source at [this link](https://docs.google.com/presentation/d/1FrYg6yd6B-CIgfWLWm4W8vBhfmJ6Qt9dKkN-mlN5AKU/edit#slide=id.g4131093782_0_40).
#
# <img src="https://pages.mtu.edu/~lebrown/un5550-f20/week8/groupby_overview.png">

# %% [markdown]
# The result of calling `groupby` then `agg` on a `Series` is also a `Series`, and the result of calling `groupby` then `agg` on a `DataFrame` is also typically a `DataFrame`, though there are exceptions, e.g. if you use the aggregation function `size`, you will get back a `Series`.

# %%
def list_of_first_and_last(series):
    return [series.iloc[0], series.iloc[-1]]

# %%
everything_grouped_by_party.agg(list_of_first_and_last)
# Out:
#                      Candidate          Perc          Year        Result
# Party
# Democratic   [Carter, Clinton]  [41.0, 48.2]  [1980, 2016]  [loss, loss]
# Independent  [Anderson, Perot]    [6.6, 8.4]  [1980, 1996]  [loss, loss]
# Republican     [Reagan, Trump]  [50.7, 46.1]  [1980, 2016]    [win, win]

# %% [markdown]
# ## Using Groups to Filter Datasets

# %%
everything_grouped_by_candidate = df.groupby('Candidate')
everything_grouped_by_candidate.filter(lambda subframe: subframe["Year"].max() > 2000)
# Out:
#    Candidate       Party  Perc  Year Result
# 5       Bush  Republican  53.4  1988    win
# 7    Clinton  Democratic  43.0  1992    win
# 8       Bush  Republican  37.4  1992   loss
# 10   Clinton  Democratic  49.2  1996    win
# 14      Bush  Republican  47.9  2000    win
# 15     Kerry  Democratic  48.3  2004   loss
# 16      Bush  Republican  50.7  2004    win
# 17     Obama  Democratic  52.9  2008    win
# 18    McCain  Republican  45.7  2008   loss
# 19     Obama  Democratic  51.1  2012    win
# 20    Romney  Republican  47.2  2012   loss
# 21   Clinton  Democratic  48.2  2016   loss
# 22     Trump  Republican  46.1  2016    win

# %%
everything_grouped_by_year = df.groupby('Year')

# %%
everything_grouped_by_year.filter(lambda subframe: subframe["Perc"].sum() < 97)
# Out:
#    Candidate       Party  Perc  Year Result
# 3     Reagan  Republican  58.8  1984    win
# 4    Mondale  Democratic  37.6  1984   loss
# 13      Gore  Democratic  48.4  2000   loss
# 14      Bush  Republican  47.9  2000    win
# 21   Clinton  Democratic  48.2  2016   loss
# 22     Trump  Republican  46.1  2016    win

# %% [markdown]
# A visual picture of how filtering works is shown below.
#
# <img src="https://pages.mtu.edu/~lebrown/un5550-f20/week8/filter_overview.png">

# %% [markdown]
# ## Using `isin` for filtering

# %% [markdown]
# This isn't actually related to `groupby` at all, but it seemed natural to bring it up here.
#
# Sometimes we want to restrict our attention to only rows where certain values appear. For example, we saw last time how we'd look at only rows that contain "Democratic" candidates.

# %%
df[df["Party"] == "Democratic"]
# Out:
#    Candidate       Party  Perc  Year Result
# 1     Carter  Democratic  41.0  1980   loss
# 4    Mondale  Democratic  37.6  1984   loss
# 6    Dukakis  Democratic  45.6  1988   loss
# 7    Clinton  Democratic  43.0  1992    win
# 10   Clinton  Democratic  49.2  1996    win
# 13      Gore  Democratic  48.4  2000   loss
# 15     Kerry  Democratic  48.3  2004   loss
# 17     Obama  Democratic  52.9  2008    win
# 19     Obama  Democratic  51.1  2012    win
# 21   Clinton  Democratic  48.2  2016   loss

# %% [markdown]
# Suppose we wanted to filter such that all Republicans and Democrats appeared. One ugly way to do this would be `df[(df["Party"] == "Democratic") | (df["Party"] == "Republican")]`. However, a better idea is to use the `isin` method.

# %%
df[(df["Party"] == "Democratic") | (df["Party"] == "Republican")]
# Out:
#    Candidate       Party  Perc  Year Result
# 0     Reagan  Republican  50.7  1980    win
# 1     Carter  Democratic  41.0  1980   loss
# 3     Reagan  Republican  58.8  1984    win
# 4    Mondale  Democratic  37.6  1984   loss
# 5       Bush  Republican  53.4  1988    win
# 6    Dukakis  Democratic  45.6  1988   loss
# 7    Clinton  Democratic  43.0  1992    win
# 8       Bush  Republican  37.4  1992   loss
# 10   Clinton  Democratic  49.2  1996    win
# 11      Dole  Republican  40.7  1996   loss
# 13      Gore  Democratic  48.4  2000   loss
# 14      Bush  Republican  47.9  2000    win
# 15     Kerry  Democratic  48.3  2004   loss
# 16      Bush  Republican  50.7  2004    win
# 17     Obama  Democratic  52.9  2008    win
# 18    McCain  Republican  45.7  2008   loss
# 19     Obama  Democratic  51.1  2012    win
# 20    Romney  Republican  47.2  2012   loss
# 21   Clinton  Democratic  48.2  2016   loss
# 22     Trump  Republican  46.1  2016    win

# %%
df[df["Party"].isin(["Republican", "Democratic"])]
# Out:
#    Candidate       Party  Perc  Year Result
# 0     Reagan  Republican  50.7  1980    win
# 1     Carter  Democratic  41.0  1980   loss
# 3     Reagan  Republican  58.8  1984    win
# 4    Mondale  Democratic  37.6  1984   loss
# 5       Bush  Republican  53.4  1988    win
# 6    Dukakis  Democratic  45.6  1988   loss
# 7    Clinton  Democratic  43.0  1992    win
# 8       Bush  Republican  37.4  1992   loss
# 10   Clinton  Democratic  49.2  1996    win
# 11      Dole  Republican  40.7  1996   loss
# 13      Gore  Democratic  48.4  2000   loss
# 14      Bush  Republican  47.9  2000    win
# 15     Kerry  Democratic  48.3  2004   loss
# 16      Bush  Republican  50.7  2004    win
# 17     Obama  Democratic  52.9  2008    win
# 18    McCain  Republican  45.7  2008   loss
# 19     Obama  Democratic  51.1  2012    win
# 20    Romney  Republican  47.2  2012   loss
# 21   Clinton  Democratic  48.2  2016   loss
# 22     Trump  Republican  46.1  2016    win

# %% [markdown]
# ## Pivot Tables
#
# Recall from before that we were able to group the "Perc" Series by the "Party" and "Result" Series, allowing us to understand the average vote earned by each party under each election result.

# %%
percent_grouped_by_party_and_result = df['Perc'].groupby([df['Party'], df['Result']])
percent_grouped_by_party_and_result.mean()
# Out:
# Party        Result
# Democratic   loss      44.850000
#              win       49.050000
# Independent  loss      11.300000
# Republican   loss      42.750000
#              win       51.266667
# Name: Perc, dtype: float64

# %% [markdown]
# Because we called `groupby` on a Series, the result of our aggregation operation was also a Series. However, I believe this data is more naturally expressed in a tabular format, with Party as the rows, and Result as the columns. The `pivot_table` operation is the natural way to achieve this data format.

# %%
df_pivot = df.pivot_table(
    index='Party', # the rows (turned into index)
    columns='Result', # the column values
    values='Perc', # the field(s) to processed in each group
    aggfunc=np.mean, # group operation
)
df_pivot.head()
# Out:
# Result        loss        win
# Party
# Democratic   44.85  49.050000
# Independent  11.30        NaN
# Republican   42.75  51.266667

# %% [markdown]
# The basic idea is that you specify a Series to be the `index` (i.e. rows) and a Series to be the `columns`. The data in the specified `values` is then grouped by all possible combinations of values that occur in the `index` and `columns` Series. These groups are then aggregated using the `aggfunc`, and arranged into a table that matches the requested `index` and `columns`. The diagram below summarizes how pivot tables are formed. (Diagram inspired by Joey Gonzales). Diagram source at [this link](https://docs.google.com/presentation/d/1FrYg6yd6B-CIgfWLWm4W8vBhfmJ6Qt9dKkN-mlN5AKU/edit#slide=id.g4131093782_0_89).
#
# <img src="https://pages.mtu.edu/~lebrown/un5550-f20/week8/pivot_table_overview.png">
#
# For more on pivot tables, see [this excellent tutorial](http://pbpython.com/pandas-pivot-table-explained.html) by Chris Moffitt.
