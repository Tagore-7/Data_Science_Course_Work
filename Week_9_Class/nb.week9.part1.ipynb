# %% [markdown]
# # SQL Review and Practice
#
#
# Many of the examples have been adapted from Data100 and J. Canny's course.

# %% [markdown]
# ## Setup
#
# This notebook makes use of a python module: `utils.py` as well as 4 data files:
#
# * `pls_fy2009_pupld09a.csv`
# * `pls_fy2014_pupld09a.csv`
# * `us_counties_2000.csv`
# * `us_counties_2010.csv`

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#from pathlib import Path
# !pip install sqlalchemy
#from sqlalchemy import create_engine
from utils import fetch_and_cache

# %%
# %%html
# <style>
# table {margin-left: 0 !important;}
# </style>
# Out:
# <style>
# table {margin-left: 0 !important;}
# </style>

# %% [markdown]
# For this lab, we will be using SQLite to connect to databases. This is a simple, light-way module, there are of course other modules to interact with databases.
#
# SQLite has a [nice tutorial](https://www.sqlitetutorial.net/) if you want to learn more about database queries and explore additional options.

# %%
import sqlite3

# %% [markdown]
# A couple of things to know about SQLite.  Other database systems such as `MySQL` and `PostgreSQL` use *static typing*, where a column is declared for a specific data type and can only store data of that type.
#
# SQLite uses *dynamic type system*, where a value stored in a column determines its data type, not the column's data type.

# %% [markdown]
# # Connecting to a Database

# %% [markdown]
# ## Example 1 - School Enrollment
#
# *Example from Practical SQL, by Anthony DeBarros, 2018 - Available on O'reilly's learning platform*
# Let's look at an example that walks through a creating a table, inserting rows, querying the table, etc.
#
# For this example, we are going to create a database for managing a school's enrollment.  Within the database there are several tables.
#
# The first table, `student_enrollment`, shows student signed up for each class section:
#
#     student_id    class_id      class_section    semester
#     ----------    ----------    -------------    ---------
#     CHRISPA004    COMPSCI101    3                Fall 2017
#     DAVISHE010    COMPSCI101    3                Fall 2017
#     ABRILDA002    ENG101        40               Fall 2017
#     DAVISHE010    ENG101        40               Fall 2017
#     RILEYPH002    ENG101        40               Fall 2017

# %% [markdown]
# A separate table, `students`, stores information about the students. The `student_id` column is used to identify each student.  The value is the unique `key` to connect the tables.
#
#     student_id    first_name    last_name    dob
#     ----------    ----------    ---------    ----------
#     ABRILDA002    Abril         Davis        1999-01-10
#     CHRISPA004    Chris         Park         1996-04-10
#     DAVISHE010    Davis         Hernandez    1987-09-14
#     RILEYPH002    Riley         Phelps       1996-06-15

# %% [markdown]
# A final table, `classes`, stores information about each class, where the `class_id` is the primary key.
#
#     class_id      first_name    last_name
#     ----------    ----------    ---------
#     COMPSCI101    Davis         Hernandez
#     COMPSCI101    Chris         Park
#     ENG101        Abril         Davis
#     ENG101        Davis         Hernandez
#     ENG101        Riley         Phelps

# %% [markdown]
# Let's connect to a new, empty database `analysis.db`

# %%
conn = sqlite3.connect("analysis.db")

# %% [markdown]
# ### Printing out SQL calls and results
#
# We define a function `print_sql(s)` that given a database connection `c` and a sql query `s` returns the result of that executing.

# %%
def print_sql(c, s):
    print('>', s)
    for result in c.execute(s):
        print(result)
    print()

# %% [markdown]
# We can confirm that the database is empty.

# %%
print_sql(conn, 'SELECT sql FROM sqlite_master;')
# Out:
# > SELECT sql FROM sqlite_master;

# %% [markdown]
# We could also use `pandas` `read_sql` function to read in the results of the query to a dataframe to display.
#
# *Be careful with running this code as it will create the dataframe - for a query that returns many records this could be memory-intensive*

# %%
def pretty_print_sql(c, s):
    print('>', s)
    df = pd.read_sql(s, c)
    display(df)

# %%
pretty_print_sql(conn, 'SELECT sql FROM sqlite_master;')
# Out:
# > SELECT sql FROM sqlite_master;
# Empty DataFrame
# Columns: [sql]
# Index: []

# %% [markdown]
# # Create a Relation (Table)

# %% [markdown]
# The simple form of creating a table is:
#
# ```mysql
# CREATE TABLE <name> (
#     <alist of elements>
# );
# ```

# %% [markdown]
# ## Example 2 - Banking
#
# Banking example from J. Freire consisting of the following relations.
#
# The first table, `Account`, has banking account information:
#
#     number    custID    owner        balance      type
#     ------    ------    ---------    ---------    ---------
#     101       1         J. Smith     1000.00      checking
#     102       2         W. Wei       2000.00      checking
#     103       1         J. Smith     5000.00      saving
#     104       3         M. Jones     1000.00      checking
#     105       4         H. Martin    10000.00     checking
#
# The second table, `Deposit`, has transaction information:
#
#     account    transID    dDate       amount
#     -------    -------    --------    ---------
#     102        1          10/22/21    500.00
#     102        2          10/29/21    200.00
#     104        3          10/29/21    1000.00
#     105        4          11/2/21     10000.00
#
# The third table `CheckInfo`, has information on checks written:
#
#     account    checkNum    cDate       amount
#     -------    --------    --------    ---------
#     101        924         10/23/21    125.00
#     101        925         10/24/21    23.98

# %% [markdown]
# #### Elements of Table Declarations
#
# The list of elements in a table declaration are at minimum an attribute (column) and its type.
#
# The most common types are:
# * INT or INTEGER
# * REAL or FLOAT
# * CHAR(*n*)   = fixed-length string of *n* characters
# * VARCHAR(*n*) = variable-length string of up to *n* characters

# %% [markdown]
# #### SQL Values
#
# * Integer and  reals are represented as you would expect.
# * Strings are too, except they require single quotes.
#     & Two single quotes  = real quote, e.g., `‘Ed’’s Bookstore’`
# * Any value can be NULL!
#
# Dates and Times
# * DATE and TIME are types in SQL.
# * The form of a date value is:
#     DATE ‘yyyy-mm-dd’
#     Example: `DATE '2022-10-12'`
# * The form of a time value is:
#     TIME ‘hh:mm:ss’
#   with an optional decimal point and fractions of a second following.
#     Example:  `TIME ’15:30:02.5'`

# %% [markdown]
# #### Declaring Keys
#
# * An attribute or list of attributes may be declared PRIMARY KEY or UNIQUE
# * Either says that no two tuples of the relation may agree in all the attribute(s) on the list
# * There are a few distinctions to be mentioned later

# %% [markdown]
# ##### Declaring Single-Attribute Keys
#
# * Place PRIMARY KEY or UNIQUE after the type in the declaration of the attribute.
# * Example:
# ```mysql
# CREATE TABLE Account(
#     number CHAR(20) PRIMARY KEY,
#     custID INTEGER,
#     owner VARCHAR(30),
#     balance REAL,
#     type CHAR(10)
# );
# ```
# or
# ```mysql
# CREATE TABLE Account(
#     number CHAR(20) UNIQUE,
#     custID INTEGER,
#     owner VARCHAR(30),
#     balance REAL,
#     type CHAR(10)
# );
# ```
# or
# ```mysql
# CREATE TABLE Account(
#     number CHAR(20),
#     custID INTEGER,
#     owner VARCHAR(30),
#     balance REAL,
#     type CHAR(10),
#     PRIMARY KEY (number)
# );
# ```

# %% [markdown]
# ##### Declaring Multi-Attribute Keys
#
# * A key declaration can also be another element in the list of elements of a CREATE TABLE statement.
# * This form is essential if the key consists of more than one attribute.
#     * May be used even for one-attribute keys
# * In the `CheckInfo` table the `account` and `checkNum` are the key.
#
# ```mysql
# CREATE TABLE CheckInfo (
#     account CHAR(20),
#     checkNum INT,
#     cDate DATE,
#     amount REAL,
#     PRIMARY KEY (account, checkNum)
# );
# ```

# %% [markdown]
# #### PRIMARY KEY vs. UNIQUE
#
# 1. There can be only one PRIMARY KEY for a relation, but several UNIQUE attributes.
# 2. No attribute of a PRIMARY KEY can ever be NULL in any tuple. But attributes declared UNIQUE may have NULL’s, and there may be several tuples with NULL.

# %% [markdown]
# ### Example 2 - Create Tables

# %%
# Example 2 - Banking 
# Create a connection to the database "banking.db"
conn2 = sqlite3.connect("banking.db")

# Add the three tables for Account, Deposit and CheckInfo
conn2.executescript("""
CREATE TABLE Account (
    number INTEGER PRIMARY KEY,
    custID INTEGER,
    owner TEXT,
    balance REAL,
    type TEXT
);
""");

conn2.executescript("""
CREATE TABLE Deposit (
    accountID INTEGER,
    transID INTEGER PRIMARY KEY, 
    dDate TEXT, 
    amount REAL, 
    FOREIGN KEY (accountID)
       REFERENCES Account (number)
);
""")

conn2.executescript("""
CREATE TABLE CheckInfo (
    accountID INTEGER NOT NULL,
    checkNum INTEGER NOT NULL, 
    cDate TEXT,
    amount REAL,
    PRIMARY KEY (accountID, checkNum), 
    FOREIGN KEY (accountID)
       REFERENCES Account (number)
);
""")

# %% [markdown]
# ### Different Database Systems
#
# Below, I list the differences in syntax between database systems.  Note, I will not do this for all queries, but want to highlight the commonalities and small differences.

# %% [markdown]
# #### SQLite Syntax
#
# Let's create a table in the `analysis` database from **Example 1** above.
#
# ```mysql
# CREATE TABLE teachers (
#     id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
#     first_name TEXT,
#     last_name TEXT,
#     school TEXT,
#     hire_date TEXT,
#     salary INTEGER
# );
# ```
#
# The table `teachers`  stores 6 pieces of information:
#
# * `id` of type `integer`, that auto-increments each time you add a row to the table.
# * `first_name` is type `TEXT` a text column.
# * `last_name`, a text column.
# * `school`, a text column.
# * `hire_date`, is set to type `TEXT`, there is no date and time type in SQLite.
# * `salary` is type INTEGER

# %% [markdown]
# #### PostgreSQL Syntax
#
# Let's create a table in the `analysis` database from Example 1 above.
#
# ```mysql
# CREATE TABLE teachers (
#     id bigserial,
#     first_name varchar(50),
#     last_name varchar(50),
#     school varchar(50),
#     hire_date date,
#     salary numeric
# );
# ```
#
# The table `teachers`  stores 6 pieces of information:
#
# * `id` of type `bigserial`, that auto-increments each time you add a row to the table.
# * `first_name` is type `varchar` a text column with a maximum length specified.
# * `last_name`, a text column limited to 50 characters.
# * `school`, a text column for 50 characters
# * `hire_date`, is set to type `date`
# * `salary` is type numeric

# %%
# Example 1 - School Enrollment
# Create tables in the "analysis.db" database
conn.executescript("""
CREATE TABLE teachers (
    id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
    first_name TEXT,
    last_name TEXT,
    school TEXT,
    hire_date TEXT,
    salary INTEGER
);
""");

# %% [markdown]
# ### Insert rows into a Table
#
# Many times we will want to automatically insert a large number or rows directly from a text file or another database.  Here, we will add a few rows using an `INSERT INTO ... VALUES` statement.
#
# ```mysql
# INSERT INTO teachers (first_name, last_name, school, hire_date, salary)
# VALUES ('Janet', 'Smith', 'F.D. Roosevelt HS', '2011-10-30', 36200),
#        ('Lee', 'Reynolds', 'F.D. Roosevelt HS', '1993-05-22', 65000),
#        ('Samuel', 'Cole', 'Myers Middle School', '2005-08-01', 43500),
#        ('Samantha', 'Bush', 'Myers Middle School', '2011-10-30', 36200),
#        ('Betty', 'Diaz', 'Myers Middle School', '2005-08-30', 43500),
#        ('Kathleen', 'Roush', 'F.D. Roosevelt HS', '2010-10-22', 38500);
# ```

# %%
# Example 1 - School Enrollment
# Add rows to the teachers table 
conn.executescript("""
INSERT INTO teachers (first_name, last_name, school, hire_date, salary)
VALUES ('Janet', 'Smith', 'F.D. Roosevelt HS', '2011-10-30', 36200),
       ('Lee', 'Reynolds', 'F.D. Roosevelt HS', '1993-05-22', 65000),
       ('Samuel', 'Cole', 'Myers Middle School', '2005-08-01', 43500),
       ('Samantha', 'Bush', 'Myers Middle School', '2011-10-30', 36200),
       ('Betty', 'Diaz', 'Myers Middle School', '2005-08-30', 43500),
       ('Kathleen', 'Roush', 'F.D. Roosevelt HS', '2010-10-22', 38500);
""");

# %% [markdown]
# We can also add rows one at a time.

# %%
# Example 1 - School Enrollment
# Add a single row to the teachers table
conn.executescript("""
INSERT INTO teachers (first_name, last_name, school, hire_date, salary) 
VALUES ('Hank', 'Smith', 'Jefferson HS', '2018-01-01', 32000);
""");

# %% [markdown]
# #### Example 2 - Add Data
#
# Populate tables, `Account`, `Deposit`, `CheckInfo` and `ATMwithdraw`.  The `ATMwithdraw` has the following schema `ATMwithdraw(transID, custID, account, amount, wDate)` where `transID` is the primary key.

# %%
# Example 2 
# Add data to populate tables

conn2.executescript("""
INSERT INTO Account (number, custID, owner, balance, type)
VALUES (101, 1, 'J. Smith', 1000.00, 'checking'), 
       (102, 2, 'W.Wei', 2000.00, 'checking'),
       (103, 1, 'J. Smith', 5000.00, 'saving'), 
       (104, 3, 'M. Jones', 1000.00, 'checking'),
       (105, 4, 'H. Martin', 10000.00, 'checking');
""")

conn2.executescript("""
INSERT INTO Deposit (accountID, transID, dDate, amount)
VALUES (102, 1, '10/22/21', 500.00), 
       (102, 2, '10/29/21', 200.00), 
       (104, 3, '10/29/21', 1000.00), 
       (105, 4, '11/2/21', 10000.00);
""")

conn2.executescript("""
INSERT INTO CheckInfo (accountID, checkNum, cDate, amount)
VALUES (101, 924, '10/23/21', 125.00),
       (101, 925, '10/24/21', 23.98);
""")

conn2.executescript("""
CREATE TABLE ATMwithdraw (
    transID INTEGER NOT NULL,
    custID INTEGER, 
    accountID INTEGER,
    amount REAL,
    wDate TEXT,
    PRIMARY KEY (transID), 
    FOREIGN KEY (accountID)
       REFERENCES Account (number)
    FOREIGN KEY (custID)
       REFERENCES Account (custID)
);
""")

conn2.executescript("""
INSERT INTO ATMwithdraw (transID, custID, accountID, amount, wDate)
VALUES (1, 2, 102, 25.00, '11/01/21 09:45:00'), 
       (2, 2, 102, 150.00, '11/10/2021 13:15:00'), 
       (3, 1, 101, 40.00, '11/01/2021 10:05:00'), 
       (4, 1, 101, 40.00, '11/01/2021 10:07:00'), 
       (5, 1, 101, 200.00, '11/8/2021 14:14:00');
""")

# %% [markdown]
# # SQL Queries

# %% [markdown]
# ## Select-From-Where Statements
#
# Select-From-Where Statements are a common form of queries.
#
# ```
# SELECT  desired attributes
# FROM    one or more tables
# WHERE   condition about tuples of the tables
# ```

# %% [markdown]
# #### Inspect every row and column
#
# Let's look to ensure the table is as expected.
#
# First a `SELECT` statement to fetch every row and column in a table called `my_table`.
#
# ```mysql
# SELECT * FROM my_table;
# ```

# %% [markdown]
# ##### Example 1 - Select Query
#
# We can use our functions to run a specific on the database connection and display the results.

# %%
print_sql(conn, 'SELECT * FROM teachers;')
# Out:
# > SELECT * FROM teachers;
# (1, 'Janet', 'Smith', 'F.D. Roosevelt HS', '2011-10-30', 36200)
# (2, 'Lee', 'Reynolds', 'F.D. Roosevelt HS', '1993-05-22', 65000)
# (3, 'Samuel', 'Cole', 'Myers Middle School', '2005-08-01', 43500)
# (4, 'Samantha', 'Bush', 'Myers Middle School', '2011-10-30', 36200)
# (5, 'Betty', 'Diaz', 'Myers Middle School', '2005-08-30', 43500)
# (6, 'Kathleen', 'Roush', 'F.D. Roosevelt HS', '2010-10-22', 38500)
# (7, 'Hank', 'Smith', 'Jefferson HS', '2018-01-01', 32000)

# %%
pretty_print_sql(conn, 'SELECT * FROM teachers;')
# Out:
# > SELECT * FROM teachers;
#    id first_name last_name               school   hire_date  salary
# 0   1      Janet     Smith    F.D. Roosevelt HS  2011-10-30   36200
# 1   2        Lee  Reynolds    F.D. Roosevelt HS  1993-05-22   65000
# 2   3     Samuel      Cole  Myers Middle School  2005-08-01   43500
# 3   4   Samantha      Bush  Myers Middle School  2011-10-30   36200
# 4   5      Betty      Diaz  Myers Middle School  2005-08-30   43500
# 5   6   Kathleen     Roush    F.D. Roosevelt HS  2010-10-22   38500
# 6   7       Hank     Smith         Jefferson HS  2018-01-01   32000

# %% [markdown]
# ##### Example 2 - Select Query
#
# Here we can use the same query structure for Example 2 to access the `ATMwithdraw` table.

# %%
pretty_print_sql(conn2, 'SELECT * FROM ATMwithdraw')
# Out:
# > SELECT * FROM ATMwithdraw
#    transID  custID  accountID  amount                wDate
# 0        1       2        102    25.0    11/01/21 09:45:00
# 1        2       2        102   150.0  11/10/2021 13:15:00
# 2        3       1        101    40.0  11/01/2021 10:05:00
# 3        4       1        101    40.0  11/01/2021 10:07:00
# 4        5       1        101   200.0   11/8/2021 14:14:00

# %% [markdown]
# #### Querying a Subset of Columns
#
# With large tables, we may want to only look at a subset of information.  We can replace the `*` with a list of columns separated by columns.  For example,
#
# ```mysql
# SELECT some_column, another_column, more_columns
# FROM table_name;
# ```
#
# This will retrieve all rows from just those three columns.

# %%
print_sql(conn, 'SELECT last_name, first_name, salary FROM teachers;')
# Out:
# > SELECT last_name, first_name, salary FROM teachers;
# ('Smith', 'Janet', 36200)
# ('Reynolds', 'Lee', 65000)
# ('Cole', 'Samuel', 43500)
# ('Bush', 'Samantha', 36200)
# ('Diaz', 'Betty', 43500)
# ('Roush', 'Kathleen', 38500)
# ('Smith', 'Hank', 32000)

# %% [markdown]
# ##### Using DISTINCT to Find Unique Values
#
# In a table, it is not unusual for a column to contain rows with duplicate values.  We can use the keyword `DISTINCT` to eliminate duplicates, that is, show only unique values.

# %%
print_sql(conn, 'SELECT school FROM teachers;')
# Out:
# > SELECT school FROM teachers;
# ('F.D. Roosevelt HS',)
# ('F.D. Roosevelt HS',)
# ('Myers Middle School',)
# ('Myers Middle School',)
# ('Myers Middle School',)
# ('F.D. Roosevelt HS',)
# ('Jefferson HS',)

# %%
print_sql(conn, 'SELECT DISTINCT school FROM teachers;')
# Out:
# > SELECT DISTINCT school FROM teachers;
# ('F.D. Roosevelt HS',)
# ('Myers Middle School',)
# ('Jefferson HS',)

# %% [markdown]
# The distinct keyword also works on more than one column at a time.

# %%
print_sql(conn, 'SELECT DISTINCT school, salary FROM teachers;')
# Out:
# > SELECT DISTINCT school, salary FROM teachers;
# ('F.D. Roosevelt HS', 36200)
# ('F.D. Roosevelt HS', 65000)
# ('Myers Middle School', 43500)
# ('Myers Middle School', 36200)
# ('F.D. Roosevelt HS', 38500)
# ('Jefferson HS', 32000)

# %% [markdown]
# #### Sorting Data with ORDER BY
#
# Results of a query can be ordered using the keywords `ORDER BY`.  Note, this does not change the original table, only the query result.
#
# ```mysql
# SELECT first_name, last_name, salary
# FROM teachers
# ORDER BY salary DESC;
# ```

# %%
print_sql(conn, 
          'SELECT first_name, last_name, salary FROM teachers ORDER BY salary DESC;')
# Out:
# > SELECT first_name, last_name, salary FROM teachers ORDER BY salary DESC;
# ('Lee', 'Reynolds', 65000)
# ('Samuel', 'Cole', 43500)
# ('Betty', 'Diaz', 43500)
# ('Kathleen', 'Roush', 38500)
# ('Janet', 'Smith', 36200)
# ('Samantha', 'Bush', 36200)
# ('Hank', 'Smith', 32000)

# %% [markdown]
# We can also sort by multiple columns. For example, here we are sorting by `school` in ascending order and `hire_date` in descending order.
#
# Note, we are also making use of a string with the triple quotations, `"""` that allows us to create a multiline string.  This is nice to use when formatting SQL queries.

# %%
print_sql(conn, """
SELECT last_name, school, hire_date 
FROM teachers 
ORDER BY school ASC, hire_date DESC;
""")
# Out:
# >
# SELECT last_name, school, hire_date
# FROM teachers
# ORDER BY school ASC, hire_date DESC;
#
# ('Smith', 'F.D. Roosevelt HS', '2011-10-30')
# ('Roush', 'F.D. Roosevelt HS', '2010-10-22')
# ('Reynolds', 'F.D. Roosevelt HS', '1993-05-22')
# ('Smith', 'Jefferson HS', '2018-01-01')
# ('Bush', 'Myers Middle School', '2011-10-30')
# ('Diaz', 'Myers Middle School', '2005-08-30')
# ('Cole', 'Myers Middle School', '2005-08-01')

# %% [markdown]
# ### Filtering Rows with WHERE
#
# We may want to limit the rows returned to those that meet a certain criteria.
# Using teachers as an example, we might want to find all teachers hired before a particular year or all teachers making more than $75,000 at elementary schools.
#
# ```mysql
# SELECT last_name, school, hire_date
# FROM teachers
# WHERE school = 'Myers Middle School';
# ```

# %%
print_sql(conn, """SELECT last_name, school, hire_date 
FROM teachers 
WHERE school = 'Myers Middle School';""")
# Out:
# > SELECT last_name, school, hire_date
# FROM teachers
# WHERE school = 'Myers Middle School';
# ('Cole', 'Myers Middle School', '2005-08-01')
# ('Bush', 'Myers Middle School', '2011-10-30')
# ('Diaz', 'Myers Middle School', '2005-08-30')

# %% [markdown]
# There are a number of different comparison operators that can be used (we have `=` above).  The table below lists several.
#
# | Operator  | Function  | Example      |
# |-----------|-----------|--------------|
# | `=`       | Equal to  | `WHERE school = 'Baker Middle` |
# | `<>` or `!=` | Not equal to | `WHERE school <> 'Baker Middle` |
# | `>`       | Greater than | `WHERE salary > 20000` |
# | `<`       | Less than | `WHERE salary < 60000` |
# | `>=`      | Greater than or equal to  | `WHERE salary >= 20000` |
# | `<=`      | Less than or equal to     | `WHERE salary <= 60000` |
# | `BETWEEN` | Within a range  | `WHERE salary BETWEEN 20000 AND 40000` |
# | `IN`      | Match one of a set of values | `WHERE last_name IN ('Bush', 'Roush')` |
# | `LIKE`    | Match a pattern (case sensitive) | `WHERE first_name LIKE 'Sam%'` |
# | `NOT`     | Negates a condition | `WHERE first_name NOT ILIKE 'sam%'` |

# %%
print_sql(conn, """
SELECT first_name, last_name, school
FROM teachers
WHERE first_name = 'Janet';
""")
# Out:
# >
# SELECT first_name, last_name, school
# FROM teachers
# WHERE first_name = 'Janet';
#
# ('Janet', 'Smith', 'F.D. Roosevelt HS')

# %%
print_sql(conn, """
SELECT school
FROM teachers
WHERE school != 'F.D. Roosevelt HS';
""")
# Out:
# >
# SELECT school
# FROM teachers
# WHERE school != 'F.D. Roosevelt HS';
#
# ('Myers Middle School',)
# ('Myers Middle School',)
# ('Myers Middle School',)
# ('Jefferson HS',)

# %%
print_sql(conn, """
SELECT first_name, last_name, hire_date
FROM teachers
WHERE hire_date < '2000-01-01';
""")
# Out:
# >
# SELECT first_name, last_name, hire_date
# FROM teachers
# WHERE hire_date < '2000-01-01';
#
# ('Lee', 'Reynolds', '1993-05-22')

# %%
print_sql(conn, """
SELECT first_name, last_name, school, salary
FROM teachers
WHERE salary BETWEEN 40000 AND 65000;
""")
# Out:
# >
# SELECT first_name, last_name, school, salary
# FROM teachers
# WHERE salary BETWEEN 40000 AND 65000;
#
# ('Lee', 'Reynolds', 'F.D. Roosevelt HS', 65000)
# ('Samuel', 'Cole', 'Myers Middle School', 43500)
# ('Betty', 'Diaz', 'Myers Middle School', 43500)

# %% [markdown]
# Select tuples that match a condition from Example 2.

# %%
print_sql(conn2, """
SELECT * 
FROM ATMWithdraw 
WHERE amount < 50;
""")
# Out:
# >
# SELECT *
# FROM ATMWithdraw
# WHERE amount < 50;
#
# (1, 2, 102, 25.0, '11/01/21 09:45:00')
# (3, 1, 101, 40.0, '11/01/2021 10:05:00')
# (4, 1, 101, 40.0, '11/01/2021 10:07:00')

# %% [markdown]
# ##### Using LIKE  with WHERE
#
# When using `LIKE`, you can search for patterns in strings using two special characters:
#
# * **Percent sign %** A wildcard matching one or more characters
# * **Underscore _** A wildcard matching exactly one character
#
# For example the following patterns with find the word `baker`
#
# ```mysql
# LIKE 'b%'
# LIKE '%ak%'
# LIKE '_aker'
# LIKE 'ba_er'
# ```

# %%
print_sql(conn, """
SELECT first_name
FROM teachers
WHERE first_name LIKE 'sam%';
""")
# Out:
# >
# SELECT first_name
# FROM teachers
# WHERE first_name LIKE 'sam%';
#
# ('Samuel',)
# ('Samantha',)

# %% [markdown]
# ##### Combining operators with AND and OR
#
# Comparison operators can be combined with `AND` and `OR` with parentheses if needed.

# %%
print_sql(conn, """
SELECT *
FROM teachers
WHERE school = 'F.D. Roosevelt HS'
      AND (salary < 38000 OR salary > 40000);
""")
# Out:
# >
# SELECT *
# FROM teachers
# WHERE school = 'F.D. Roosevelt HS'
#       AND (salary < 38000 OR salary > 40000);
#
# (1, 'Janet', 'Smith', 'F.D. Roosevelt HS', '2011-10-30', 36200)
# (2, 'Lee', 'Reynolds', 'F.D. Roosevelt HS', '1993-05-22', 65000)

# %% [markdown]
# ### Connections to Relational Algebra
#
# There can be a basic syntax comparison between relational algebra operators and SQL.

# %% [markdown]
# ####  Projection
#
# The projection operator $\pi_{a,b}$ is related to `SELECT a, b`

# %%
print_sql(conn2, """
SELECT custID, amount 
FROM ATMWithdraw 
""")
# Out:
# >
# SELECT custID, amount
# FROM ATMWithdraw
#
# (2, 25.0)
# (2, 150.0)
# (1, 40.0)
# (1, 40.0)
# (1, 200.0)

# %% [markdown]
# #### Selection
#
# The selection operator $\sigma_{(d > e) \wedge (f = g)}$ is related to `WHERE d > e AND f = g`

# %%
print_sql(conn2, """
SELECT * 
FROM ATMWithdraw 
WHERE (amount > 50) AND (accountID==102)
""")
# Out:
# >
# SELECT *
# FROM ATMWithdraw
# WHERE (amount > 50) AND (accountID==102)
#
# (2, 2, 102, 150.0, '11/10/2021 13:15:00')

# %% [markdown]
# #### Renaming
#
# Renaming attributes or $\rho$ relates to `AS {or blank space}`.
#
# Here we can rename the `custID` attribute as `owner`

# %%
pretty_print_sql(conn2, """
SELECT custID AS owner, amount 
FROM ATMWithdraw 
""")
# Out:
# >
# SELECT custID AS owner, amount
# FROM ATMWithdraw
#    owner  amount
# 0      2    25.0
# 1      2   150.0
# 2      1    40.0
# 3      1    40.0
# 4      1   200.0

# %% [markdown]
# ### NULL Values
#
# Tuples in SQL relations can have NULL as a value for one or more components.  What a NULL value means depends on the context, but two common cases are:
#
# * _Missing value_:  we don't know a particular attribute's value for a row.
# * _Inapplicable_: e.g., the value of the attribute `spouse` for an unmarried person.
#
# The logic on conditions in SQL is really **3-valued logic**: TRUE, FALSE, UNKNOWN.
#
# Comparing any value (including NULL itself) with NULL yields UNKNOWN.
#
# A tuple is in a query answer if and only if the WHERE clause is TRUE (not FALSE or UNKNOWN).

# %% [markdown]
# #### Three-Valued Logic
#
# To understand how AND, OR, and NOT work in 3-valued logic, think of:
#
# * TRUE = 1, FALSE = 0, and UNKNOWN = 1/2
# * AND = MIN, OR = MAX, NOT(x) = 1 - x.
#
# For example,
#
# $$ \text{TRUE AND (FALSE OR NOT(UNKNOWN))} \\
#  = MIN(1, MAX(0, (1-1/2)) \\
#  = MIN(1, MAX(0, 1/2))  \\
#  = MIN(1, 1/2) = 1/2 $$

# %% [markdown]
# ### Importing Data
#
# Many times we might have data from a delimited file.  We can import or export this data.
#
# In SQLite, this is done at the command line with the `.import` command.  In PostgreSQL, this is done with the `COPY` command.
#
# Here we can take advantage of `pandas`, to write a DataFrame to an sql database with the `to_sql` function.

# %%
df = pd.read_csv("us_counties_2010.csv")
df.to_sql('us_counties_2010', conn, if_exists='append', index=False)
df.head()
# Out:
#              NAME STUSAB  SUMLEV  REGION  DIVISION  STATE  COUNTY    AREALAND  \
# 0  Autauga County     AL      50       3         6      1       1  1539582278
# 1  Baldwin County     AL      50       3         6      1       3  4117521611
# 2  Barbour County     AL      50       3         6      1       5  2291818968
# 3     Bibb County     AL      50       3         6      1       7  1612480789
# 4   Blount County     AL      50       3         6      1       9  1669961855
#
#      AREAWATR  POP100  ...  P0040010  P0040011  P0040012  P0040028  P0040049  \
# 0    25775735   54571  ...        22       384       363        19         2
# 1  1133190229  182265  ...       141      1244      1198        46         0
# 2    50864716   27457  ...         5       135       132         2         0
# 3     9289057   22915  ...         8       120       119         1         0
# 4    15157440   57322  ...        17       351       341        10         0
#
#    P0040065  P0040072  H0010001  H0010002  H0010003
# 0         0         0     22135     20221      1914
# 1         0         0    104061     73180     30881
# 2         0         1     11829      9820      2009
# 3         0         0      8981      7953      1028
# 4         0         0     23887     21578      2309
#
# [5 rows x 91 columns]

# %%
print_sql(conn, "SELECT NAME, STUSAB, POP100 FROM us_counties_2010 LIMIT 10;")
# Out:
# > SELECT NAME, STUSAB, POP100 FROM us_counties_2010 LIMIT 10;
# ('Autauga County', 'AL', 54571)
# ('Baldwin County', 'AL', 182265)
# ('Barbour County', 'AL', 27457)
# ('Bibb County', 'AL', 22915)
# ('Blount County', 'AL', 57322)
# ('Bullock County', 'AL', 10914)
# ('Butler County', 'AL', 20947)
# ('Calhoun County', 'AL', 118572)
# ('Chambers County', 'AL', 34215)
# ('Cherokee County', 'AL', 25989)

# %% [markdown]
# ### Math in SQL
#
# SQL can perform basic math operators.

# %% [markdown]
# ##### Addition, Subtraction, and Multiplication

# %%
print_sql(conn, 'SELECT 2 + 2;')
# Out:
# > SELECT 2 + 2;
# (4,)

# %%
pretty_print_sql(conn, 'SELECT 3 * 4;')
# Out:
# > SELECT 3 * 4;
#    3 * 4
# 0     12

# %% [markdown]
# ##### Division and Modulo

# %%
pretty_print_sql(conn, 'SELECT 11 / 6;')
# Out:
# > SELECT 11 / 6;
#    11 / 6
# 0       1

# %% [markdown]
# The result above may be unexpected.  Division on two integers returns only the integer quotient.  You can get the remainder with the modulo operator.

# %%
pretty_print_sql(conn, 'SELECT 11 % 6;')
# Out:
# > SELECT 11 % 6;
#    11 % 6
# 0       5

# %% [markdown]
# Here we can see division on floats.

# %%
pretty_print_sql(conn, 'SELECT 11.0 / 6;')
# Out:
# > SELECT 11.0 / 6;
#    11.0 / 6
# 0  1.833333

# %% [markdown]
# #### Math on Table Columns

# %% [markdown]
# We will look at the census data already imported.
#
# The census tracks the population as well as the number of people who identified with one of six race categories or a combination of two or more races.
#
# The `AS` keyword, allows use to give each column a more readable alias in the result set.

# %%
pretty_print_sql(conn, """
SELECT NAME,
       STUSAB AS "ST",
       P0010001 AS "Tot. Pop.",
       P0010003 AS "Caucasian Alone",
       P0010004 AS "African American Alone",
       P0010005 AS "Am Indian/Alaska Native Alone",
       P0010006 AS "Asian Alone",
       P0010007 AS "Native Hawaiian and Other Pacific Islander Alone",
       P0010008 AS "Some Other Race Alone",
       P0010009 AS "Two or More Races"
FROM us_counties_2010;
""")
# Out:
# >
# SELECT NAME,
#        STUSAB AS "ST",
#        P0010001 AS "Tot. Pop.",
#        P0010003 AS "Caucasian Alone",
#        P0010004 AS "African American Alone",
#        P0010005 AS "Am Indian/Alaska Native Alone",
#        P0010006 AS "Asian Alone",
#        P0010007 AS "Native Hawaiian and Other Pacific Islander Alone",
#        P0010008 AS "Some Other Race Alone",
#        P0010009 AS "Two or More Races"
# FROM us_counties_2010;
#                    NAME  ST  Tot. Pop.  Caucasian Alone  \
# 0        Autauga County  AL      54571            42855
# 1        Baldwin County  AL     182265           156153
# 2        Barbour County  AL      27457            13180
# 3           Bibb County  AL      22915            17381
# 4         Blount County  AL      57322            53068
# ...                 ...  ..        ...              ...
# 3138  Sweetwater County  WY      43806            38748
# 3139       Teton County  WY      21294            18821
# 3140       Uinta County  WY      21118            19514
# 3141    Washakie County  WY       8533             7795
# 3142      Weston County  WY       7208             6885
#
#       African American Alone  Am Indian/Alaska Native Alone  Asian Alone  \
# 0                       9643                            232          474
# 1                      17105                           1216         1348
# 2                      12875                            114          107
# 3                       5047                             64           22
# 4                        761                            307          117
# ...                      ...                            ...          ...
# 3138                     438                            423          336
# 3139                      49                            111          235
# 3140                      55                            168           61
# 3141                      22                             93           48
# 3142                      21                             91           20
#
#       Native Hawaiian and Other Pacific Islander Alone  Some Other Race Alone  \
# 0                                                   32                    466
# 1                                                   89                   3631
# 2                                                   29                    894
# 3                                                   13                    185
# 4                                                   38                   2347
# ...                                                ...                    ...
# 3138                                                42                   2799
# 3139                                                15                   1715
# 3140                                                36                    860
# 3141                                                 1                    373
# 3142                                                 3                     67
#
#       Two or More Races
# 0                   869
# 1                  2723
# 2                   258
# 3                   203
# 4                   684
# ...                 ...
# 3138               1020
# 3139                348
# 3140                424
# 3141                201
# 3142                121
#
# [3143 rows x 10 columns]

# %% [markdown]
# Now, we can do a simple calculation of adding to columns together.

# %%
pretty_print_sql(conn, """
SELECT NAME,
       STUSAB AS "ST",
       P0010003 AS "Caucasian Alone",
       P0010004 AS "Afr. Amer. Alone",
       P0010003 + P0010004 AS "Total Causacian and Afr. Amer."
FROM us_counties_2010;
""")
# Out:
# >
# SELECT NAME,
#        STUSAB AS "ST",
#        P0010003 AS "Caucasian Alone",
#        P0010004 AS "Afr. Amer. Alone",
#        P0010003 + P0010004 AS "Total Causacian and Afr. Amer."
# FROM us_counties_2010;
#                    NAME  ST  Caucasian Alone  Afr. Amer. Alone  \
# 0        Autauga County  AL            42855              9643
# 1        Baldwin County  AL           156153             17105
# 2        Barbour County  AL            13180             12875
# 3           Bibb County  AL            17381              5047
# 4         Blount County  AL            53068               761
# ...                 ...  ..              ...               ...
# 3138  Sweetwater County  WY            38748               438
# 3139       Teton County  WY            18821                49
# 3140       Uinta County  WY            19514                55
# 3141    Washakie County  WY             7795                22
# 3142      Weston County  WY             6885                21
#
#       Total Causacian and Afr. Amer.
# 0                              52498
# 1                             173258
# 2                              26055
# 3                              22428
# 4                              53829
# ...                              ...
# 3138                           39186
# 3139                           18870
# 3140                           19569
# 3141                            7817
# 3142                            6906
#
# [3143 rows x 5 columns]

# %% [markdown]
# We can use this to check the data.  The six race "alone" columns plus the "two or more races" column should add up to be the total.

# %%
print_sql(conn, """
SELECT NAME,
       STUSAB AS "ST",
       P0010001 AS "Total",
       P0010003 + P0010004 + P0010005 + P0010006 + P0010007
              + P0010008 + P0010009 AS "All Races",
       (P0010003 + P0010004 + P0010005 + P0010006 + P0010007
              + P0010008 + P0010009) - P0010001 AS "Difference"
FROM us_counties_2010
ORDER BY "Difference" DESC;
""")
# Out:
# >
# SELECT NAME,
#        STUSAB AS "ST",
#        P0010001 AS "Total",
#        P0010003 + P0010004 + P0010005 + P0010006 + P0010007
#               + P0010008 + P0010009 AS "All Races",
#        (P0010003 + P0010004 + P0010005 + P0010006 + P0010007
#               + P0010008 + P0010009) - P0010001 AS "Difference"
# FROM us_counties_2010
# ORDER BY "Difference" DESC;
#
# ('Autauga County', 'AL', 54571, 54571, 0)
# ('Baldwin County', 'AL', 182265, 182265, 0)
# ('Barbour County', 'AL', 27457, 27457, 0)
# ('Bibb County', 'AL', 22915, 22915, 0)
# ('Blount County', 'AL', 57322, 57322, 0)
# ('Bullock County', 'AL', 10914, 10914, 0)
# ('Butler County', 'AL', 20947, 20947, 0)
# ('Calhoun County', 'AL', 118572, 118572, 0)
# ('Chambers County', 'AL', 34215, 34215, 0)
# ('Cherokee County', 'AL', 25989, 25989, 0)
# ('Chilton County', 'AL', 43643, 43643, 0)
# ('Choctaw County', 'AL', 13859, 13859, 0)
# ('Clarke County', 'AL', 25833, 25833, 0)
# ('Clay County', 'AL', 13932, 13932, 0)
# ('Cleburne County', 'AL', 14972, 14972, 0)
# ('Coffee County', 'AL', 49948, 49948, 0)
# ('Colbert County', 'AL', 54428, 54428, 0)
# ('Conecuh County', 'AL', 13228, 13228, 0)
# ('Coosa County', 'AL', 11539, 11539, 0)
# ('Covington County', 'AL', 37765, 37765, 0)
# ('Crenshaw County', 'AL', 13906, 13906, 0)
# ('Cullman County', 'AL', 80406, 80406, 0)
# ('Dale County', 'AL', 50251, 50251, 0)
# ('Dallas County', 'AL', 43820, 43820, 0)
# ('DeKalb County', 'AL', 71109, 71109, 0)
# ('Elmore County', 'AL', 79303, 79303, 0)
# ('Escambia County', 'AL', 38319, 38319, 0)
# ('Etowah County', 'AL', 104430, 104430, 0)
# ('Fayette County', 'AL', 17241, 17241, 0)
# ('Franklin County', 'AL', 31704, 31704, 0)
# ('Geneva County', 'AL', 26790, 26790, 0)
# ('Greene County', 'AL', 9045, 9045, 0)
# ('Hale County', 'AL', 15760, 15760, 0)
# ('Henry County', 'AL', 17302, 17302, 0)
# ('Houston County', 'AL', 101547, 101547, 0)
# ('Jackson County', 'AL', 53227, 53227, 0)
# ('Jefferson County', 'AL', 658466, 658466, 0)
# ('Lamar County', 'AL', 14564, 14564, 0)
# ('Lauderdale County', 'AL', 92709, 92709, 0)
# ('Lawrence County', 'AL', 34339, 34339, 0)
# ('Lee County', 'AL', 140247, 140247, 0)
# ('Limestone County', 'AL', 82782, 82782, 0)
# ('Lowndes County', 'AL', 11299, 11299, 0)
# ('Macon County', 'AL', 21452, 21452, 0)
# ('Madison County', 'AL', 334811, 334811, 0)
# ('Marengo County', 'AL', 21027, 21027, 0)
# ('Marion County', 'AL', 30776, 30776, 0)
# ('Marshall County', 'AL', 93019, 93019, 0)
# ('Mobile County', 'AL', 412992, 412992, 0)
# ('Monroe County', 'AL', 23068, 23068, 0)
# ('Montgomery County', 'AL', 229363, 229363, 0)
# ('Morgan County', 'AL', 119490, 119490, 0)
# ('Perry County', 'AL', 10591, 10591, 0)
# ('Pickens County', 'AL', 19746, 19746, 0)
# ('Pike County', 'AL', 32899, 32899, 0)
# ('Randolph County', 'AL', 22913, 22913, 0)
# ('Russell County', 'AL', 52947, 52947, 0)
# ('St. Clair County', 'AL', 83593, 83593, 0)
# ('Shelby County', 'AL', 195085, 195085, 0)
# ('Sumter County', 'AL', 13763, 13763, 0)
# ('Talladega County', 'AL', 82291, 82291, 0)
# ('Tallapoosa County', 'AL', 41616, 41616, 0)
# ('Tuscaloosa County', 'AL', 194656, 194656, 0)
# ('Walker County', 'AL', 67023, 67023, 0)
# ('Washington County', 'AL', 17581, 17581, 0)
# ('Wilcox County', 'AL', 11670, 11670, 0)
# ('Winston County', 'AL', 24484, 24484, 0)
# ('Aleutians East Borough', 'AK', 3141, 3141, 0)
# ('Aleutians West Census Area', 'AK', 5561, 5561, 0)
# ('Anchorage Municipality', 'AK', 291826, 291826, 0)
# ('Bethel Census Area', 'AK', 17013, 17013, 0)
# ('Bristol Bay Borough', 'AK', 997, 997, 0)
# ('Denali Borough', 'AK', 1826, 1826, 0)
# ('Dillingham Census Area', 'AK', 4847, 4847, 0)
# ('Fairbanks North Star Borough', 'AK', 97581, 97581, 0)
# ('Haines Borough', 'AK', 2508, 2508, 0)
# ('Hoonah-Angoon Census Area', 'AK', 2150, 2150, 0)
# ('Juneau City and Borough', 'AK', 31275, 31275, 0)
# ('Kenai Peninsula Borough', 'AK', 55400, 55400, 0)
# ('Ketchikan Gateway Borough', 'AK', 13477, 13477, 0)
# ('Kodiak Island Borough', 'AK', 13592, 13592, 0)
# ('Lake and Peninsula Borough', 'AK', 1631, 1631, 0)
# ('Matanuska-Susitna Borough', 'AK', 88995, 88995, 0)
# ('Nome Census Area', 'AK', 9492, 9492, 0)
# ('North Slope Borough', 'AK', 9430, 9430, 0)
# ('Northwest Arctic Borough', 'AK', 7523, 7523, 0)
# ('Petersburg Census Area', 'AK', 3815, 3815, 0)
# ('Prince of Wales-Hyder Census Area', 'AK', 5559, 5559, 0)
# ('Sitka City and Borough', 'AK', 8881, 8881, 0)
# ('Skagway Municipality', 'AK', 968, 968, 0)
# ('Southeast Fairbanks Census Area', 'AK', 7029, 7029, 0)
# ('Valdez-Cordova Census Area', 'AK', 9636, 9636, 0)
# ('Wade Hampton Census Area', 'AK', 7459, 7459, 0)
# ('Wrangell City and Borough', 'AK', 2369, 2369, 0)
# ('Yakutat City and Borough', 'AK', 662, 662, 0)
# ('Yukon-Koyukuk Census Area', 'AK', 5588, 5588, 0)
# ('Apache County', 'AZ', 71518, 71518, 0)
# ('Cochise County', 'AZ', 131346, 131346, 0)
# ('Coconino County', 'AZ', 134421, 134421, 0)
# ('Gila County', 'AZ', 53597, 53597, 0)
# ('Graham County', 'AZ', 37220, 37220, 0)
# ('Greenlee County', 'AZ', 8437, 8437, 0)
# ('La Paz County', 'AZ', 20489, 20489, 0)
# ('Maricopa County', 'AZ', 3817117, 3817117, 0)
# ('Mohave County', 'AZ', 200186, 200186, 0)
# ('Navajo County', 'AZ', 107449, 107449, 0)
# ('Pima County', 'AZ', 980263, 980263, 0)
# ('Pinal County', 'AZ', 375770, 375770, 0)
# ('Santa Cruz County', 'AZ', 47420, 47420, 0)
# ('Yavapai County', 'AZ', 211033, 211033, 0)
# ('Yuma County', 'AZ', 195751, 195751, 0)
# ('Arkansas County', 'AR', 19019, 19019, 0)
# ('Ashley County', 'AR', 21853, 21853, 0)
# ('Baxter County', 'AR', 41513, 41513, 0)
# ('Benton County', 'AR', 221339, 221339, 0)
# ('Boone County', 'AR', 36903, 36903, 0)
# ('Bradley County', 'AR', 11508, 11508, 0)
# ('Calhoun County', 'AR', 5368, 5368, 0)
# ('Carroll County', 'AR', 27446, 27446, 0)
# ('Chicot County', 'AR', 11800, 11800, 0)
# ('Clark County', 'AR', 22995, 22995, 0)
# ('Clay County', 'AR', 16083, 16083, 0)
# ('Cleburne County', 'AR', 25970, 25970, 0)
# ('Cleveland County', 'AR', 8689, 8689, 0)
# ('Columbia County', 'AR', 24552, 24552, 0)
# ('Conway County', 'AR', 21273, 21273, 0)
# ('Craighead County', 'AR', 96443, 96443, 0)
# ('Crawford County', 'AR', 61948, 61948, 0)
# ('Crittenden County', 'AR', 50902, 50902, 0)
# ('Cross County', 'AR', 17870, 17870, 0)
# ('Dallas County', 'AR', 8116, 8116, 0)
# ('Desha County', 'AR', 13008, 13008, 0)
# ('Drew County', 'AR', 18509, 18509, 0)
# ('Faulkner County', 'AR', 113237, 113237, 0)
# ('Franklin County', 'AR', 18125, 18125, 0)
# ('Fulton County', 'AR', 12245, 12245, 0)
# ('Garland County', 'AR', 96024, 96024, 0)
# ('Grant County', 'AR', 17853, 17853, 0)
# ('Greene County', 'AR', 42090, 42090, 0)
# ('Hempstead County', 'AR', 22609, 22609, 0)
# ('Hot Spring County', 'AR', 32923, 32923, 0)
# ('Howard County', 'AR', 13789, 13789, 0)
# ('Independence County', 'AR', 36647, 36647, 0)
# ('Izard County', 'AR', 13696, 13696, 0)
# ('Jackson County', 'AR', 17997, 17997, 0)
# ('Jefferson County', 'AR', 77435, 77435, 0)
# ('Johnson County', 'AR', 25540, 25540, 0)
# ('Lafayette County', 'AR', 7645, 7645, 0)
# ('Lawrence County', 'AR', 17415, 17415, 0)
# ('Lee County', 'AR', 10424, 10424, 0)
# ('Lincoln County', 'AR', 14134, 14134, 0)
# ('Little River County', 'AR', 13171, 13171, 0)
# ('Logan County', 'AR', 22353, 22353, 0)
# ('Lonoke County', 'AR', 68356, 68356, 0)
# ('Madison County', 'AR', 15717, 15717, 0)
# ('Marion County', 'AR', 16653, 16653, 0)
# ('Miller County', 'AR', 43462, 43462, 0)
# ('Mississippi County', 'AR', 46480, 46480, 0)
# ('Monroe County', 'AR', 8149, 8149, 0)
# ('Montgomery County', 'AR', 9487, 9487, 0)
# ('Nevada County', 'AR', 8997, 8997, 0)
# ('Newton County', 'AR', 8330, 8330, 0)
# ('Ouachita County', 'AR', 26120, 26120, 0)
# ('Perry County', 'AR', 10445, 10445, 0)
# ('Phillips County', 'AR', 21757, 21757, 0)
# ('Pike County', 'AR', 11291, 11291, 0)
# ('Poinsett County', 'AR', 24583, 24583, 0)
# ('Polk County', 'AR', 20662, 20662, 0)
# ('Pope County', 'AR', 61754, 61754, 0)
# ('Prairie County', 'AR', 8715, 8715, 0)
# ('Pulaski County', 'AR', 382748, 382748, 0)
# ('Randolph County', 'AR', 17969, 17969, 0)
# ('St. Francis County', 'AR', 28258, 28258, 0)
# ('Saline County', 'AR', 107118, 107118, 0)
# ('Scott County', 'AR', 11233, 11233, 0)
# ('Searcy County', 'AR', 8195, 8195, 0)
# ('Sebastian County', 'AR', 125744, 125744, 0)
# ('Sevier County', 'AR', 17058, 17058, 0)
# ('Sharp County', 'AR', 17264, 17264, 0)
# ('Stone County', 'AR', 12394, 12394, 0)
# ('Union County', 'AR', 41639, 41639, 0)
# ('Van Buren County', 'AR', 17295, 17295, 0)
# ('Washington County', 'AR', 203065, 203065, 0)
# ('White County', 'AR', 77076, 77076, 0)
# ('Woodruff County', 'AR', 7260, 7260, 0)
# ('Yell County', 'AR', 22185, 22185, 0)
# ('Alameda County', 'CA', 1510271, 1510271, 0)
# ('Alpine County', 'CA', 1175, 1175, 0)
# ('Amador County', 'CA', 38091, 38091, 0)
# ('Butte County', 'CA', 220000, 220000, 0)
# ('Calaveras County', 'CA', 45578, 45578, 0)
# ('Colusa County', 'CA', 21419, 21419, 0)
# ('Contra Costa County', 'CA', 1049025, 1049025, 0)
# ('Del Norte County', 'CA', 28610, 28610, 0)
# ('El Dorado County', 'CA', 181058, 181058, 0)
# ('Fresno County', 'CA', 930450, 930450, 0)
# ('Glenn County', 'CA', 28122, 28122, 0)
# ('Humboldt County', 'CA', 134623, 134623, 0)
# ('Imperial County', 'CA', 174528, 174528, 0)
# ('Inyo County', 'CA', 18546, 18546, 0)
# ('Kern County', 'CA', 839631, 839631, 0)
# ('Kings County', 'CA', 152982, 152982, 0)
# ('Lake County', 'CA', 64665, 64665, 0)
# ('Lassen County', 'CA', 34895, 34895, 0)
# ('Los Angeles County', 'CA', 9818605, 9818605, 0)
# ('Madera County', 'CA', 150865, 150865, 0)
# ('Marin County', 'CA', 252409, 252409, 0)
# ('Mariposa County', 'CA', 18251, 18251, 0)
# ('Mendocino County', 'CA', 87841, 87841, 0)
# ('Merced County', 'CA', 255793, 255793, 0)
# ('Modoc County', 'CA', 9686, 9686, 0)
# ('Mono County', 'CA', 14202, 14202, 0)
# ('Monterey County', 'CA', 415057, 415057, 0)
# ('Napa County', 'CA', 136484, 136484, 0)
# ('Nevada County', 'CA', 98764, 98764, 0)
# ('Orange County', 'CA', 3010232, 3010232, 0)
# ('Placer County', 'CA', 348432, 348432, 0)
# ('Plumas County', 'CA', 20007, 20007, 0)
# ('Riverside County', 'CA', 2189641, 2189641, 0)
# ('Sacramento County', 'CA', 1418788, 1418788, 0)
# ('San Benito County', 'CA', 55269, 55269, 0)
# ('San Bernardino County', 'CA', 2035210, 2035210, 0)
# ('San Diego County', 'CA', 3095313, 3095313, 0)
# ('San Francisco County', 'CA', 805235, 805235, 0)
# ('San Joaquin County', 'CA', 685306, 685306, 0)
# ('San Luis Obispo County', 'CA', 269637, 269637, 0)
# ('San Mateo County', 'CA', 718451, 718451, 0)
# ('Santa Barbara County', 'CA', 423895, 423895, 0)
# ('Santa Clara County', 'CA', 1781642, 1781642, 0)
# ('Santa Cruz County', 'CA', 262382, 262382, 0)
# ('Shasta County', 'CA', 177223, 177223, 0)
# ('Sierra County', 'CA', 3240, 3240, 0)
# ('Siskiyou County', 'CA', 44900, 44900, 0)
# ('Solano County', 'CA', 413344, 413344, 0)
# ('Sonoma County', 'CA', 483878, 483878, 0)
# ('Stanislaus County', 'CA', 514453, 514453, 0)
# ('Sutter County', 'CA', 94737, 94737, 0)
# ('Tehama County', 'CA', 63463, 63463, 0)
# ('Trinity County', 'CA', 13786, 13786, 0)
# ('Tulare County', 'CA', 442179, 442179, 0)
# ('Tuolumne County', 'CA', 55365, 55365, 0)
# ('Ventura County', 'CA', 823318, 823318, 0)
# ('Yolo County', 'CA', 200849, 200849, 0)
# ('Yuba County', 'CA', 72155, 72155, 0)
# ('Adams County', 'CO', 441603, 441603, 0)
# ('Alamosa County', 'CO', 15445, 15445, 0)
# ('Arapahoe County', 'CO', 572003, 572003, 0)
# ('Archuleta County', 'CO', 12084, 12084, 0)
# ('Baca County', 'CO', 3788, 3788, 0)
# ('Bent County', 'CO', 6499, 6499, 0)
# ('Boulder County', 'CO', 294567, 294567, 0)
# ('Broomfield County', 'CO', 55889, 55889, 0)
# ('Chaffee County', 'CO', 17809, 17809, 0)
# ('Cheyenne County', 'CO', 1836, 1836, 0)
# ('Clear Creek County', 'CO', 9088, 9088, 0)
# ('Conejos County', 'CO', 8256, 8256, 0)
# ('Costilla County', 'CO', 3524, 3524, 0)
# ('Crowley County', 'CO', 5823, 5823, 0)
# ('Custer County', 'CO', 4255, 4255, 0)
# ('Delta County', 'CO', 30952, 30952, 0)
# ('Denver County', 'CO', 600158, 600158, 0)
# ('Dolores County', 'CO', 2064, 2064, 0)
# ('Douglas County', 'CO', 285465, 285465, 0)
# ('Eagle County', 'CO', 52197, 52197, 0)
# ('Elbert County', 'CO', 23086, 23086, 0)
# ('El Paso County', 'CO', 622263, 622263, 0)
# ('Fremont County', 'CO', 46824, 46824, 0)
# ('Garfield County', 'CO', 56389, 56389, 0)
# ('Gilpin County', 'CO', 5441, 5441, 0)
# ('Grand County', 'CO', 14843, 14843, 0)
# ('Gunnison County', 'CO', 15324, 15324, 0)
# ('Hinsdale County', 'CO', 843, 843, 0)
# ('Huerfano County', 'CO', 6711, 6711, 0)
# ('Jackson County', 'CO', 1394, 1394, 0)
# ('Jefferson County', 'CO', 534543, 534543, 0)
# ('Kiowa County', 'CO', 1398, 1398, 0)
# ('Kit Carson County', 'CO', 8270, 8270, 0)
# ('Lake County', 'CO', 7310, 7310, 0)
# ('La Plata County', 'CO', 51334, 51334, 0)
# ('Larimer County', 'CO', 299630, 299630, 0)
# ('Las Animas County', 'CO', 15507, 15507, 0)
# ('Lincoln County', 'CO', 5467, 5467, 0)
# ('Logan County', 'CO', 22709, 22709, 0)
# ('Mesa County', 'CO', 146723, 146723, 0)
# ('Mineral County', 'CO', 712, 712, 0)
# ('Moffat County', 'CO', 13795, 13795, 0)
# ('Montezuma County', 'CO', 25535, 25535, 0)
# ('Montrose County', 'CO', 41276, 41276, 0)
# ('Morgan County', 'CO', 28159, 28159, 0)
# ('Otero County', 'CO', 18831, 18831, 0)
# ('Ouray County', 'CO', 4436, 4436, 0)
# ('Park County', 'CO', 16206, 16206, 0)
# ('Phillips County', 'CO', 4442, 4442, 0)
# ('Pitkin County', 'CO', 17148, 17148, 0)
# ('Prowers County', 'CO', 12551, 12551, 0)
# ('Pueblo County', 'CO', 159063, 159063, 0)
# ('Rio Blanco County', 'CO', 6666, 6666, 0)
# ('Rio Grande County', 'CO', 11982, 11982, 0)
# ('Routt County', 'CO', 23509, 23509, 0)
# ('Saguache County', 'CO', 6108, 6108, 0)
# ('San Juan County', 'CO', 699, 699, 0)
# ('San Miguel County', 'CO', 7359, 7359, 0)
# ('Sedgwick County', 'CO', 2379, 2379, 0)
# ('Summit County', 'CO', 27994, 27994, 0)
# ('Teller County', 'CO', 23350, 23350, 0)
# ('Washington County', 'CO', 4814, 4814, 0)
# ('Weld County', 'CO', 252825, 252825, 0)
# ('Yuma County', 'CO', 10043, 10043, 0)
# ('Fairfield County', 'CT', 916829, 916829, 0)
# ('Hartford County', 'CT', 894014, 894014, 0)
# ('Litchfield County', 'CT', 189927, 189927, 0)
# ('Middlesex County', 'CT', 165676, 165676, 0)
# ('New Haven County', 'CT', 862477, 862477, 0)
# ('New London County', 'CT', 274055, 274055, 0)
# ('Tolland County', 'CT', 152691, 152691, 0)
# ('Windham County', 'CT', 118428, 118428, 0)
# ('Kent County', 'DE', 162310, 162310, 0)
# ('New Castle County', 'DE', 538479, 538479, 0)
# ('Sussex County', 'DE', 197145, 197145, 0)
# ('District of Columbia', 'DC', 601723, 601723, 0)
# ('Alachua County', 'FL', 247336, 247336, 0)
# ('Baker County', 'FL', 27115, 27115, 0)
# ('Bay County', 'FL', 168852, 168852, 0)
# ('Bradford County', 'FL', 28520, 28520, 0)
# ('Brevard County', 'FL', 543376, 543376, 0)
# ('Broward County', 'FL', 1748066, 1748066, 0)
# ('Calhoun County', 'FL', 14625, 14625, 0)
# ('Charlotte County', 'FL', 159978, 159978, 0)
# ('Citrus County', 'FL', 141236, 141236, 0)
# ('Clay County', 'FL', 190865, 190865, 0)
# ('Collier County', 'FL', 321520, 321520, 0)
# ('Columbia County', 'FL', 67531, 67531, 0)
# ('DeSoto County', 'FL', 34862, 34862, 0)
# ('Dixie County', 'FL', 16422, 16422, 0)
# ('Duval County', 'FL', 864263, 864263, 0)
# ('Escambia County', 'FL', 297619, 297619, 0)
# ('Flagler County', 'FL', 95696, 95696, 0)
# ('Franklin County', 'FL', 11549, 11549, 0)
# ('Gadsden County', 'FL', 46389, 46389, 0)
# ('Gilchrist County', 'FL', 16939, 16939, 0)
# ('Glades County', 'FL', 12884, 12884, 0)
# ('Gulf County', 'FL', 15863, 15863, 0)
# ('Hamilton County', 'FL', 14799, 14799, 0)
# ('Hardee County', 'FL', 27731, 27731, 0)
# ('Hendry County', 'FL', 39140, 39140, 0)
# ('Hernando County', 'FL', 172778, 172778, 0)
# ('Highlands County', 'FL', 98786, 98786, 0)
# ('Hillsborough County', 'FL', 1229226, 1229226, 0)
# ('Holmes County', 'FL', 19927, 19927, 0)
# ('Indian River County', 'FL', 138028, 138028, 0)
# ('Jackson County', 'FL', 49746, 49746, 0)
# ('Jefferson County', 'FL', 14761, 14761, 0)
# ('Lafayette County', 'FL', 8870, 8870, 0)
# ('Lake County', 'FL', 297052, 297052, 0)
# ('Lee County', 'FL', 618754, 618754, 0)
# ('Leon County', 'FL', 275487, 275487, 0)
# ('Levy County', 'FL', 40801, 40801, 0)
# ('Liberty County', 'FL', 8365, 8365, 0)
# ('Madison County', 'FL', 19224, 19224, 0)
# ('Manatee County', 'FL', 322833, 322833, 0)
# ('Marion County', 'FL', 331298, 331298, 0)
# ('Martin County', 'FL', 146318, 146318, 0)
# ('Miami-Dade County', 'FL', 2496435, 2496435, 0)
# ('Monroe County', 'FL', 73090, 73090, 0)
# ('Nassau County', 'FL', 73314, 73314, 0)
# ('Okaloosa County', 'FL', 180822, 180822, 0)
# ('Okeechobee County', 'FL', 39996, 39996, 0)
# ('Orange County', 'FL', 1145956, 1145956, 0)
# ('Osceola County', 'FL', 268685, 268685, 0)
# ('Palm Beach County', 'FL', 1320134, 1320134, 0)
# ('Pasco County', 'FL', 464697, 464697, 0)
# ('Pinellas County', 'FL', 916542, 916542, 0)
# ('Polk County', 'FL', 602095, 602095, 0)
# ('Putnam County', 'FL', 74364, 74364, 0)
# ('St. Johns County', 'FL', 190039, 190039, 0)
# ('St. Lucie County', 'FL', 277789, 277789, 0)
# ('Santa Rosa County', 'FL', 151372, 151372, 0)
# ('Sarasota County', 'FL', 379448, 379448, 0)
# ('Seminole County', 'FL', 422718, 422718, 0)
# ('Sumter County', 'FL', 93420, 93420, 0)
# ('Suwannee County', 'FL', 41551, 41551, 0)
# ('Taylor County', 'FL', 22570, 22570, 0)
# ('Union County', 'FL', 15535, 15535, 0)
# ('Volusia County', 'FL', 494593, 494593, 0)
# ('Wakulla County', 'FL', 30776, 30776, 0)
# ('Walton County', 'FL', 55043, 55043, 0)
# ('Washington County', 'FL', 24896, 24896, 0)
# ('Appling County', 'GA', 18236, 18236, 0)
# ('Atkinson County', 'GA', 8375, 8375, 0)
# ('Bacon County', 'GA', 11096, 11096, 0)
# ('Baker County', 'GA', 3451, 3451, 0)
# ('Baldwin County', 'GA', 45720, 45720, 0)
# ('Banks County', 'GA', 18395, 18395, 0)
# ('Barrow County', 'GA', 69367, 69367, 0)
# ('Bartow County', 'GA', 100157, 100157, 0)
# ('Ben Hill County', 'GA', 17634, 17634, 0)
# ('Berrien County', 'GA', 19286, 19286, 0)
# ('Bibb County', 'GA', 155547, 155547, 0)
# ('Bleckley County', 'GA', 13063, 13063, 0)
# ('Brantley County', 'GA', 18411, 18411, 0)
# ('Brooks County', 'GA', 16243, 16243, 0)
# ('Bryan County', 'GA', 30233, 30233, 0)
# ('Bulloch County', 'GA', 70217, 70217, 0)
# ('Burke County', 'GA', 23316, 23316, 0)
# ('Butts County', 'GA', 23655, 23655, 0)
# ('Calhoun County', 'GA', 6694, 6694, 0)
# ('Camden County', 'GA', 50513, 50513, 0)
# ('Candler County', 'GA', 10998, 10998, 0)
# ('Carroll County', 'GA', 110527, 110527, 0)
# ('Catoosa County', 'GA', 63942, 63942, 0)
# ('Charlton County', 'GA', 12171, 12171, 0)
# ('Chatham County', 'GA', 265128, 265128, 0)
# ('Chattahoochee County', 'GA', 11267, 11267, 0)
# ('Chattooga County', 'GA', 26015, 26015, 0)
# ('Cherokee County', 'GA', 214346, 214346, 0)
# ('Clarke County', 'GA', 116714, 116714, 0)
# ('Clay County', 'GA', 3183, 3183, 0)
# ('Clayton County', 'GA', 259424, 259424, 0)
# ('Clinch County', 'GA', 6798, 6798, 0)
# ('Cobb County', 'GA', 688078, 688078, 0)
# ('Coffee County', 'GA', 42356, 42356, 0)
# ('Colquitt County', 'GA', 45498, 45498, 0)
# ('Columbia County', 'GA', 124053, 124053, 0)
# ('Cook County', 'GA', 17212, 17212, 0)
# ('Coweta County', 'GA', 127317, 127317, 0)
# ('Crawford County', 'GA', 12630, 12630, 0)
# ('Crisp County', 'GA', 23439, 23439, 0)
# ('Dade County', 'GA', 16633, 16633, 0)
# ('Dawson County', 'GA', 22330, 22330, 0)
# ('Decatur County', 'GA', 27842, 27842, 0)
# ('DeKalb County', 'GA', 691893, 691893, 0)
# ('Dodge County', 'GA', 21796, 21796, 0)
# ('Dooly County', 'GA', 14918, 14918, 0)
# ('Dougherty County', 'GA', 94565, 94565, 0)
# ('Douglas County', 'GA', 132403, 132403, 0)
# ('Early County', 'GA', 11008, 11008, 0)
# ('Echols County', 'GA', 4034, 4034, 0)
# ('Effingham County', 'GA', 52250, 52250, 0)
# ('Elbert County', 'GA', 20166, 20166, 0)
# ('Emanuel County', 'GA', 22598, 22598, 0)
# ('Evans County', 'GA', 11000, 11000, 0)
# ('Fannin County', 'GA', 23682, 23682, 0)
# ('Fayette County', 'GA', 106567, 106567, 0)
# ('Floyd County', 'GA', 96317, 96317, 0)
# ('Forsyth County', 'GA', 175511, 175511, 0)
# ('Franklin County', 'GA', 22084, 22084, 0)
# ('Fulton County', 'GA', 920581, 920581, 0)
# ('Gilmer County', 'GA', 28292, 28292, 0)
# ('Glascock County', 'GA', 3082, 3082, 0)
# ('Glynn County', 'GA', 79626, 79626, 0)
# ('Gordon County', 'GA', 55186, 55186, 0)
# ('Grady County', 'GA', 25011, 25011, 0)
# ('Greene County', 'GA', 15994, 15994, 0)
# ('Gwinnett County', 'GA', 805321, 805321, 0)
# ('Habersham County', 'GA', 43041, 43041, 0)
# ('Hall County', 'GA', 179684, 179684, 0)
# ('Hancock County', 'GA', 9429, 9429, 0)
# ('Haralson County', 'GA', 28780, 28780, 0)
# ('Harris County', 'GA', 32024, 32024, 0)
# ('Hart County', 'GA', 25213, 25213, 0)
# ('Heard County', 'GA', 11834, 11834, 0)
# ('Henry County', 'GA', 203922, 203922, 0)
# ('Houston County', 'GA', 139900, 139900, 0)
# ('Irwin County', 'GA', 9538, 9538, 0)
# ('Jackson County', 'GA', 60485, 60485, 0)
# ('Jasper County', 'GA', 13900, 13900, 0)
# ('Jeff Davis County', 'GA', 15068, 15068, 0)
# ('Jefferson County', 'GA', 16930, 16930, 0)
# ('Jenkins County', 'GA', 8340, 8340, 0)
# ('Johnson County', 'GA', 9980, 9980, 0)
# ('Jones County', 'GA', 28669, 28669, 0)
# ('Lamar County', 'GA', 18317, 18317, 0)
# ('Lanier County', 'GA', 10078, 10078, 0)
# ('Laurens County', 'GA', 48434, 48434, 0)
# ('Lee County', 'GA', 28298, 28298, 0)
# ('Liberty County', 'GA', 63453, 63453, 0)
# ('Lincoln County', 'GA', 7996, 7996, 0)
# ('Long County', 'GA', 14464, 14464, 0)
# ('Lowndes County', 'GA', 109233, 109233, 0)
# ('Lumpkin County', 'GA', 29966, 29966, 0)
# ('McDuffie County', 'GA', 21875, 21875, 0)
# ('McIntosh County', 'GA', 14333, 14333, 0)
# ('Macon County', 'GA', 14740, 14740, 0)
# ('Madison County', 'GA', 28120, 28120, 0)
# ('Marion County', 'GA', 8742, 8742, 0)
# ('Meriwether County', 'GA', 21992, 21992, 0)
# ('Miller County', 'GA', 6125, 6125, 0)
# ('Mitchell County', 'GA', 23498, 23498, 0)
# ('Monroe County', 'GA', 26424, 26424, 0)
# ('Montgomery County', 'GA', 9123, 9123, 0)
# ('Morgan County', 'GA', 17868, 17868, 0)
# ('Murray County', 'GA', 39628, 39628, 0)
# ('Muscogee County', 'GA', 189885, 189885, 0)
# ('Newton County', 'GA', 99958, 99958, 0)
# ('Oconee County', 'GA', 32808, 32808, 0)
# ('Oglethorpe County', 'GA', 14899, 14899, 0)
# ('Paulding County', 'GA', 142324, 142324, 0)
# ('Peach County', 'GA', 27695, 27695, 0)
# ('Pickens County', 'GA', 29431, 29431, 0)
# ('Pierce County', 'GA', 18758, 18758, 0)
# ('Pike County', 'GA', 17869, 17869, 0)
# ('Polk County', 'GA', 41475, 41475, 0)
# ('Pulaski County', 'GA', 12010, 12010, 0)
# ('Putnam County', 'GA', 21218, 21218, 0)
# ('Quitman County', 'GA', 2513, 2513, 0)
# ('Rabun County', 'GA', 16276, 16276, 0)
# ('Randolph County', 'GA', 7719, 7719, 0)
# ('Richmond County', 'GA', 200549, 200549, 0)
# ('Rockdale County', 'GA', 85215, 85215, 0)
# ('Schley County', 'GA', 5010, 5010, 0)
# ('Screven County', 'GA', 14593, 14593, 0)
# ('Seminole County', 'GA', 8729, 8729, 0)
# ('Spalding County', 'GA', 64073, 64073, 0)
# ('Stephens County', 'GA', 26175, 26175, 0)
# ('Stewart County', 'GA', 6058, 6058, 0)
# ('Sumter County', 'GA', 32819, 32819, 0)
# ('Talbot County', 'GA', 6865, 6865, 0)
# ('Taliaferro County', 'GA', 1717, 1717, 0)
# ('Tattnall County', 'GA', 25520, 25520, 0)
# ('Taylor County', 'GA', 8906, 8906, 0)
# ('Telfair County', 'GA', 16500, 16500, 0)
# ('Terrell County', 'GA', 9315, 9315, 0)
# ('Thomas County', 'GA', 44720, 44720, 0)
# ('Tift County', 'GA', 40118, 40118, 0)
# ('Toombs County', 'GA', 27223, 27223, 0)
# ('Towns County', 'GA', 10471, 10471, 0)
# ('Treutlen County', 'GA', 6885, 6885, 0)
# ('Troup County', 'GA', 67044, 67044, 0)
# ('Turner County', 'GA', 8930, 8930, 0)
# ('Twiggs County', 'GA', 9023, 9023, 0)
# ('Union County', 'GA', 21356, 21356, 0)
# ('Upson County', 'GA', 27153, 27153, 0)
# ('Walker County', 'GA', 68756, 68756, 0)
# ('Walton County', 'GA', 83768, 83768, 0)
# ('Ware County', 'GA', 36312, 36312, 0)
# ('Warren County', 'GA', 5834, 5834, 0)
# ('Washington County', 'GA', 21187, 21187, 0)
# ('Wayne County', 'GA', 30099, 30099, 0)
# ('Webster County', 'GA', 2799, 2799, 0)
# ('Wheeler County', 'GA', 7421, 7421, 0)
# ('White County', 'GA', 27144, 27144, 0)
# ('Whitfield County', 'GA', 102599, 102599, 0)
# ('Wilcox County', 'GA', 9255, 9255, 0)
# ('Wilkes County', 'GA', 10593, 10593, 0)
# ('Wilkinson County', 'GA', 9563, 9563, 0)
# ('Worth County', 'GA', 21679, 21679, 0)
# ('Hawaii County', 'HI', 185079, 185079, 0)
# ('Honolulu County', 'HI', 953207, 953207, 0)
# ('Kalawao County', 'HI', 90, 90, 0)
# ('Kauai County', 'HI', 67091, 67091, 0)
# ('Maui County', 'HI', 154834, 154834, 0)
# ('Ada County', 'ID', 392365, 392365, 0)
# ('Adams County', 'ID', 3976, 3976, 0)
# ('Bannock County', 'ID', 82839, 82839, 0)
# ('Bear Lake County', 'ID', 5986, 5986, 0)
# ('Benewah County', 'ID', 9285, 9285, 0)
# ('Bingham County', 'ID', 45607, 45607, 0)
# ('Blaine County', 'ID', 21376, 21376, 0)
# ('Boise County', 'ID', 7028, 7028, 0)
# ('Bonner County', 'ID', 40877, 40877, 0)
# ('Bonneville County', 'ID', 104234, 104234, 0)
# ('Boundary County', 'ID', 10972, 10972, 0)
# ('Butte County', 'ID', 2891, 2891, 0)
# ('Camas County', 'ID', 1117, 1117, 0)
# ('Canyon County', 'ID', 188923, 188923, 0)
# ('Caribou County', 'ID', 6963, 6963, 0)
# ('Cassia County', 'ID', 22952, 22952, 0)
# ('Clark County', 'ID', 982, 982, 0)
# ('Clearwater County', 'ID', 8761, 8761, 0)
# ('Custer County', 'ID', 4368, 4368, 0)
# ('Elmore County', 'ID', 27038, 27038, 0)
# ('Franklin County', 'ID', 12786, 12786, 0)
# ('Fremont County', 'ID', 13242, 13242, 0)
# ('Gem County', 'ID', 16719, 16719, 0)
# ('Gooding County', 'ID', 15464, 15464, 0)
# ('Idaho County', 'ID', 16267, 16267, 0)
# ('Jefferson County', 'ID', 26140, 26140, 0)
# ('Jerome County', 'ID', 22374, 22374, 0)
# ('Kootenai County', 'ID', 138494, 138494, 0)
# ('Latah County', 'ID', 37244, 37244, 0)
# ('Lemhi County', 'ID', 7936, 7936, 0)
# ('Lewis County', 'ID', 3821, 3821, 0)
# ('Lincoln County', 'ID', 5208, 5208, 0)
# ('Madison County', 'ID', 37536, 37536, 0)
# ('Minidoka County', 'ID', 20069, 20069, 0)
# ('Nez Perce County', 'ID', 39265, 39265, 0)
# ('Oneida County', 'ID', 4286, 4286, 0)
# ('Owyhee County', 'ID', 11526, 11526, 0)
# ('Payette County', 'ID', 22623, 22623, 0)
# ('Power County', 'ID', 7817, 7817, 0)
# ('Shoshone County', 'ID', 12765, 12765, 0)
# ('Teton County', 'ID', 10170, 10170, 0)
# ('Twin Falls County', 'ID', 77230, 77230, 0)
# ('Valley County', 'ID', 9862, 9862, 0)
# ('Washington County', 'ID', 10198, 10198, 0)
# ('Adams County', 'IL', 67103, 67103, 0)
# ('Alexander County', 'IL', 8238, 8238, 0)
# ('Bond County', 'IL', 17768, 17768, 0)
# ('Boone County', 'IL', 54165, 54165, 0)
# ('Brown County', 'IL', 6937, 6937, 0)
# ('Bureau County', 'IL', 34978, 34978, 0)
# ('Calhoun County', 'IL', 5089, 5089, 0)
# ('Carroll County', 'IL', 15387, 15387, 0)
# ('Cass County', 'IL', 13642, 13642, 0)
# ('Champaign County', 'IL', 201081, 201081, 0)
# ('Christian County', 'IL', 34800, 34800, 0)
# ('Clark County', 'IL', 16335, 16335, 0)
# ('Clay County', 'IL', 13815, 13815, 0)
# ('Clinton County', 'IL', 37762, 37762, 0)
# ('Coles County', 'IL', 53873, 53873, 0)
# ('Cook County', 'IL', 5194675, 5194675, 0)
# ('Crawford County', 'IL', 19817, 19817, 0)
# ('Cumberland County', 'IL', 11048, 11048, 0)
# ('DeKalb County', 'IL', 105160, 105160, 0)
# ('De Witt County', 'IL', 16561, 16561, 0)
# ('Douglas County', 'IL', 19980, 19980, 0)
# ('DuPage County', 'IL', 916924, 916924, 0)
# ('Edgar County', 'IL', 18576, 18576, 0)
# ('Edwards County', 'IL', 6721, 6721, 0)
# ('Effingham County', 'IL', 34242, 34242, 0)
# ('Fayette County', 'IL', 22140, 22140, 0)
# ('Ford County', 'IL', 14081, 14081, 0)
# ('Franklin County', 'IL', 39561, 39561, 0)
# ('Fulton County', 'IL', 37069, 37069, 0)
# ('Gallatin County', 'IL', 5589, 5589, 0)
# ('Greene County', 'IL', 13886, 13886, 0)
# ('Grundy County', 'IL', 50063, 50063, 0)
# ('Hamilton County', 'IL', 8457, 8457, 0)
# ('Hancock County', 'IL', 19104, 19104, 0)
# ('Hardin County', 'IL', 4320, 4320, 0)
# ('Henderson County', 'IL', 7331, 7331, 0)
# ('Henry County', 'IL', 50486, 50486, 0)
# ('Iroquois County', 'IL', 29718, 29718, 0)
# ('Jackson County', 'IL', 60218, 60218, 0)
# ('Jasper County', 'IL', 9698, 9698, 0)
# ('Jefferson County', 'IL', 38827, 38827, 0)
# ('Jersey County', 'IL', 22985, 22985, 0)
# ('Jo Daviess County', 'IL', 22678, 22678, 0)
# ('Johnson County', 'IL', 12582, 12582, 0)
# ('Kane County', 'IL', 515269, 515269, 0)
# ('Kankakee County', 'IL', 113449, 113449, 0)
# ('Kendall County', 'IL', 114736, 114736, 0)
# ('Knox County', 'IL', 52919, 52919, 0)
# ('Lake County', 'IL', 703462, 703462, 0)
# ('LaSalle County', 'IL', 113924, 113924, 0)
# ('Lawrence County', 'IL', 16833, 16833, 0)
# ('Lee County', 'IL', 36031, 36031, 0)
# ('Livingston County', 'IL', 38950, 38950, 0)
# ('Logan County', 'IL', 30305, 30305, 0)
# ('McDonough County', 'IL', 32612, 32612, 0)
# ('McHenry County', 'IL', 308760, 308760, 0)
# ('McLean County', 'IL', 169572, 169572, 0)
# ('Macon County', 'IL', 110768, 110768, 0)
# ('Macoupin County', 'IL', 47765, 47765, 0)
# ('Madison County', 'IL', 269282, 269282, 0)
# ('Marion County', 'IL', 39437, 39437, 0)
# ('Marshall County', 'IL', 12640, 12640, 0)
# ('Mason County', 'IL', 14666, 14666, 0)
# ('Massac County', 'IL', 15429, 15429, 0)
# ('Menard County', 'IL', 12705, 12705, 0)
# ('Mercer County', 'IL', 16434, 16434, 0)
# ('Monroe County', 'IL', 32957, 32957, 0)
# ('Montgomery County', 'IL', 30104, 30104, 0)
# ('Morgan County', 'IL', 35547, 35547, 0)
# ('Moultrie County', 'IL', 14846, 14846, 0)
# ('Ogle County', 'IL', 53497, 53497, 0)
# ('Peoria County', 'IL', 186494, 186494, 0)
# ('Perry County', 'IL', 22350, 22350, 0)
# ('Piatt County', 'IL', 16729, 16729, 0)
# ('Pike County', 'IL', 16430, 16430, 0)
# ('Pope County', 'IL', 4470, 4470, 0)
# ('Pulaski County', 'IL', 6161, 6161, 0)
# ('Putnam County', 'IL', 6006, 6006, 0)
# ('Randolph County', 'IL', 33476, 33476, 0)
# ('Richland County', 'IL', 16233, 16233, 0)
# ('Rock Island County', 'IL', 147546, 147546, 0)
# ('St. Clair County', 'IL', 270056, 270056, 0)
# ('Saline County', 'IL', 24913, 24913, 0)
# ('Sangamon County', 'IL', 197465, 197465, 0)
# ('Schuyler County', 'IL', 7544, 7544, 0)
# ('Scott County', 'IL', 5355, 5355, 0)
# ('Shelby County', 'IL', 22363, 22363, 0)
# ('Stark County', 'IL', 5994, 5994, 0)
# ('Stephenson County', 'IL', 47711, 47711, 0)
# ('Tazewell County', 'IL', 135394, 135394, 0)
# ('Union County', 'IL', 17808, 17808, 0)
# ('Vermilion County', 'IL', 81625, 81625, 0)
# ('Wabash County', 'IL', 11947, 11947, 0)
# ('Warren County', 'IL', 17707, 17707, 0)
# ('Washington County', 'IL', 14716, 14716, 0)
# ('Wayne County', 'IL', 16760, 16760, 0)
# ('White County', 'IL', 14665, 14665, 0)
# ('Whiteside County', 'IL', 58498, 58498, 0)
# ('Will County', 'IL', 677560, 677560, 0)
# ('Williamson County', 'IL', 66357, 66357, 0)
# ('Winnebago County', 'IL', 295266, 295266, 0)
# ('Woodford County', 'IL', 38664, 38664, 0)
# ('Adams County', 'IN', 34387, 34387, 0)
# ('Allen County', 'IN', 355329, 355329, 0)
# ('Bartholomew County', 'IN', 76794, 76794, 0)
# ('Benton County', 'IN', 8854, 8854, 0)
# ('Blackford County', 'IN', 12766, 12766, 0)
# ('Boone County', 'IN', 56640, 56640, 0)
# ('Brown County', 'IN', 15242, 15242, 0)
# ('Carroll County', 'IN', 20155, 20155, 0)
# ('Cass County', 'IN', 38966, 38966, 0)
# ('Clark County', 'IN', 110232, 110232, 0)
# ('Clay County', 'IN', 26890, 26890, 0)
# ('Clinton County', 'IN', 33224, 33224, 0)
# ('Crawford County', 'IN', 10713, 10713, 0)
# ('Daviess County', 'IN', 31648, 31648, 0)
# ('Dearborn County', 'IN', 50047, 50047, 0)
# ('Decatur County', 'IN', 25740, 25740, 0)
# ('DeKalb County', 'IN', 42223, 42223, 0)
# ('Delaware County', 'IN', 117671, 117671, 0)
# ('Dubois County', 'IN', 41889, 41889, 0)
# ('Elkhart County', 'IN', 197559, 197559, 0)
# ('Fayette County', 'IN', 24277, 24277, 0)
# ('Floyd County', 'IN', 74578, 74578, 0)
# ('Fountain County', 'IN', 17240, 17240, 0)
# ('Franklin County', 'IN', 23087, 23087, 0)
# ('Fulton County', 'IN', 20836, 20836, 0)
# ('Gibson County', 'IN', 33503, 33503, 0)
# ('Grant County', 'IN', 70061, 70061, 0)
# ('Greene County', 'IN', 33165, 33165, 0)
# ('Hamilton County', 'IN', 274569, 274569, 0)
# ('Hancock County', 'IN', 70002, 70002, 0)
# ('Harrison County', 'IN', 39364, 39364, 0)
# ('Hendricks County', 'IN', 145448, 145448, 0)
# ('Henry County', 'IN', 49462, 49462, 0)
# ('Howard County', 'IN', 82752, 82752, 0)
# ('Huntington County', 'IN', 37124, 37124, 0)
# ('Jackson County', 'IN', 42376, 42376, 0)
# ('Jasper County', 'IN', 33478, 33478, 0)
# ('Jay County', 'IN', 21253, 21253, 0)
# ('Jefferson County', 'IN', 32428, 32428, 0)
# ('Jennings County', 'IN', 28525, 28525, 0)
# ('Johnson County', 'IN', 139654, 139654, 0)
# ('Knox County', 'IN', 38440, 38440, 0)
# ('Kosciusko County', 'IN', 77358, 77358, 0)
# ('LaGrange County', 'IN', 37128, 37128, 0)
# ('Lake County', 'IN', 496005, 496005, 0)
# ('LaPorte County', 'IN', 111467, 111467, 0)
# ('Lawrence County', 'IN', 46134, 46134, 0)
# ('Madison County', 'IN', 131636, 131636, 0)
# ('Marion County', 'IN', 903393, 903393, 0)
# ('Marshall County', 'IN', 47051, 47051, 0)
# ('Martin County', 'IN', 10334, 10334, 0)
# ('Miami County', 'IN', 36903, 36903, 0)
# ('Monroe County', 'IN', 137974, 137974, 0)
# ('Montgomery County', 'IN', 38124, 38124, 0)
# ('Morgan County', 'IN', 68894, 68894, 0)
# ('Newton County', 'IN', 14244, 14244, 0)
# ('Noble County', 'IN', 47536, 47536, 0)
# ('Ohio County', 'IN', 6128, 6128, 0)
# ('Orange County', 'IN', 19840, 19840, 0)
# ('Owen County', 'IN', 21575, 21575, 0)
# ('Parke County', 'IN', 17339, 17339, 0)
# ('Perry County', 'IN', 19338, 19338, 0)
# ('Pike County', 'IN', 12845, 12845, 0)
# ('Porter County', 'IN', 164343, 164343, 0)
# ('Posey County', 'IN', 25910, 25910, 0)
# ('Pulaski County', 'IN', 13402, 13402, 0)
# ('Putnam County', 'IN', 37963, 37963, 0)
# ('Randolph County', 'IN', 26171, 26171, 0)
# ('Ripley County', 'IN', 28818, 28818, 0)
# ('Rush County', 'IN', 17392, 17392, 0)
# ('St. Joseph County', 'IN', 266931, 266931, 0)
# ('Scott County', 'IN', 24181, 24181, 0)
# ('Shelby County', 'IN', 44436, 44436, 0)
# ('Spencer County', 'IN', 20952, 20952, 0)
# ('Starke County', 'IN', 23363, 23363, 0)
# ('Steuben County', 'IN', 34185, 34185, 0)
# ('Sullivan County', 'IN', 21475, 21475, 0)
# ('Switzerland County', 'IN', 10613, 10613, 0)
# ('Tippecanoe County', 'IN', 172780, 172780, 0)
# ('Tipton County', 'IN', 15936, 15936, 0)
# ('Union County', 'IN', 7516, 7516, 0)
# ('Vanderburgh County', 'IN', 179703, 179703, 0)
# ('Vermillion County', 'IN', 16212, 16212, 0)
# ('Vigo County', 'IN', 107848, 107848, 0)
# ('Wabash County', 'IN', 32888, 32888, 0)
# ('Warren County', 'IN', 8508, 8508, 0)
# ('Warrick County', 'IN', 59689, 59689, 0)
# ('Washington County', 'IN', 28262, 28262, 0)
# ('Wayne County', 'IN', 68917, 68917, 0)
# ('Wells County', 'IN', 27636, 27636, 0)
# ('White County', 'IN', 24643, 24643, 0)
# ('Whitley County', 'IN', 33292, 33292, 0)
# ('Adair County', 'IA', 7682, 7682, 0)
# ('Adams County', 'IA', 4029, 4029, 0)
# ('Allamakee County', 'IA', 14330, 14330, 0)
# ('Appanoose County', 'IA', 12887, 12887, 0)
# ('Audubon County', 'IA', 6119, 6119, 0)
# ('Benton County', 'IA', 26076, 26076, 0)
# ('Black Hawk County', 'IA', 131090, 131090, 0)
# ('Boone County', 'IA', 26306, 26306, 0)
# ('Bremer County', 'IA', 24276, 24276, 0)
# ('Buchanan County', 'IA', 20958, 20958, 0)
# ('Buena Vista County', 'IA', 20260, 20260, 0)
# ('Butler County', 'IA', 14867, 14867, 0)
# ('Calhoun County', 'IA', 9670, 9670, 0)
# ('Carroll County', 'IA', 20816, 20816, 0)
# ('Cass County', 'IA', 13956, 13956, 0)
# ('Cedar County', 'IA', 18499, 18499, 0)
# ('Cerro Gordo County', 'IA', 44151, 44151, 0)
# ('Cherokee County', 'IA', 12072, 12072, 0)
# ('Chickasaw County', 'IA', 12439, 12439, 0)
# ('Clarke County', 'IA', 9286, 9286, 0)
# ('Clay County', 'IA', 16667, 16667, 0)
# ('Clayton County', 'IA', 18129, 18129, 0)
# ('Clinton County', 'IA', 49116, 49116, 0)
# ('Crawford County', 'IA', 17096, 17096, 0)
# ('Dallas County', 'IA', 66135, 66135, 0)
# ('Davis County', 'IA', 8753, 8753, 0)
# ('Decatur County', 'IA', 8457, 8457, 0)
# ('Delaware County', 'IA', 17764, 17764, 0)
# ('Des Moines County', 'IA', 40325, 40325, 0)
# ('Dickinson County', 'IA', 16667, 16667, 0)
# ('Dubuque County', 'IA', 93653, 93653, 0)
# ('Emmet County', 'IA', 10302, 10302, 0)
# ('Fayette County', 'IA', 20880, 20880, 0)
# ('Floyd County', 'IA', 16303, 16303, 0)
# ('Franklin County', 'IA', 10680, 10680, 0)
# ('Fremont County', 'IA', 7441, 7441, 0)
# ('Greene County', 'IA', 9336, 9336, 0)
# ('Grundy County', 'IA', 12453, 12453, 0)
# ('Guthrie County', 'IA', 10954, 10954, 0)
# ('Hamilton County', 'IA', 15673, 15673, 0)
# ('Hancock County', 'IA', 11341, 11341, 0)
# ('Hardin County', 'IA', 17534, 17534, 0)
# ('Harrison County', 'IA', 14928, 14928, 0)
# ('Henry County', 'IA', 20145, 20145, 0)
# ('Howard County', 'IA', 9566, 9566, 0)
# ('Humboldt County', 'IA', 9815, 9815, 0)
# ('Ida County', 'IA', 7089, 7089, 0)
# ('Iowa County', 'IA', 16355, 16355, 0)
# ('Jackson County', 'IA', 19848, 19848, 0)
# ('Jasper County', 'IA', 36842, 36842, 0)
# ('Jefferson County', 'IA', 16843, 16843, 0)
# ('Johnson County', 'IA', 130882, 130882, 0)
# ('Jones County', 'IA', 20638, 20638, 0)
# ('Keokuk County', 'IA', 10511, 10511, 0)
# ('Kossuth County', 'IA', 15543, 15543, 0)
# ('Lee County', 'IA', 35862, 35862, 0)
# ('Linn County', 'IA', 211226, 211226, 0)
# ('Louisa County', 'IA', 11387, 11387, 0)
# ('Lucas County', 'IA', 8898, 8898, 0)
# ('Lyon County', 'IA', 11581, 11581, 0)
# ('Madison County', 'IA', 15679, 15679, 0)
# ('Mahaska County', 'IA', 22381, 22381, 0)
# ('Marion County', 'IA', 33309, 33309, 0)
# ('Marshall County', 'IA', 40648, 40648, 0)
# ('Mills County', 'IA', 15059, 15059, 0)
# ('Mitchell County', 'IA', 10776, 10776, 0)
# ('Monona County', 'IA', 9243, 9243, 0)
# ('Monroe County', 'IA', 7970, 7970, 0)
# ('Montgomery County', 'IA', 10740, 10740, 0)
# ('Muscatine County', 'IA', 42745, 42745, 0)
# ("O'Brien County", 'IA', 14398, 14398, 0)
# ('Osceola County', 'IA', 6462, 6462, 0)
# ('Page County', 'IA', 15932, 15932, 0)
# ('Palo Alto County', 'IA', 9421, 9421, 0)
# ('Plymouth County', 'IA', 24986, 24986, 0)
# ('Pocahontas County', 'IA', 7310, 7310, 0)
# ('Polk County', 'IA', 430640, 430640, 0)
# ('Pottawattamie County', 'IA', 93158, 93158, 0)
# ('Poweshiek County', 'IA', 18914, 18914, 0)
# ('Ringgold County', 'IA', 5131, 5131, 0)
# ('Sac County', 'IA', 10350, 10350, 0)
# ('Scott County', 'IA', 165224, 165224, 0)
# ('Shelby County', 'IA', 12167, 12167, 0)
# ('Sioux County', 'IA', 33704, 33704, 0)
# ('Story County', 'IA', 89542, 89542, 0)
# ('Tama County', 'IA', 17767, 17767, 0)
# ('Taylor County', 'IA', 6317, 6317, 0)
# ('Union County', 'IA', 12534, 12534, 0)
# ('Van Buren County', 'IA', 7570, 7570, 0)
# ('Wapello County', 'IA', 35625, 35625, 0)
# ('Warren County', 'IA', 46225, 46225, 0)
# ('Washington County', 'IA', 21704, 21704, 0)
# ('Wayne County', 'IA', 6403, 6403, 0)
# ('Webster County', 'IA', 38013, 38013, 0)
# ('Winnebago County', 'IA', 10866, 10866, 0)
# ('Winneshiek County', 'IA', 21056, 21056, 0)
# ('Woodbury County', 'IA', 102172, 102172, 0)
# ('Worth County', 'IA', 7598, 7598, 0)
# ('Wright County', 'IA', 13229, 13229, 0)
# ('Allen County', 'KS', 13371, 13371, 0)
# ('Anderson County', 'KS', 8102, 8102, 0)
# ('Atchison County', 'KS', 16924, 16924, 0)
# ('Barber County', 'KS', 4861, 4861, 0)
# ('Barton County', 'KS', 27674, 27674, 0)
# ('Bourbon County', 'KS', 15173, 15173, 0)
# ('Brown County', 'KS', 9984, 9984, 0)
# ('Butler County', 'KS', 65880, 65880, 0)
# ('Chase County', 'KS', 2790, 2790, 0)
# ('Chautauqua County', 'KS', 3669, 3669, 0)
# ('Cherokee County', 'KS', 21603, 21603, 0)
# ('Cheyenne County', 'KS', 2726, 2726, 0)
# ('Clark County', 'KS', 2215, 2215, 0)
# ('Clay County', 'KS', 8535, 8535, 0)
# ('Cloud County', 'KS', 9533, 9533, 0)
# ('Coffey County', 'KS', 8601, 8601, 0)
# ('Comanche County', 'KS', 1891, 1891, 0)
# ('Cowley County', 'KS', 36311, 36311, 0)
# ('Crawford County', 'KS', 39134, 39134, 0)
# ('Decatur County', 'KS', 2961, 2961, 0)
# ('Dickinson County', 'KS', 19754, 19754, 0)
# ('Doniphan County', 'KS', 7945, 7945, 0)
# ('Douglas County', 'KS', 110826, 110826, 0)
# ('Edwards County', 'KS', 3037, 3037, 0)
# ('Elk County', 'KS', 2882, 2882, 0)
# ('Ellis County', 'KS', 28452, 28452, 0)
# ('Ellsworth County', 'KS', 6497, 6497, 0)
# ('Finney County', 'KS', 36776, 36776, 0)
# ('Ford County', 'KS', 33848, 33848, 0)
# ('Franklin County', 'KS', 25992, 25992, 0)
# ('Geary County', 'KS', 34362, 34362, 0)
# ('Gove County', 'KS', 2695, 2695, 0)
# ('Graham County', 'KS', 2597, 2597, 0)
# ('Grant County', 'KS', 7829, 7829, 0)
# ('Gray County', 'KS', 6006, 6006, 0)
# ('Greeley County', 'KS', 1247, 1247, 0)
# ('Greenwood County', 'KS', 6689, 6689, 0)
# ('Hamilton County', 'KS', 2690, 2690, 0)
# ('Harper County', 'KS', 6034, 6034, 0)
# ('Harvey County', 'KS', 34684, 34684, 0)
# ('Haskell County', 'KS', 4256, 4256, 0)
# ('Hodgeman County', 'KS', 1916, 1916, 0)
# ('Jackson County', 'KS', 13462, 13462, 0)
# ('Jefferson County', 'KS', 19126, 19126, 0)
# ('Jewell County', 'KS', 3077, 3077, 0)
# ('Johnson County', 'KS', 544179, 544179, 0)
# ('Kearny County', 'KS', 3977, 3977, 0)
# ('Kingman County', 'KS', 7858, 7858, 0)
# ('Kiowa County', 'KS', 2553, 2553, 0)
# ('Labette County', 'KS', 21607, 21607, 0)
# ('Lane County', 'KS', 1750, 1750, 0)
# ('Leavenworth County', 'KS', 76227, 76227, 0)
# ('Lincoln County', 'KS', 3241, 3241, 0)
# ('Linn County', 'KS', 9656, 9656, 0)
# ('Logan County', 'KS', 2756, 2756, 0)
# ('Lyon County', 'KS', 33690, 33690, 0)
# ('McPherson County', 'KS', 29180, 29180, 0)
# ('Marion County', 'KS', 12660, 12660, 0)
# ('Marshall County', 'KS', 10117, 10117, 0)
# ('Meade County', 'KS', 4575, 4575, 0)
# ('Miami County', 'KS', 32787, 32787, 0)
# ('Mitchell County', 'KS', 6373, 6373, 0)
# ('Montgomery County', 'KS', 35471, 35471, 0)
# ('Morris County', 'KS', 5923, 5923, 0)
# ('Morton County', 'KS', 3233, 3233, 0)
# ('Nemaha County', 'KS', 10178, 10178, 0)
# ('Neosho County', 'KS', 16512, 16512, 0)
# ('Ness County', 'KS', 3107, 3107, 0)
# ('Norton County', 'KS', 5671, 5671, 0)
# ('Osage County', 'KS', 16295, 16295, 0)
# ('Osborne County', 'KS', 3858, 3858, 0)
# ('Ottawa County', 'KS', 6091, 6091, 0)
# ('Pawnee County', 'KS', 6973, 6973, 0)
# ('Phillips County', 'KS', 5642, 5642, 0)
# ('Pottawatomie County', 'KS', 21604, 21604, 0)
# ('Pratt County', 'KS', 9656, 9656, 0)
# ('Rawlins County', 'KS', 2519, 2519, 0)
# ('Reno County', 'KS', 64511, 64511, 0)
# ('Republic County', 'KS', 4980, 4980, 0)
# ('Rice County', 'KS', 10083, 10083, 0)
# ('Riley County', 'KS', 71115, 71115, 0)
# ('Rooks County', 'KS', 5181, 5181, 0)
# ('Rush County', 'KS', 3307, 3307, 0)
# ('Russell County', 'KS', 6970, 6970, 0)
# ('Saline County', 'KS', 55606, 55606, 0)
# ('Scott County', 'KS', 4936, 4936, 0)
# ('Sedgwick County', 'KS', 498365, 498365, 0)
# ('Seward County', 'KS', 22952, 22952, 0)
# ('Shawnee County', 'KS', 177934, 177934, 0)
# ('Sheridan County', 'KS', 2556, 2556, 0)
# ('Sherman County', 'KS', 6010, 6010, 0)
# ('Smith County', 'KS', 3853, 3853, 0)
# ('Stafford County', 'KS', 4437, 4437, 0)
# ('Stanton County', 'KS', 2235, 2235, 0)
# ('Stevens County', 'KS', 5724, 5724, 0)
# ('Sumner County', 'KS', 24132, 24132, 0)
# ('Thomas County', 'KS', 7900, 7900, 0)
# ('Trego County', 'KS', 3001, 3001, 0)
# ('Wabaunsee County', 'KS', 7053, 7053, 0)
# ('Wallace County', 'KS', 1485, 1485, 0)
# ('Washington County', 'KS', 5799, 5799, 0)
# ('Wichita County', 'KS', 2234, 2234, 0)
# ('Wilson County', 'KS', 9409, 9409, 0)
# ('Woodson County', 'KS', 3309, 3309, 0)
# ('Wyandotte County', 'KS', 157505, 157505, 0)
# ('Adair County', 'KY', 18656, 18656, 0)
# ('Allen County', 'KY', 19956, 19956, 0)
# ('Anderson County', 'KY', 21421, 21421, 0)
# ('Ballard County', 'KY', 8249, 8249, 0)
# ('Barren County', 'KY', 42173, 42173, 0)
# ('Bath County', 'KY', 11591, 11591, 0)
# ('Bell County', 'KY', 28691, 28691, 0)
# ('Boone County', 'KY', 118811, 118811, 0)
# ('Bourbon County', 'KY', 19985, 19985, 0)
# ('Boyd County', 'KY', 49542, 49542, 0)
# ('Boyle County', 'KY', 28432, 28432, 0)
# ('Bracken County', 'KY', 8488, 8488, 0)
# ('Breathitt County', 'KY', 13878, 13878, 0)
# ('Breckinridge County', 'KY', 20059, 20059, 0)
# ('Bullitt County', 'KY', 74319, 74319, 0)
# ('Butler County', 'KY', 12690, 12690, 0)
# ('Caldwell County', 'KY', 12984, 12984, 0)
# ('Calloway County', 'KY', 37191, 37191, 0)
# ('Campbell County', 'KY', 90336, 90336, 0)
# ('Carlisle County', 'KY', 5104, 5104, 0)
# ('Carroll County', 'KY', 10811, 10811, 0)
# ('Carter County', 'KY', 27720, 27720, 0)
# ('Casey County', 'KY', 15955, 15955, 0)
# ('Christian County', 'KY', 73955, 73955, 0)
# ('Clark County', 'KY', 35613, 35613, 0)
# ('Clay County', 'KY', 21730, 21730, 0)
# ('Clinton County', 'KY', 10272, 10272, 0)
# ('Crittenden County', 'KY', 9315, 9315, 0)
# ('Cumberland County', 'KY', 6856, 6856, 0)
# ('Daviess County', 'KY', 96656, 96656, 0)
# ('Edmonson County', 'KY', 12161, 12161, 0)
# ('Elliott County', 'KY', 7852, 7852, 0)
# ('Estill County', 'KY', 14672, 14672, 0)
# ('Fayette County', 'KY', 295803, 295803, 0)
# ('Fleming County', 'KY', 14348, 14348, 0)
# ('Floyd County', 'KY', 39451, 39451, 0)
# ('Franklin County', 'KY', 49285, 49285, 0)
# ('Fulton County', 'KY', 6813, 6813, 0)
# ('Gallatin County', 'KY', 8589, 8589, 0)
# ('Garrard County', 'KY', 16912, 16912, 0)
# ('Grant County', 'KY', 24662, 24662, 0)
# ('Graves County', 'KY', 37121, 37121, 0)
# ('Grayson County', 'KY', 25746, 25746, 0)
# ('Green County', 'KY', 11258, 11258, 0)
# ('Greenup County', 'KY', 36910, 36910, 0)
# ('Hancock County', 'KY', 8565, 8565, 0)
# ('Hardin County', 'KY', 105543, 105543, 0)
# ('Harlan County', 'KY', 29278, 29278, 0)
# ('Harrison County', 'KY', 18846, 18846, 0)
# ('Hart County', 'KY', 18199, 18199, 0)
# ('Henderson County', 'KY', 46250, 46250, 0)
# ('Henry County', 'KY', 15416, 15416, 0)
# ('Hickman County', 'KY', 4902, 4902, 0)
# ('Hopkins County', 'KY', 46920, 46920, 0)
# ('Jackson County', 'KY', 13494, 13494, 0)
# ('Jefferson County', 'KY', 741096, 741096, 0)
# ('Jessamine County', 'KY', 48586, 48586, 0)
# ('Johnson County', 'KY', 23356, 23356, 0)
# ('Kenton County', 'KY', 159720, 159720, 0)
# ('Knott County', 'KY', 16346, 16346, 0)
# ('Knox County', 'KY', 31883, 31883, 0)
# ('Larue County', 'KY', 14193, 14193, 0)
# ('Laurel County', 'KY', 58849, 58849, 0)
# ('Lawrence County', 'KY', 15860, 15860, 0)
# ('Lee County', 'KY', 7887, 7887, 0)
# ('Leslie County', 'KY', 11310, 11310, 0)
# ('Letcher County', 'KY', 24519, 24519, 0)
# ('Lewis County', 'KY', 13870, 13870, 0)
# ('Lincoln County', 'KY', 24742, 24742, 0)
# ('Livingston County', 'KY', 9519, 9519, 0)
# ('Logan County', 'KY', 26835, 26835, 0)
# ('Lyon County', 'KY', 8314, 8314, 0)
# ('McCracken County', 'KY', 65565, 65565, 0)
# ('McCreary County', 'KY', 18306, 18306, 0)
# ('McLean County', 'KY', 9531, 9531, 0)
# ('Madison County', 'KY', 82916, 82916, 0)
# ('Magoffin County', 'KY', 13333, 13333, 0)
# ('Marion County', 'KY', 19820, 19820, 0)
# ('Marshall County', 'KY', 31448, 31448, 0)
# ('Martin County', 'KY', 12929, 12929, 0)
# ('Mason County', 'KY', 17490, 17490, 0)
# ('Meade County', 'KY', 28602, 28602, 0)
# ('Menifee County', 'KY', 6306, 6306, 0)
# ('Mercer County', 'KY', 21331, 21331, 0)
# ('Metcalfe County', 'KY', 10099, 10099, 0)
# ('Monroe County', 'KY', 10963, 10963, 0)
# ('Montgomery County', 'KY', 26499, 26499, 0)
# ('Morgan County', 'KY', 13923, 13923, 0)
# ('Muhlenberg County', 'KY', 31499, 31499, 0)
# ('Nelson County', 'KY', 43437, 43437, 0)
# ('Nicholas County', 'KY', 7135, 7135, 0)
# ('Ohio County', 'KY', 23842, 23842, 0)
# ('Oldham County', 'KY', 60316, 60316, 0)
# ('Owen County', 'KY', 10841, 10841, 0)
# ('Owsley County', 'KY', 4755, 4755, 0)
# ('Pendleton County', 'KY', 14877, 14877, 0)
# ('Perry County', 'KY', 28712, 28712, 0)
# ('Pike County', 'KY', 65024, 65024, 0)
# ('Powell County', 'KY', 12613, 12613, 0)
# ('Pulaski County', 'KY', 63063, 63063, 0)
# ('Robertson County', 'KY', 2282, 2282, 0)
# ('Rockcastle County', 'KY', 17056, 17056, 0)
# ('Rowan County', 'KY', 23333, 23333, 0)
# ('Russell County', 'KY', 17565, 17565, 0)
# ('Scott County', 'KY', 47173, 47173, 0)
# ('Shelby County', 'KY', 42074, 42074, 0)
# ('Simpson County', 'KY', 17327, 17327, 0)
# ('Spencer County', 'KY', 17061, 17061, 0)
# ('Taylor County', 'KY', 24512, 24512, 0)
# ('Todd County', 'KY', 12460, 12460, 0)
# ('Trigg County', 'KY', 14339, 14339, 0)
# ('Trimble County', 'KY', 8809, 8809, 0)
# ('Union County', 'KY', 15007, 15007, 0)
# ('Warren County', 'KY', 113792, 113792, 0)
# ('Washington County', 'KY', 11717, 11717, 0)
# ('Wayne County', 'KY', 20813, 20813, 0)
# ('Webster County', 'KY', 13621, 13621, 0)
# ('Whitley County', 'KY', 35637, 35637, 0)
# ('Wolfe County', 'KY', 7355, 7355, 0)
# ('Woodford County', 'KY', 24939, 24939, 0)
# ('Acadia Parish', 'LA', 61773, 61773, 0)
# ('Allen Parish', 'LA', 25764, 25764, 0)
# ('Ascension Parish', 'LA', 107215, 107215, 0)
# ('Assumption Parish', 'LA', 23421, 23421, 0)
# ('Avoyelles Parish', 'LA', 42073, 42073, 0)
# ('Beauregard Parish', 'LA', 35654, 35654, 0)
# ('Bienville Parish', 'LA', 14353, 14353, 0)
# ('Bossier Parish', 'LA', 116979, 116979, 0)
# ('Caddo Parish', 'LA', 254969, 254969, 0)
# ('Calcasieu Parish', 'LA', 192768, 192768, 0)
# ('Caldwell Parish', 'LA', 10132, 10132, 0)
# ('Cameron Parish', 'LA', 6839, 6839, 0)
# ('Catahoula Parish', 'LA', 10407, 10407, 0)
# ('Claiborne Parish', 'LA', 17195, 17195, 0)
# ('Concordia Parish', 'LA', 20822, 20822, 0)
# ('De Soto Parish', 'LA', 26656, 26656, 0)
# ('East Baton Rouge Parish', 'LA', 440171, 440171, 0)
# ('East Carroll Parish', 'LA', 7759, 7759, 0)
# ('East Feliciana Parish', 'LA', 20267, 20267, 0)
# ('Evangeline Parish', 'LA', 33984, 33984, 0)
# ('Franklin Parish', 'LA', 20767, 20767, 0)
# ('Grant Parish', 'LA', 22309, 22309, 0)
# ...
# ('Wichita County', 'TX', 131500, 131500, 0)
# ('Wilbarger County', 'TX', 13535, 13535, 0)
# ('Willacy County', 'TX', 22134, 22134, 0)
# ('Williamson County', 'TX', 422679, 422679, 0)
# ('Wilson County', 'TX', 42918, 42918, 0)
# ('Winkler County', 'TX', 7110, 7110, 0)
# ('Wise County', 'TX', 59127, 59127, 0)
# ('Wood County', 'TX', 41964, 41964, 0)
# ('Yoakum County', 'TX', 7879, 7879, 0)
# ('Young County', 'TX', 18550, 18550, 0)
# ('Zapata County', 'TX', 14018, 14018, 0)
# ('Zavala County', 'TX', 11677, 11677, 0)
# ('Beaver County', 'UT', 6629, 6629, 0)
# ('Box Elder County', 'UT', 49975, 49975, 0)
# ('Cache County', 'UT', 112656, 112656, 0)
# ('Carbon County', 'UT', 21403, 21403, 0)
# ('Daggett County', 'UT', 1059, 1059, 0)
# ('Davis County', 'UT', 306479, 306479, 0)
# ('Duchesne County', 'UT', 18607, 18607, 0)
# ('Emery County', 'UT', 10976, 10976, 0)
# ('Garfield County', 'UT', 5172, 5172, 0)
# ('Grand County', 'UT', 9225, 9225, 0)
# ('Iron County', 'UT', 46163, 46163, 0)
# ('Juab County', 'UT', 10246, 10246, 0)
# ('Kane County', 'UT', 7125, 7125, 0)
# ('Millard County', 'UT', 12503, 12503, 0)
# ('Morgan County', 'UT', 9469, 9469, 0)
# ('Piute County', 'UT', 1556, 1556, 0)
# ('Rich County', 'UT', 2264, 2264, 0)
# ('Salt Lake County', 'UT', 1029655, 1029655, 0)
# ('San Juan County', 'UT', 14746, 14746, 0)
# ('Sanpete County', 'UT', 27822, 27822, 0)
# ('Sevier County', 'UT', 20802, 20802, 0)
# ('Summit County', 'UT', 36324, 36324, 0)
# ('Tooele County', 'UT', 58218, 58218, 0)
# ('Uintah County', 'UT', 32588, 32588, 0)
# ('Utah County', 'UT', 516564, 516564, 0)
# ('Wasatch County', 'UT', 23530, 23530, 0)
# ('Washington County', 'UT', 138115, 138115, 0)
# ('Wayne County', 'UT', 2778, 2778, 0)
# ('Weber County', 'UT', 231236, 231236, 0)
# ('Addison County', 'VT', 36821, 36821, 0)
# ('Bennington County', 'VT', 37125, 37125, 0)
# ('Caledonia County', 'VT', 31227, 31227, 0)
# ('Chittenden County', 'VT', 156545, 156545, 0)
# ('Essex County', 'VT', 6306, 6306, 0)
# ('Franklin County', 'VT', 47746, 47746, 0)
# ('Grand Isle County', 'VT', 6970, 6970, 0)
# ('Lamoille County', 'VT', 24475, 24475, 0)
# ('Orange County', 'VT', 28936, 28936, 0)
# ('Orleans County', 'VT', 27231, 27231, 0)
# ('Rutland County', 'VT', 61642, 61642, 0)
# ('Washington County', 'VT', 59534, 59534, 0)
# ('Windham County', 'VT', 44513, 44513, 0)
# ('Windsor County', 'VT', 56670, 56670, 0)
# ('Accomack County', 'VA', 33164, 33164, 0)
# ('Albemarle County', 'VA', 98970, 98970, 0)
# ('Alleghany County', 'VA', 16250, 16250, 0)
# ('Amelia County', 'VA', 12690, 12690, 0)
# ('Amherst County', 'VA', 32353, 32353, 0)
# ('Appomattox County', 'VA', 14973, 14973, 0)
# ('Arlington County', 'VA', 207627, 207627, 0)
# ('Augusta County', 'VA', 73750, 73750, 0)
# ('Bath County', 'VA', 4731, 4731, 0)
# ('Bedford County', 'VA', 68676, 68676, 0)
# ('Bland County', 'VA', 6824, 6824, 0)
# ('Botetourt County', 'VA', 33148, 33148, 0)
# ('Brunswick County', 'VA', 17434, 17434, 0)
# ('Buchanan County', 'VA', 24098, 24098, 0)
# ('Buckingham County', 'VA', 17146, 17146, 0)
# ('Campbell County', 'VA', 54842, 54842, 0)
# ('Caroline County', 'VA', 28545, 28545, 0)
# ('Carroll County', 'VA', 30042, 30042, 0)
# ('Charles City County', 'VA', 7256, 7256, 0)
# ('Charlotte County', 'VA', 12586, 12586, 0)
# ('Chesterfield County', 'VA', 316236, 316236, 0)
# ('Clarke County', 'VA', 14034, 14034, 0)
# ('Craig County', 'VA', 5190, 5190, 0)
# ('Culpeper County', 'VA', 46689, 46689, 0)
# ('Cumberland County', 'VA', 10052, 10052, 0)
# ('Dickenson County', 'VA', 15903, 15903, 0)
# ('Dinwiddie County', 'VA', 28001, 28001, 0)
# ('Essex County', 'VA', 11151, 11151, 0)
# ('Fairfax County', 'VA', 1081726, 1081726, 0)
# ('Fauquier County', 'VA', 65203, 65203, 0)
# ('Floyd County', 'VA', 15279, 15279, 0)
# ('Fluvanna County', 'VA', 25691, 25691, 0)
# ('Franklin County', 'VA', 56159, 56159, 0)
# ('Frederick County', 'VA', 78305, 78305, 0)
# ('Giles County', 'VA', 17286, 17286, 0)
# ('Gloucester County', 'VA', 36858, 36858, 0)
# ('Goochland County', 'VA', 21717, 21717, 0)
# ('Grayson County', 'VA', 15533, 15533, 0)
# ('Greene County', 'VA', 18403, 18403, 0)
# ('Greensville County', 'VA', 12243, 12243, 0)
# ('Halifax County', 'VA', 36241, 36241, 0)
# ('Hanover County', 'VA', 99863, 99863, 0)
# ('Henrico County', 'VA', 306935, 306935, 0)
# ('Henry County', 'VA', 54151, 54151, 0)
# ('Highland County', 'VA', 2321, 2321, 0)
# ('Isle of Wight County', 'VA', 35270, 35270, 0)
# ('James City County', 'VA', 67009, 67009, 0)
# ('King and Queen County', 'VA', 6945, 6945, 0)
# ('King George County', 'VA', 23584, 23584, 0)
# ('King William County', 'VA', 15935, 15935, 0)
# ('Lancaster County', 'VA', 11391, 11391, 0)
# ('Lee County', 'VA', 25587, 25587, 0)
# ('Loudoun County', 'VA', 312311, 312311, 0)
# ('Louisa County', 'VA', 33153, 33153, 0)
# ('Lunenburg County', 'VA', 12914, 12914, 0)
# ('Madison County', 'VA', 13308, 13308, 0)
# ('Mathews County', 'VA', 8978, 8978, 0)
# ('Mecklenburg County', 'VA', 32727, 32727, 0)
# ('Middlesex County', 'VA', 10959, 10959, 0)
# ('Montgomery County', 'VA', 94392, 94392, 0)
# ('Nelson County', 'VA', 15020, 15020, 0)
# ('New Kent County', 'VA', 18429, 18429, 0)
# ('Northampton County', 'VA', 12389, 12389, 0)
# ('Northumberland County', 'VA', 12330, 12330, 0)
# ('Nottoway County', 'VA', 15853, 15853, 0)
# ('Orange County', 'VA', 33481, 33481, 0)
# ('Page County', 'VA', 24042, 24042, 0)
# ('Patrick County', 'VA', 18490, 18490, 0)
# ('Pittsylvania County', 'VA', 63506, 63506, 0)
# ('Powhatan County', 'VA', 28046, 28046, 0)
# ('Prince Edward County', 'VA', 23368, 23368, 0)
# ('Prince George County', 'VA', 35725, 35725, 0)
# ('Prince William County', 'VA', 402002, 402002, 0)
# ('Pulaski County', 'VA', 34872, 34872, 0)
# ('Rappahannock County', 'VA', 7373, 7373, 0)
# ('Richmond County', 'VA', 9254, 9254, 0)
# ('Roanoke County', 'VA', 92376, 92376, 0)
# ('Rockbridge County', 'VA', 22307, 22307, 0)
# ('Rockingham County', 'VA', 76314, 76314, 0)
# ('Russell County', 'VA', 28897, 28897, 0)
# ('Scott County', 'VA', 23177, 23177, 0)
# ('Shenandoah County', 'VA', 41993, 41993, 0)
# ('Smyth County', 'VA', 32208, 32208, 0)
# ('Southampton County', 'VA', 18570, 18570, 0)
# ('Spotsylvania County', 'VA', 122397, 122397, 0)
# ('Stafford County', 'VA', 128961, 128961, 0)
# ('Surry County', 'VA', 7058, 7058, 0)
# ('Sussex County', 'VA', 12087, 12087, 0)
# ('Tazewell County', 'VA', 45078, 45078, 0)
# ('Warren County', 'VA', 37575, 37575, 0)
# ('Washington County', 'VA', 54876, 54876, 0)
# ('Westmoreland County', 'VA', 17454, 17454, 0)
# ('Wise County', 'VA', 41452, 41452, 0)
# ('Wythe County', 'VA', 29235, 29235, 0)
# ('York County', 'VA', 65464, 65464, 0)
# ('Alexandria city', 'VA', 139966, 139966, 0)
# ('Bedford city', 'VA', 6222, 6222, 0)
# ('Bristol city', 'VA', 17835, 17835, 0)
# ('Buena Vista city', 'VA', 6650, 6650, 0)
# ('Charlottesville city', 'VA', 43475, 43475, 0)
# ('Chesapeake city', 'VA', 222209, 222209, 0)
# ('Colonial Heights city', 'VA', 17411, 17411, 0)
# ('Covington city', 'VA', 5961, 5961, 0)
# ('Danville city', 'VA', 43055, 43055, 0)
# ('Emporia city', 'VA', 5927, 5927, 0)
# ('Fairfax city', 'VA', 22565, 22565, 0)
# ('Falls Church city', 'VA', 12332, 12332, 0)
# ('Franklin city', 'VA', 8582, 8582, 0)
# ('Fredericksburg city', 'VA', 24286, 24286, 0)
# ('Galax city', 'VA', 7042, 7042, 0)
# ('Hampton city', 'VA', 137436, 137436, 0)
# ('Harrisonburg city', 'VA', 48914, 48914, 0)
# ('Hopewell city', 'VA', 22591, 22591, 0)
# ('Lexington city', 'VA', 7042, 7042, 0)
# ('Lynchburg city', 'VA', 75568, 75568, 0)
# ('Manassas city', 'VA', 37821, 37821, 0)
# ('Manassas Park city', 'VA', 14273, 14273, 0)
# ('Martinsville city', 'VA', 13821, 13821, 0)
# ('Newport News city', 'VA', 180719, 180719, 0)
# ('Norfolk city', 'VA', 242803, 242803, 0)
# ('Norton city', 'VA', 3958, 3958, 0)
# ('Petersburg city', 'VA', 32420, 32420, 0)
# ('Poquoson city', 'VA', 12150, 12150, 0)
# ('Portsmouth city', 'VA', 95535, 95535, 0)
# ('Radford city', 'VA', 16408, 16408, 0)
# ('Richmond city', 'VA', 204214, 204214, 0)
# ('Roanoke city', 'VA', 97032, 97032, 0)
# ('Salem city', 'VA', 24802, 24802, 0)
# ('Staunton city', 'VA', 23746, 23746, 0)
# ('Suffolk city', 'VA', 84585, 84585, 0)
# ('Virginia Beach city', 'VA', 437994, 437994, 0)
# ('Waynesboro city', 'VA', 21006, 21006, 0)
# ('Williamsburg city', 'VA', 14068, 14068, 0)
# ('Winchester city', 'VA', 26203, 26203, 0)
# ('Adams County', 'WA', 18728, 18728, 0)
# ('Asotin County', 'WA', 21623, 21623, 0)
# ('Benton County', 'WA', 175177, 175177, 0)
# ('Chelan County', 'WA', 72453, 72453, 0)
# ('Clallam County', 'WA', 71404, 71404, 0)
# ('Clark County', 'WA', 425363, 425363, 0)
# ('Columbia County', 'WA', 4078, 4078, 0)
# ('Cowlitz County', 'WA', 102410, 102410, 0)
# ('Douglas County', 'WA', 38431, 38431, 0)
# ('Ferry County', 'WA', 7551, 7551, 0)
# ('Franklin County', 'WA', 78163, 78163, 0)
# ('Garfield County', 'WA', 2266, 2266, 0)
# ('Grant County', 'WA', 89120, 89120, 0)
# ('Grays Harbor County', 'WA', 72797, 72797, 0)
# ('Island County', 'WA', 78506, 78506, 0)
# ('Jefferson County', 'WA', 29872, 29872, 0)
# ('King County', 'WA', 1931249, 1931249, 0)
# ('Kitsap County', 'WA', 251133, 251133, 0)
# ('Kittitas County', 'WA', 40915, 40915, 0)
# ('Klickitat County', 'WA', 20318, 20318, 0)
# ('Lewis County', 'WA', 75455, 75455, 0)
# ('Lincoln County', 'WA', 10570, 10570, 0)
# ('Mason County', 'WA', 60699, 60699, 0)
# ('Okanogan County', 'WA', 41120, 41120, 0)
# ('Pacific County', 'WA', 20920, 20920, 0)
# ('Pend Oreille County', 'WA', 13001, 13001, 0)
# ('Pierce County', 'WA', 795225, 795225, 0)
# ('San Juan County', 'WA', 15769, 15769, 0)
# ('Skagit County', 'WA', 116901, 116901, 0)
# ('Skamania County', 'WA', 11066, 11066, 0)
# ('Snohomish County', 'WA', 713335, 713335, 0)
# ('Spokane County', 'WA', 471221, 471221, 0)
# ('Stevens County', 'WA', 43531, 43531, 0)
# ('Thurston County', 'WA', 252264, 252264, 0)
# ('Wahkiakum County', 'WA', 3978, 3978, 0)
# ('Walla Walla County', 'WA', 58781, 58781, 0)
# ('Whatcom County', 'WA', 201140, 201140, 0)
# ('Whitman County', 'WA', 44776, 44776, 0)
# ('Yakima County', 'WA', 243231, 243231, 0)
# ('Barbour County', 'WV', 16589, 16589, 0)
# ('Berkeley County', 'WV', 104169, 104169, 0)
# ('Boone County', 'WV', 24629, 24629, 0)
# ('Braxton County', 'WV', 14523, 14523, 0)
# ('Brooke County', 'WV', 24069, 24069, 0)
# ('Cabell County', 'WV', 96319, 96319, 0)
# ('Calhoun County', 'WV', 7627, 7627, 0)
# ('Clay County', 'WV', 9386, 9386, 0)
# ('Doddridge County', 'WV', 8202, 8202, 0)
# ('Fayette County', 'WV', 46039, 46039, 0)
# ('Gilmer County', 'WV', 8693, 8693, 0)
# ('Grant County', 'WV', 11937, 11937, 0)
# ('Greenbrier County', 'WV', 35480, 35480, 0)
# ('Hampshire County', 'WV', 23964, 23964, 0)
# ('Hancock County', 'WV', 30676, 30676, 0)
# ('Hardy County', 'WV', 14025, 14025, 0)
# ('Harrison County', 'WV', 69099, 69099, 0)
# ('Jackson County', 'WV', 29211, 29211, 0)
# ('Jefferson County', 'WV', 53498, 53498, 0)
# ('Kanawha County', 'WV', 193063, 193063, 0)
# ('Lewis County', 'WV', 16372, 16372, 0)
# ('Lincoln County', 'WV', 21720, 21720, 0)
# ('Logan County', 'WV', 36743, 36743, 0)
# ('McDowell County', 'WV', 22113, 22113, 0)
# ('Marion County', 'WV', 56418, 56418, 0)
# ('Marshall County', 'WV', 33107, 33107, 0)
# ('Mason County', 'WV', 27324, 27324, 0)
# ('Mercer County', 'WV', 62264, 62264, 0)
# ('Mineral County', 'WV', 28212, 28212, 0)
# ('Mingo County', 'WV', 26839, 26839, 0)
# ('Monongalia County', 'WV', 96189, 96189, 0)
# ('Monroe County', 'WV', 13502, 13502, 0)
# ('Morgan County', 'WV', 17541, 17541, 0)
# ('Nicholas County', 'WV', 26233, 26233, 0)
# ('Ohio County', 'WV', 44443, 44443, 0)
# ('Pendleton County', 'WV', 7695, 7695, 0)
# ('Pleasants County', 'WV', 7605, 7605, 0)
# ('Pocahontas County', 'WV', 8719, 8719, 0)
# ('Preston County', 'WV', 33520, 33520, 0)
# ('Putnam County', 'WV', 55486, 55486, 0)
# ('Raleigh County', 'WV', 78859, 78859, 0)
# ('Randolph County', 'WV', 29405, 29405, 0)
# ('Ritchie County', 'WV', 10449, 10449, 0)
# ('Roane County', 'WV', 14926, 14926, 0)
# ('Summers County', 'WV', 13927, 13927, 0)
# ('Taylor County', 'WV', 16895, 16895, 0)
# ('Tucker County', 'WV', 7141, 7141, 0)
# ('Tyler County', 'WV', 9208, 9208, 0)
# ('Upshur County', 'WV', 24254, 24254, 0)
# ('Wayne County', 'WV', 42481, 42481, 0)
# ('Webster County', 'WV', 9154, 9154, 0)
# ('Wetzel County', 'WV', 16583, 16583, 0)
# ('Wirt County', 'WV', 5717, 5717, 0)
# ('Wood County', 'WV', 86956, 86956, 0)
# ('Wyoming County', 'WV', 23796, 23796, 0)
# ('Adams County', 'WI', 20875, 20875, 0)
# ('Ashland County', 'WI', 16157, 16157, 0)
# ('Barron County', 'WI', 45870, 45870, 0)
# ('Bayfield County', 'WI', 15014, 15014, 0)
# ('Brown County', 'WI', 248007, 248007, 0)
# ('Buffalo County', 'WI', 13587, 13587, 0)
# ('Burnett County', 'WI', 15457, 15457, 0)
# ('Calumet County', 'WI', 48971, 48971, 0)
# ('Chippewa County', 'WI', 62415, 62415, 0)
# ('Clark County', 'WI', 34690, 34690, 0)
# ('Columbia County', 'WI', 56833, 56833, 0)
# ('Crawford County', 'WI', 16644, 16644, 0)
# ('Dane County', 'WI', 488073, 488073, 0)
# ('Dodge County', 'WI', 88759, 88759, 0)
# ('Door County', 'WI', 27785, 27785, 0)
# ('Douglas County', 'WI', 44159, 44159, 0)
# ('Dunn County', 'WI', 43857, 43857, 0)
# ('Eau Claire County', 'WI', 98736, 98736, 0)
# ('Florence County', 'WI', 4423, 4423, 0)
# ('Fond du Lac County', 'WI', 101633, 101633, 0)
# ('Forest County', 'WI', 9304, 9304, 0)
# ('Grant County', 'WI', 51208, 51208, 0)
# ('Green County', 'WI', 36842, 36842, 0)
# ('Green Lake County', 'WI', 19051, 19051, 0)
# ('Iowa County', 'WI', 23687, 23687, 0)
# ('Iron County', 'WI', 5916, 5916, 0)
# ('Jackson County', 'WI', 20449, 20449, 0)
# ('Jefferson County', 'WI', 83686, 83686, 0)
# ('Juneau County', 'WI', 26664, 26664, 0)
# ('Kenosha County', 'WI', 166426, 166426, 0)
# ('Kewaunee County', 'WI', 20574, 20574, 0)
# ('La Crosse County', 'WI', 114638, 114638, 0)
# ('Lafayette County', 'WI', 16836, 16836, 0)
# ('Langlade County', 'WI', 19977, 19977, 0)
# ('Lincoln County', 'WI', 28743, 28743, 0)
# ('Manitowoc County', 'WI', 81442, 81442, 0)
# ('Marathon County', 'WI', 134063, 134063, 0)
# ('Marinette County', 'WI', 41749, 41749, 0)
# ('Marquette County', 'WI', 15404, 15404, 0)
# ('Menominee County', 'WI', 4232, 4232, 0)
# ('Milwaukee County', 'WI', 947735, 947735, 0)
# ('Monroe County', 'WI', 44673, 44673, 0)
# ('Oconto County', 'WI', 37660, 37660, 0)
# ('Oneida County', 'WI', 35998, 35998, 0)
# ('Outagamie County', 'WI', 176695, 176695, 0)
# ('Ozaukee County', 'WI', 86395, 86395, 0)
# ('Pepin County', 'WI', 7469, 7469, 0)
# ('Pierce County', 'WI', 41019, 41019, 0)
# ('Polk County', 'WI', 44205, 44205, 0)
# ('Portage County', 'WI', 70019, 70019, 0)
# ('Price County', 'WI', 14159, 14159, 0)
# ('Racine County', 'WI', 195408, 195408, 0)
# ('Richland County', 'WI', 18021, 18021, 0)
# ('Rock County', 'WI', 160331, 160331, 0)
# ('Rusk County', 'WI', 14755, 14755, 0)
# ('St. Croix County', 'WI', 84345, 84345, 0)
# ('Sauk County', 'WI', 61976, 61976, 0)
# ('Sawyer County', 'WI', 16557, 16557, 0)
# ('Shawano County', 'WI', 41949, 41949, 0)
# ('Sheboygan County', 'WI', 115507, 115507, 0)
# ('Taylor County', 'WI', 20689, 20689, 0)
# ('Trempealeau County', 'WI', 28816, 28816, 0)
# ('Vernon County', 'WI', 29773, 29773, 0)
# ('Vilas County', 'WI', 21430, 21430, 0)
# ('Walworth County', 'WI', 102228, 102228, 0)
# ('Washburn County', 'WI', 15911, 15911, 0)
# ('Washington County', 'WI', 131887, 131887, 0)
# ('Waukesha County', 'WI', 389891, 389891, 0)
# ('Waupaca County', 'WI', 52410, 52410, 0)
# ('Waushara County', 'WI', 24496, 24496, 0)
# ('Winnebago County', 'WI', 166994, 166994, 0)
# ('Wood County', 'WI', 74749, 74749, 0)
# ('Albany County', 'WY', 36299, 36299, 0)
# ('Big Horn County', 'WY', 11668, 11668, 0)
# ('Campbell County', 'WY', 46133, 46133, 0)
# ('Carbon County', 'WY', 15885, 15885, 0)
# ('Converse County', 'WY', 13833, 13833, 0)
# ('Crook County', 'WY', 7083, 7083, 0)
# ('Fremont County', 'WY', 40123, 40123, 0)
# ('Goshen County', 'WY', 13249, 13249, 0)
# ('Hot Springs County', 'WY', 4812, 4812, 0)
# ('Johnson County', 'WY', 8569, 8569, 0)
# ('Laramie County', 'WY', 91738, 91738, 0)
# ('Lincoln County', 'WY', 18106, 18106, 0)
# ('Natrona County', 'WY', 75450, 75450, 0)
# ('Niobrara County', 'WY', 2484, 2484, 0)
# ('Park County', 'WY', 28205, 28205, 0)
# ('Platte County', 'WY', 8667, 8667, 0)
# ('Sheridan County', 'WY', 29116, 29116, 0)
# ('Sublette County', 'WY', 10247, 10247, 0)
# ('Sweetwater County', 'WY', 43806, 43806, 0)
# ('Teton County', 'WY', 21294, 21294, 0)
# ('Uinta County', 'WY', 21118, 21118, 0)
# ('Washakie County', 'WY', 8533, 8533, 0)
# ('Weston County', 'WY', 7208, 7208, 0)

# %% [markdown]
# ##### Finding Percentages
#
# Let's look at the percentage of the population that is Asian.
#
# We can calculate the percentage Asian, then sort by this value.

# %%
print_sql(conn, """
SELECT DISTINCT NAME,
       STUSAB AS "ST",
       (CAST (P0010006 AS FLOAT) / P0010001) * 100 AS "pct_asian"
FROM us_counties_2010
ORDER BY "pct_asian" DESC;
""")
# Out:
# >
# SELECT DISTINCT NAME,
#        STUSAB AS "ST",
#        (CAST (P0010006 AS FLOAT) / P0010001) * 100 AS "pct_asian"
# FROM us_counties_2010
# ORDER BY "pct_asian" DESC;
#
# ('Honolulu County', 'HI', 43.894977691099626)
# ('Aleutians East Borough', 'AK', 35.97580388411334)
# ('San Francisco County', 'CA', 33.27165361664608)
# ('Santa Clara County', 'CA', 32.02237037519322)
# ('Kauai County', 'HI', 31.32461880132954)
# ('Aleutians West Census Area', 'AK', 28.879697896061856)
# ('Maui County', 'HI', 28.801813555162305)
# ('Alameda County', 'CA', 26.125112645346434)
# ('San Mateo County', 'CA', 24.791948233073654)
# ('Queens County', 'NY', 22.942661613594165)
# ('Hawaii County', 'HI', 22.179717850215315)
# ('Middlesex County', 'NJ', 21.39794877620521)
# ('Kodiak Island Borough', 'AK', 19.570335491465567)
# ('Orange County', 'CA', 17.865865488108557)
# ('Fairfax County', 'VA', 17.533183079633844)
# ('Fort Bend County', 'TX', 16.975443092035018)
# ('Fairfax city', 'VA', 15.209395080877467)
# ('Loudoun County', 'VA', 14.739474434137767)
# ('Solano County', 'CA', 14.630186962917085)
# ('King County', 'WA', 14.60583280560922)
# ('Bergen County', 'NJ', 14.509631914583323)
# ('Contra Costa County', 'CA', 14.43902671528324)
# ('Sutter County', 'CA', 14.422031518836356)
# ('San Joaquin County', 'CA', 14.369055575173718)
# ('Howard County', 'MD', 14.358465262901232)
# ('Sacramento County', 'CA', 14.322858665283325)
# ('Somerset County', 'NJ', 14.113726023670248)
# ('Montgomery County', 'MD', 13.938485887194286)
# ('Los Angeles County', 'CA', 13.717478195731472)
# ('Hudson County', 'NJ', 13.389335073927974)
# ('Yolo County', 'CA', 12.970938366633641)
# ('Ramsey County', 'MN', 11.658737024221454)
# ('New York County', 'NY', 11.32196588251392)
# ('Collin County', 'TX', 11.21659225325018)
# ('San Diego County', 'CA', 10.858061850287838)
# ('Gwinnett County', 'GA', 10.591056237202308)
# ('Kings County', 'NY', 10.471353854753064)
# ('DuPage County', 'IL', 10.066701275132944)
# ('Fresno County', 'CA', 9.603632650867858)
# ('Arlington County', 'VA', 9.59942589354949)
# ('Falls Church city', 'VA', 9.422640285436264)
# ('Middlesex County', 'MA', 9.310384974901618)
# ('Manassas Park city', 'VA', 8.974987739087787)
# ('Morris County', 'NJ', 8.952091915917087)
# ('Champaign County', 'IL', 8.936199839865527)
# ('Mercer County', 'NJ', 8.93610867827335)
# ('Snohomish County', 'WA', 8.885726902507237)
# ('Clark County', 'NV', 8.652369304283521)
# ('Washington County', 'OR', 8.63774518132563)
# ('Norfolk County', 'MA', 8.61638220168443)
# ('Tompkins County', 'NY', 8.602457563703675)
# ('Jefferson County', 'IA', 8.460488036573057)
# ('Suffolk County', 'MA', 8.230901231678216)
# ('Anchorage Municipality', 'AK', 8.080157354039736)
# ('Washtenaw County', 'MI', 7.862444205330185)
# ('Kalawao County', 'HI', 7.777777777777778)
# ('Whitman County', 'WA', 7.754154011077363)
# ('Nassau County', 'NY', 7.634457407512474)
# ('Prince William County', 'VA', 7.541504768632993)
# ('Richmond County', 'NY', 7.501973417532481)
# ('Atlantic County', 'NJ', 7.501393193928953)
# ('Merced County', 'CA', 7.363766795807547)
# ('Ketchikan Gateway Borough', 'AK', 6.997106180900794)
# ('Napa County', 'CA', 6.757568652735851)
# ('Orange County', 'NC', 6.743596834104379)
# ('Yuba County', 'CA', 6.7382717760376964)
# ('Ventura County', 'CA', 6.734457402850418)
# ('Denton County', 'TX', 6.561587892800333)
# ('Henrico County', 'VA', 6.5329792952905335)
# ('Multnomah County', 'OR', 6.520846309296184)
# ('Montgomery County', 'PA', 6.4466403458544725)
# ('Charlottesville city', 'VA', 6.373778033352502)
# ('San Bernardino County', 'CA', 6.318905665754395)
# ('Philadelphia County', 'PA', 6.317471884121033)
# ('Lake County', 'IL', 6.305671095240396)
# ('Hennepin County', 'MN', 6.23945159120984)
# ('Forsyth County', 'GA', 6.22468107412071)
# ('Cook County', 'IL', 6.21159167801643)
# ('Tippecanoe County', 'IN', 6.210209514990161)
# ('Rockland County', 'NY', 6.189863549009102)
# ('Harris County', 'TX', 6.1828841779477814)
# ('Juneau City and Borough', 'AK', 6.135891286970423)
# ('Virginia Beach city', 'VA', 6.1117275579117525)
# ('Moore County', 'TX', 6.103907962016071)
# ('Broomfield County', 'CO', 6.096011737551218)
# ('Monterey County', 'CA', 6.085429230202117)
# ('Alexandria city', 'VA', 6.02432019204664)
# ('Story County', 'IA', 6.011704004824551)
# ('Pierce County', 'WA', 5.973278003080889)
# ('Los Alamos County', 'NM', 5.9665738161559885)
# ('Riverside County', 'CA', 5.95841966788163)
# ('Sitka City and Borough', 'AK', 5.956536426078144)
# ('Placer County', 'CA', 5.86484593837535)
# ('Travis County', 'TX', 5.792733528204588)
# ('Williamsburg city', 'VA', 5.74353141882286)
# ('Scott County', 'MN', 5.654670278923712)
# ('Oakland County', 'MI', 5.641229513241437)
# ('Buena Vista County', 'IA', 5.631786771964462)
# ('Fulton County', 'GA', 5.601788435781317)
# ('Brazoria County', 'TX', 5.500916446868434)
# ('Nobles County', 'MN', 5.4635606698475065)
# ('Marin County', 'CA', 5.451865820949332)
# ('Westchester County', 'NY', 5.448877004108047)
# ('Montgomery County', 'VA', 5.415713196033562)
# ('Olmsted County', 'MN', 5.411513504519993)
# ('Wake County', 'NC', 5.388832099694448)
# ('Alachua County', 'FL', 5.351020474172785)
# ('Marathon County', 'WI', 5.330329770331859)
# ('Monroe County', 'IN', 5.2285213156101875)
# ('Johnson County', 'IA', 5.210036521446799)
# ('Ingham County', 'MI', 5.197315722956977)
# ('Centre County', 'PA', 5.186051042275473)
# ('Benton County', 'OR', 5.175335070519637)
# ('Brazos County', 'TX', 5.174723250073133)
# ('Washoe County', 'NV', 5.170773148049273)
# ('Thurston County', 'WA', 5.167998604636413)
# ('DeKalb County', 'GA', 5.120155862250377)
# ('Camden County', 'NJ', 5.111776925068674)
# ('Arapahoe County', 'CO', 5.08336494738664)
# ('Stanislaus County', 'CA', 5.071405939901216)
# ('Washington County', 'MN', 5.06895219538415)
# ('Dallas County', 'TX', 5.035599683971253)
# ('Passaic County', 'NJ', 5.006124981545251)
# ('Clayton County', 'GA', 4.98681694831627)
# ('Manassas city', 'VA', 4.981359562148013)
# ('Baltimore County', 'MD', 4.978329973205934)
# ('Monmouth County', 'NJ', 4.958596402170119)
# ('Orange County', 'FL', 4.9374496053949715)
# ('Kitsap County', 'WA', 4.936029912436836)
# ('York County', 'VA', 4.895820603690578)
# ('Santa Barbara County', 'CA', 4.875028014012904)
# ('Williamson County', 'TX', 4.834164933673072)
# ('Hamilton County', 'IN', 4.7984295386587705)
# ('Albany County', 'NY', 4.792507659333868)
# ('Dane County', 'WI', 4.719580882368007)
# ('Delaware County', 'PA', 4.700892162317368)
# ('Tarrant County', 'TX', 4.674373173749084)
# ('Albemarle County', 'VA', 4.673133272708902)
# ('Union County', 'NJ', 4.629831556070002)
# ('Fairfield County', 'CT', 4.611983259691829)
# ('Mecklenburg County', 'NC', 4.605340420256886)
# ('Sheboygan County', 'WI', 4.59712398382782)
# ('Durham County', 'NC', 4.588414235370179)
# ('Essex County', 'NJ', 4.5651039773256334)
# ('Will County', 'IL', 4.550593305389929)
# ('Hampshire County', 'MA', 4.545167004048583)
# ('North Slope Borough', 'AK', 4.506892895015906)
# ('Cobb County', 'GA', 4.455454178160034)
# ('Calhoun County', 'TX', 4.433843131752491)
# ('Island County', 'WA', 4.381830688100273)
# ('Dakota County', 'MN', 4.378600533932837)
# ('New Castle County', 'DE', 4.3270025386319615)
# ('Burlington County', 'NJ', 4.322159675888165)
# ('Delaware County', 'OH', 4.2683136831712725)
# ('McLean County', 'IL', 4.261906446819051)
# ('Hartford County', 'CT', 4.245794808582416)
# ('Santa Cruz County', 'CA', 4.235046611429138)
# ('Riley County', 'KS', 4.212894607326162)
# ('Johnson County', 'KS', 4.179323347648476)
# ('Clarke County', 'GA', 4.171736038521514)
# ('Duval County', 'FL', 4.153943880508596)
# ('New London County', 'CT', 4.153545821094306)
# ('Kern County', 'CA', 4.150156437768496)
# ('La Crosse County', 'WI', 4.136499241089342)
# ('Boulder County', 'CO', 4.118927103171774)
# ('Butte County', 'CA', 4.116818181818182)
# ('Clark County', 'WA', 4.115073478417258)
# ('Sedgwick County', 'KS', 4.090375527976483)
# ('Yakutat City and Borough', 'AK', 4.078549848942599)
# ("Prince George's County", 'MD', 4.073567904380256)
# ('Sebastian County', 'AR', 4.057450057259193)
# ('Worcester County', 'MA', 3.984086196014787)
# ('Potter County', 'TX', 3.9827211682208254)
# ('Guilford County', 'NC', 3.9262416923625016)
# ('Warren County', 'OH', 3.894815532246007)
# ('Anoka County', 'MN', 3.8894463856077186)
# ('Fayette County', 'GA', 3.8754961667307892)
# ('Chester County', 'PA', 3.8678174973841717)
# ('Franklin County', 'OH', 3.8675828209046825)
# ('Jefferson Parish', 'LA', 3.856877323420074)
# ('Bucks County', 'PA', 3.839750243502989)
# ('Columbia County', 'GA', 3.8378757466566706)
# ('Frederick County', 'MD', 3.8331512307988946)
# ('Cleveland County', 'OK', 3.791910226584035)
# ('Sonoma County', 'CA', 3.7904182459214923)
# ('Boone County', 'MO', 3.7776220164533143)
# ('Douglas County', 'CO', 3.7538752561610003)
# ('Douglas County', 'KS', 3.740999404471875)
# ('Seminole County', 'FL', 3.7121674496945958)
# ('Valdez-Cordova Census Area', 'AK', 3.6737235367372354)
# ('Kings County', 'CA', 3.673634806709286)
# ('Providence County', 'RI', 3.6711682600168825)
# ('Clackamas County', 'OR', 3.651407476754825)
# ('Beadle County', 'SD', 3.6326014484423497)
# ('Adams County', 'CO', 3.607538898060022)
# ('Bronx County', 'NY', 3.581597969255827)
# ('Polk County', 'IA', 3.5342745680847107)
# ('Whatcom County', 'WA', 3.524908024261708)
# ('Broome County', 'NY', 3.5219341974077762)
# ('Harrisonburg city', 'VA', 3.512286870834526)
# ('New Haven County', 'CT', 3.508847192446871)
# ('Dutchess County', 'NY', 3.508376808476308)
# ('Burke County', 'NC', 3.503387891587469)
# ('District of Columbia', 'DC', 3.499284554520934)
# ('Lancaster County', 'NE', 3.4901036064287143)
# ('El Dorado County', 'CA', 3.477891062532448)
# ('Payne County', 'OK', 3.475113122171946)
# ('Kane County', 'IL', 3.4729432587638693)
# ('Catawba County', 'NC', 3.467264411303593)
# ('Maricopa County', 'AZ', 3.4640017583951446)
# ('St. Louis County', 'MO', 3.463322635476709)
# ('Barrow County', 'GA', 3.433909495869794)
# ('Tulare County', 'CA', 3.432094242376956)
# ('Bartholomew County', 'IN', 3.4273510951376407)
# ('Hillsborough County', 'FL', 3.4229669727129104)
# ('Milwaukee County', 'WI', 3.420998485863665)
# ('Jefferson County', 'TX', 3.420897202633655)
# ('Scott County', 'AR', 3.418499065254162)
# ('Anne Arundel County', 'MD', 3.413334920469594)
# ('Suffolk County', 'NY', 3.413265476947802)
# ('Denver County', 'CO', 3.4046034544236687)
# ('Del Norte County', 'CA', 3.3729465221950368)
# ('Finney County', 'KS', 3.3636067000217533)
# ('Tolland County', 'CT', 3.3623461762644817)
# ('Eau Claire County', 'WI', 3.3392075838599906)
# ('Colonial Heights city', 'VA', 3.319740394003791)
# ('Salt Lake County', 'UT', 3.300814350437768)
# ('Norfolk city', 'VA', 3.294440348760106)
# ('Monroe County', 'NY', 3.2620670012789788)
# ('Hunterdon County', 'NJ', 3.257524406111462)
# ('Chesterfield County', 'VA', 3.2551638649616113)
# ('Broward County', 'FL', 3.249019201792152)
# ('Hillsborough County', 'NH', 3.232673106725128)
# ('Fayette County', 'KY', 3.2295142375161845)
# ('Schenectady County', 'NY', 3.2056460734067103)
# ('Geary County', 'KS', 3.2041208311506897)
# ('Dauphin County', 'PA', 3.200298396120851)
# ('Plaquemines Parish', 'LA', 3.1724676677371755)
# ('Jackson County', 'IL', 3.17180909362649)
# ('Redwood County', 'MN', 3.1571081636465532)
# ('San Luis Obispo County', 'CA', 3.1549824393536494)
# ('Peoria County', 'IL', 3.140047400988772)
# ('Essex County', 'MA', 3.1244996023731124)
# ('Oconee County', 'GA', 3.1150938795415755)
# ('Onondaga County', 'NY', 3.094902639253489)
# ('Monongalia County', 'WV', 3.0575221698946864)
# ('Rutherford County', 'TN', 3.0403192639868393)
# ('Davidson County', 'TN', 3.0361539603083543)
# ('Kendall County', 'IL', 3.0217194254636732)
# ('Canadian County', 'OK', 3.014514328247116)
# ('Williamson County', 'TN', 3.0117587972617397)
# ('Cumberland County', 'PA', 3.004171516443931)
# ('Dakota County', 'NE', 3.0039036465771685)
# ('Oklahoma County', 'OK', 2.985390317449936)
# ('Galveston County', 'TX', 2.9830866880185645)
# ('Macomb County', 'MI', 2.980220647864748)
# ('Charles County', 'MD', 2.9791676617696226)
# ('Pinellas County', 'FL', 2.9620028323852043)
# ('Outagamie County', 'WI', 2.959336710150259)
# ('Grafton County', 'NH', 2.9545097511164973)
# ('Okaloosa County', 'FL', 2.9465441152072205)
# ('Lehigh County', 'PA', 2.9319278849317736)
# ('Clay County', 'FL', 2.928247714353077)
# ('Henry County', 'GA', 2.926609193711321)
# ('Leon County', 'FL', 2.9231869380406335)
# ('Phelps County', 'MO', 2.9143413942776153)
# ('Greene County', 'OH', 2.910758604469806)
# ('St. Louis city', 'MO', 2.9098573728288035)
# ('Orleans Parish', 'LA', 2.899697233217675)
# ('Houghton County', 'MI', 2.877579993447636)
# ('Chesapeake city', 'VA', 2.872520914994442)
# ('Benton County', 'AR', 2.8548967872810485)
# ('Harrison County', 'MS', 2.8443921862056065)
# ('Elmore County', 'ID', 2.840446778607885)
# ('Fredericksburg city', 'VA', 2.83702544675945)
# ('Bell County', 'TX', 2.8197978951440037)
# ('Albany County', 'WY', 2.8127496625251385)
# ('Portage County', 'WI', 2.812093860237935)
# ('Chittenden County', 'VT', 2.8100546168833245)
# ('East Baton Rouge Parish', 'LA', 2.809589909376129)
# ('Stafford County', 'VA', 2.8070501934693435)
# ('Warren County', 'KY', 2.798087739032621)
# ('Oneida County', 'NY', 2.795068077895759)
# ('Allegheny County', 'PA', 2.786615092353116)
# ('Osceola County', 'FL', 2.756387591417459)
# ('Waukesha County', 'WI', 2.7497428768553265)
# ('Escambia County', 'FL', 2.7464644394343103)
# ('Newport News city', 'VA', 2.7423790525622653)
# ('El Paso County', 'CO', 2.740802522406121)
# ('Allen County', 'IN', 2.735774451283177)
# ('Union County', 'OH', 2.730401529636711)
# ('Carver County', 'MN', 2.7218206981393203)
# ('Brookings County', 'SD', 2.7185984670733614)
# ('Cottonwood County', 'MN', 2.712415504406606)
# ('Brown County', 'WI', 2.7112137963847793)
# ('Athens County', 'OH', 2.6977778464104265)
# ('Benton County', 'WA', 2.6778629614618357)
# ('Churchill County', 'NV', 2.673151907384331)
# ('Roanoke County', 'VA', 2.6695245518316444)
# ('Seward County', 'KS', 2.6620773788776577)
# ('Douglas County', 'NE', 2.659975633810988)
# ('Fairbanks North Star Borough', 'AK', 2.6552300140396183)
# ('Gloucester County', 'NJ', 2.639374514374514)
# ('Jefferson County', 'CO', 2.6259814458331694)
# ('Lyon County', 'MN', 2.6259813590130334)
# ('Pima County', 'AZ', 2.6249078053542774)
# ('Petersburg Census Area', 'AK', 2.621231979030144)
# ('San Benito County', 'CA', 2.6108668512185855)
# ('Lee County', 'AL', 2.608255435053869)
# ('Dunn County', 'WI', 2.6061974143238253)
# ('Strafford County', 'NH', 2.5912962978001186)
# ('Erie County', 'NY', 2.5884618732590527)
# ('Pulaski County', 'MO', 2.5748938286719976)
# ('Cuyahoga County', 'OH', 2.568739542012402)
# ('Glenn County', 'CA', 2.567384965507432)
# ('Middlesex County', 'CT', 2.5634370699437454)
# ('Ottawa County', 'MI', 2.5541980508034463)
# ('McHenry County', 'IL', 2.528501101178909)
# ('Wayne County', 'MI', 2.5219929429238093)
# ('Manitowoc County', 'WI', 2.5171287542054466)
# ('Dallas County', 'IA', 2.513041506010433)
# ('Wyandotte County', 'KS', 2.512936097266753)
# ('Roseau County', 'MN', 2.508157911574637)
# ('Wicomico County', 'MD', 2.502709327175311)
# ('Shasta County', 'CA', 2.477669376999599)
# ('Lynchburg city', 'VA', 2.47194579716282)
# ("St. Mary's County", 'MD', 2.4688305389392395)
# ('Madison County', 'AL', 2.4685568873185173)
# ('Warren County', 'NJ', 2.459242630552387)
# ('Bexar County', 'TX', 2.434083111875449)
# ('Houston County', 'GA', 2.4324517512508934)
# ('Oktibbeha County', 'MS', 2.424954374777118)
# ('Rockwall County', 'TX', 2.421588776695559)
# ('Northampton County', 'PA', 2.419265454179052)
# ('Ada County', 'ID', 2.397512520229888)
# ('Iberia Parish', 'LA', 2.3948661933369744)
# ('Butler County', 'OH', 2.3934479667508763)
# ('Orange County', 'NY', 2.3859146542636656)
# ('Chatham County', 'GA', 2.380359675326635)
# ('Harford County', 'MD', 2.3796492202625537)
# ('Woodbury County', 'IA', 2.371491210899268)
# ('Lane County', 'OR', 2.366120296262599)
# ('Cass County', 'ND', 2.3581567386398534)
# ('Palm Beach County', 'FL', 2.355821454488711)
# ('Bernalillo County', 'NM', 2.343169867363757)
# ('Baltimore city', 'MD', 2.3428202415288557)
# ('Kleberg County', 'TX', 2.3424097813542932)
# ('Kent County', 'MI', 2.331975931844506)
# ('Winchester city', 'VA', 2.3317940693813686)
# ('Tulsa County', 'OK', 2.331112042863559)
# ('Richmond city', 'VA', 2.325991362002605)
# ('DeKalb County', 'IL', 2.3183720045644733)
# ('Lyon County', 'KS', 2.318195310181063)
# ('Spotsylvania County', 'VA', 2.308063106121882)
# ('Winnebago County', 'IL', 2.306394911706732)
# ('Shelby County', 'TN', 2.3059492650197706)
# ('Platte County', 'MO', 2.296186829672421)
# ('Winnebago County', 'WI', 2.2887049834125777)
# ('Henry County', 'IA', 2.288409034499876)
# ('Berkeley County', 'SC', 2.2750403445735845)
# ('James City County', 'VA', 2.2474592965124085)
# ('Comanche County', 'OK', 2.237747586584796)
# ('Habersham County', 'GA', 2.230431449083432)
# ('Richland County', 'SC', 2.223123816657304)
# ('Cumberland County', 'NC', 2.2195716758861854)
# ('Rensselaer County', 'NY', 2.20599765412817)
# ('Jefferson County', 'KY', 2.204572686939344)
# ('Lexington city', 'VA', 2.2010792388525986)
# ('Summit County', 'OH', 2.1936908086477747)
# ('Humboldt County', 'CA', 2.1868477154720964)
# ('Chattahoochee County', 'GA', 2.183367355995385)
# ('Lee County', 'GA', 2.1803661036115627)
# ('St. Charles County', 'MO', 2.1776218150547177)
# ('Hampton city', 'VA', 2.1770133007363426)
# ('Washington County', 'AR', 2.174673134218107)
# ('Muscogee County', 'GA', 2.1739473892092582)
# ('Jackson County', 'MS', 2.164418478105221)
# ('Madison County', 'MS', 2.1427896179742234)
# ('Poquoson city', 'VA', 2.139917695473251)
# ('Winona County', 'MN', 2.1394842696410876)
# ('Flagler County', 'FL', 2.138020397926768)
# ('Carson City', 'NV', 2.136628432897927)
# ('Boone County', 'KY', 2.1327991515937077)
# ('Frio County', 'TX', 2.1316141023407096)
# ('Lafayette County', 'MS', 2.1245591434183018)
# ('Spokane County', 'WA', 2.113021278763043)
# ('Sarpy County', 'NE', 2.110929236968018)
# ('Pasco County', 'FL', 2.1080402929220545)
# ('Calumet County', 'WI', 2.1053276428906904)
# ('Montgomery County', 'AL', 2.1019083287191047)
# ('Latah County', 'ID', 2.09698206422511)
# ('Montgomery County', 'TX', 2.0945877747692796)
# ('Brevard County', 'FL', 2.0886089926680604)
# ('Kalamazoo County', 'MI', 2.0820433745720663)
# ('Hendricks County', 'IN', 2.0818436829657334)
# ('Saline County', 'KS', 2.07891234758839)
# ('Montgomery County', 'TN', 2.071594779813266)
# ('Lubbock County', 'TX', 2.0632569549296886)
# ('St. Johns County', 'FL', 2.062734491341251)
# ('Monroe County', 'PA', 2.051318284052237)
# ('Clay County', 'MO', 2.0505634431082416)
# ('Rice County', 'MN', 2.0485797137600947)
# ('Cumberland County', 'ME', 2.048112356838047)
# ('Pacific County', 'WA', 2.041108986615679)
# ('Kent County', 'DE', 2.0368430780605014)
# ('Kent County', 'RI', 2.0330047304372947)
# ('Wichita County', 'TX', 2.029657794676806)
# ('Craven County', 'NC', 2.02792135645621)
# ('Marion County', 'IN', 2.027246170824879)
# ('Spartanburg County', 'SC', 2.0210547049492273)
# ('Hamilton County', 'OH', 2.016765249123227)
# ('Scott County', 'IA', 2.0166561758582287)
# ('Vermilion Parish', 'LA', 2.0000344833531614)
# ('Hardin County', 'KY', 1.993500279506931)
# ('Pike County', 'AL', 1.9879023678531262)
# ('Bay County', 'FL', 1.985762679743207)
# ('Hamilton County', 'IA', 1.984304217444012)
# ('Kittitas County', 'WA', 1.9797140413051448)
# ('Stearns County', 'MN', 1.9795276217787867)
# ('Cabarrus County', 'NC', 1.9734735493873972)
# ('Hampden County', 'MA', 1.9672484843254439)
# ('Liberty County', 'GA', 1.9652341102863538)
# ('Johnson County', 'IN', 1.9648560012602574)
# ('Aransas County', 'TX', 1.9647637965281974)
# ('Greenville County', 'SC', 1.961105878442019)
# ('Pulaski County', 'AR', 1.9608201741093356)
# ('Matagorda County', 'TX', 1.959021306740777)
# ('Blue Earth County', 'MN', 1.9511661693718465)
# ('Larimer County', 'CO', 1.9357207222240764)
# ('Grand Forks County', 'ND', 1.932367149758454)
# ('Cochise County', 'AZ', 1.9224034230201148)
# ('St. Bernard Parish', 'LA', 1.9221661977324012)
# ('Shelby County', 'AL', 1.9099366942614757)
# ('Polk County', 'OR', 1.9031073034229407)
# ('Marion County', 'OR', 1.901152742321658)
# ('Lancaster County', 'PA', 1.8981797880430074)
# ('Coryell County', 'TX', 1.8875683132594048)
# ('Putnam County', 'NY', 1.8874736736535953)
# ('Onslow County', 'NC', 1.8872488355871564)
# ('St. Joseph County', 'IN', 1.8866298781333006)
# ('Cache County', 'UT', 1.8836102826303083)
# ('Knox County', 'TN', 1.872862807882913)
# ('Bristol County', 'MA', 1.8680066024056832)
# ('Midland County', 'MI', 1.8605985961807507)
# ('Madera County', 'CA', 1.857289629801478)
# ('Morton County', 'KS', 1.8558614290133002)
# ('Forsyth County', 'NC', 1.852168705620669)
# ('Stanly County', 'NC', 1.8453412560864901)
# ('Franklin County', 'WA', 1.8346276371173063)
# ('Iredell County', 'NC', 1.8326988089339362)
# ('Mobile County', 'AL', 1.8307860684952735)
# ('Santa Rosa County', 'FL', 1.8226620511058846)
# ('Tyrrell County', 'NC', 1.8152938506920808)
# ('Linn County', 'IA', 1.8018615132606781)
# ('Hall County', 'GA', 1.7953741011998843)
# ('Montour County', 'PA', 1.7846389664422182)
# ('Saratoga County', 'NY', 1.784551494260201)
# ('Skagit County', 'WA', 1.779283325206799)
# ('Rockdale County', 'GA', 1.7790295135832894)
# ('McDonough County', 'IL', 1.7784864467067336)
# ('Sussex County', 'NJ', 1.7700063645194788)
# ('Adair County', 'MO', 1.7690475260670908)
# ('Davis County', 'UT', 1.7671683867410164)
# ('Calloway County', 'KY', 1.7665564249415182)
# ('Wood County', 'WI', 1.7645721012990139)
# ('Hamilton County', 'TN', 1.7571025640263565)
# ('Roanoke city', 'VA', 1.75612169181301)
# ('Vernon Parish', 'LA', 1.756028585623113)
# ('Ocean County', 'NJ', 1.74845247820288)
# ('Ozaukee County', 'WI', 1.7466288558365646)
# ('Lake County', 'FL', 1.7414459421246111)
# ('St. Mary Parish', 'LA', 1.7346752058554435)
# ('Montgomery County', 'OH', 1.7327754866365321)
# ('Pinal County', 'AZ', 1.7276525534236369)
# ('Garfield County', 'WA', 1.7210944395410415)
# ('Jackson County', 'GA', 1.7078614532528724)
# ('Ulster County', 'NY', 1.7019830897623471)
# ('Lackawanna County', 'PA', 1.699333603809044)
# ('Lincoln Parish', 'LA', 1.6903819407296456)
# ('Hancock County', 'OH', 1.68890909577171)
# ('Nueces County', 'TX', 1.684483412350135)
# ('Malheur County', 'OR', 1.6830070577715326)
# ('Eaton County', 'MI', 1.6787460908137604)
# ('Rockingham County', 'NH', 1.6743275422307882)
# ('Clay County', 'SD', 1.673398730525101)
# ('Boone County', 'IN', 1.663135593220339)
# ('Richmond County', 'GA', 1.6609407177298314)
# ('Mower County', 'MN', 1.657176416515589)
# ('Vigo County', 'IN', 1.6513982642237222)
# ('Mendocino County', 'CA', 1.6507098052162428)
# ('Cherokee County', 'GA', 1.650602297220382)
# ('Greene County', 'MO', 1.6480481440833799)
# ('Bossier Parish', 'LA', 1.647304216996213)
# ('Storey County', 'NV', 1.6458852867830425)
# ('Rock Island County', 'IL', 1.6394887018285822)
# ('Manatee County', 'FL', 1.6339717439047434)
# ('Isabella County', 'MI', 1.6327459430245623)
# ('Sangamon County', 'IL', 1.6306687261033601)
# ('Washington County', 'RI', 1.6294032871577189)
# ('Imperial County', 'CA', 1.6289649798313166)
# ('Bibb County', 'GA', 1.6271609224221617)
# ('Union County', 'NC', 1.6250024839536594)
# ('Polk County', 'FL', 1.6210066517742217)
# ('Salem city', 'VA', 1.6208370292718328)
# ('Nodaway County', 'MO', 1.6174582798459562)
# ('Logan County', 'AR', 1.614995750011184)
# ('Cowley County', 'KS', 1.6138360276500234)
# ('Warrick County', 'IN', 1.6083365444219202)
# ('Bryan County', 'GA', 1.6075149670889424)
# ('Pickens County', 'SC', 1.604542709521573)
# ('Calhoun County', 'MI', 1.6004877117212404)
# ('Suffolk city', 'VA', 1.5960276644795177)
# ('Jackson County', 'MO', 1.5953233514992036)
# ('Columbia County', 'NY', 1.588056295169266)
# ('Merrimack County', 'NH', 1.5876267540714943)
# ('Montgomery County', 'NC', 1.586445067990503)
# ('Saline County', 'NE', 1.584507042253521)
# ('Troup County', 'GA', 1.5810512499254221)
# ('Cheyenne County', 'NE', 1.5803160632126425)
# ('Taylor County', 'TX', 1.5763539306191354)
# ('Texas County', 'OK', 1.574612403100775)
# ('Berrien County', 'MI', 1.5630081689655833)
# ('Radford city', 'VA', 1.5602145294978058)
# ('St. Lucie County', 'FL', 1.5601769688504585)
# ('Pitt County', 'NC', 1.5539881532935271)
# ('Newport County', 'RI', 1.553904063314352)
# ('Jefferson County', 'WA', 1.553294054633101)
# ('Wood County', 'OH', 1.5483552212163714)
# ('Douglas County', 'NV', 1.5426516586165073)
# ('Litchfield County', 'CT', 1.5311145861304605)
# ('Lucas County', 'OH', 1.5309575274719056)
# ('Volusia County', 'FL', 1.5299448233193758)
# ('Johnson County', 'MO', 1.524859777545394)
# ('Prince George County', 'VA', 1.5199440167949616)
# ('Coweta County', 'GA', 1.519043018607099)
# ('York County', 'SC', 1.5096893481309135)
# ('Miami-Dade County', 'FL', 1.5089117080957444)
# ('Lafayette Parish', 'LA', 1.5033080901533546)
# ('Dorchester County', 'SC', 1.5026912233166123)
# ('Stevens County', 'MN', 1.5011309891013778)
# ('Yamhill County', 'OR', 1.4859919550774752)
# ('Minnehaha County', 'SD', 1.4805154955507824)
# ('Clinton County', 'MI', 1.4791329495104932)
# ('Cowlitz County', 'WA', 1.4647007128210134)
# ('Camden County', 'NC', 1.4629258517034067)
# ('Sandoval County', 'NM', 1.4609192693883446)
# ('Highlands County', 'FL', 1.4566841455266941)
# ('Lowndes County', 'GA', 1.4565195499528532)
# ('Bulloch County', 'GA', 1.452639674152983)
# ('Carroll County', 'MD', 1.446743331697919)
# ('Addison County', 'VT', 1.4448276798566035)
# ('Ford County', 'KS', 1.4446939257858662)
# ('Crawford County', 'AR', 1.4415316071543876)
# ('Douglas County', 'GA', 1.4380338814075209)
# ('Kenosha County', 'WI', 1.4378762933676228)
# ('Bristol County', 'RI', 1.4355889724310777)
# ('Clay County', 'MN', 1.4339226088577772)
# ('Camden County', 'GA', 1.4332943994615246)
# ('Portage County', 'OH', 1.4279607728953843)
# ('Franklin County', 'KY', 1.4263974840215075)
# ('Lexington County', 'SC', 1.4211615489860552)
# ('Calvert County', 'MD', 1.4199262990635249)
# ('Grays Harbor County', 'WA', 1.4176408368476723)
# ('Gilpin County', 'CO', 1.4151810328983643)
# ('Norton city', 'VA', 1.414855987872663)
# ('Guadalupe County', 'TX', 1.4148540670402106)
# ('Citrus County', 'FL', 1.4132374182219831)
# ('Clallam County', 'WA', 1.410285138087502)
# ('Adams County', 'NE', 1.4060706542532841)
# ('Hood River County', 'OR', 1.4051731853575584)
# ('Greene County', 'VA', 1.4019453349997282)
# ('Randall County', 'TX', 1.3949057775937046)
# ('Lyon County', 'NV', 1.394767218160831)
# ('Washington County', 'MD', 1.3945601302312962)
# ('Wrangell City and Borough', 'AK', 1.3929928239763614)
# ('Jefferson County', 'AL', 1.390808333308022)
# ('Sullivan County', 'NY', 1.3862560769597794)
# ('Wagoner County', 'OK', 1.3764794417459123)
# ('Poweshiek County', 'IA', 1.3746431214973036)
# ('Ellis County', 'KS', 1.3742443413468297)
# ('Coconino County', 'AZ', 1.3732973270545523)
# ('McLennan County', 'TX', 1.370761070385601)
# ('Lee County', 'FL', 1.3674255035118965)
# ('Jackson County', 'MN', 1.3637249172024157)
# ('Utah County', 'UT', 1.3613027620972427)
# ('Johnson County', 'NE', 1.360935403488595)
# ('Crenshaw County', 'AL', 1.35912555731339)
# ('Hanover County', 'VA', 1.3528534091705635)
# ('Mono County', 'CA', 1.351922264469793)
# ('Charleston County', 'SC', 1.3474810755862927)
# ('Marion County', 'FL', 1.3302223375933449)
# ('Newton County', 'MO', 1.3249819320645628)
# ('Floyd County', 'IA', 1.3249095258541372)
# ('Macon County', 'GA', 1.322930800542741)
# ('Guadalupe County', 'NM', 1.322807766161724)
# ('Oldham County', 'KY', 1.3213740964254923)
# ('Washington County', 'TX', 1.319769855863337)
# ('Marshall County', 'IA', 1.3186380633733517)
# ('Nicollet County', 'MN', 1.316955419072937)
# ('Colusa County', 'CA', 1.3119193239647042)
# ('Barry County', 'MO', 1.3119083068797932)
# ('Inyo County', 'CA', 1.3102555807182141)
# ('Berks County', 'PA', 1.308811448515222)
# ('Jefferson County', 'NY', 1.3060423818496245)
# ('Bannock County', 'ID', 1.3025265877183452)
# ('Black Hawk County', 'IA', 1.302158822183233)
# ('Nye County', 'NV', 1.3015974150093297)
# ('Floyd County', 'GA', 1.3009126114808394)
# ('Culpeper County', 'VA', 1.3000920987812974)
# ('Whitfield County', 'GA', 1.296308930886266)
# ('Yell County', 'AR', 1.293666892044174)
# ('Buffalo County', 'NE', 1.2927855624484836)
# ('Sarasota County', 'FL', 1.2921401614977548)
# ('Curry County', 'NM', 1.2919629568381017)
# ('Walla Walla County', 'WA', 1.2895323318759464)
# ('Coffee County', 'AL', 1.2893409145511332)
# ('Pershing County', 'NV', 1.288316303864949)
# ('Sumter County', 'GA', 1.282793503763064)
# ('Fauquier County', 'VA', 1.2821495943438186)
# ('Sherburne County', 'MN', 1.2779805421530188)
# ('Tift County', 'GA', 1.2762351064360138)
# ('Baldwin County', 'GA', 1.2729658792650917)
# ('St. Tammany Parish', 'LA', 1.2714982459142636)
# ('Cole County', 'MO', 1.2712198973549151)
# ('Boone County', 'IL', 1.2665005077079294)
# ('Leavenworth County', 'KS', 1.2659556325186614)
# ('DeSoto County', 'MS', 1.2607595564706173)
# ('Weber County', 'UT', 1.2588870245117543)
# ('Franklin County', 'MA', 1.2539931625847671)
# ('Midland County', 'TX', 1.2529954994447368)
# ('Calaveras County', 'CA', 1.2527974022554742)
# ('Delaware County', 'OK', 1.250994287367127)
# ('Talbot County', 'MD', 1.2492721401725688)
# ('York County', 'PA', 1.2430685193529698)
# ('Chippewa County', 'WI', 1.240086517664023)
# ('Smith County', 'TX', 1.238353185767283)
# ('Lake County', 'IN', 1.2382939688107983)
# ('Frederick County', 'VA', 1.237468871719558)
# ('Nacogdoches County', 'TX', 1.2351993056847064)
# ('Clatsop County', 'OR', 1.2338346067658414)
# ('Matanuska-Susitna Borough', 'AK', 1.2315298612281589)
# ('Summit County', 'UT', 1.2278383437947362)
# ('Berkshire County', 'MA', 1.2277185468567815)
# ('Socorro County', 'NM', 1.2257920071644466)
# ('Catoosa County', 'GA', 1.2245472459416344)
# ('Davidson County', 'NC', 1.2242291776667198)
# ('Florence County', 'SC', 1.2207327318552068)
# ('Crawford County', 'KS', 1.2163336229365769)
# ('Alamance County', 'NC', 1.215501783221179)
# ('Cumberland County', 'NJ', 1.2154393300105801)
# ('Porter County', 'IN', 1.213316052402597)
# ('St. Clair County', 'IL', 1.2130817311964925)
# ('Pitkin County', 'CO', 1.2071378586424073)
# ('Plymouth County', 'MA', 1.2070662067934348)
# ('Indian River County', 'FL', 1.2070014779609934)
# ('Stark County', 'ND', 1.2066614322905904)
# ('Mason County', 'WA', 1.2043032010412034)
# ('Siskiyou County', 'CA', 1.2026726057906458)
# ('Gaston County', 'NC', 1.202410644100036)
# ('Nevada County', 'CA', 1.20185492689644)
# ('Livingston County', 'NY', 1.200434297248941)
# ('Weld County', 'CO', 1.1952931869870465)
# ('Charlotte County', 'FL', 1.1951643350960757)
# ('Cheshire County', 'NH', 1.194289196934528)
# ('Twin Falls County', 'ID', 1.1938365919979284)
# ('Washington County', 'TN', 1.1920734434334317)
# ('Chemung County', 'NY', 1.189913317572892)
# ('New Hanover County', 'NC', 1.1891427810151627)
# ('Miami County', 'OH', 1.18822312840224)
# ('Yuma County', 'AZ', 1.1872225429244294)
# ('Cape Girardeau County', 'MO', 1.1866691333879535)
# ('Wright County', 'MN', 1.185244587008821)
# ('Tuscaloosa County', 'AL', 1.1846539536412954)
# ('Rapides Parish', 'LA', 1.1845334427450176)
# ('Jackson County', 'OK', 1.179762534976934)
# ('Garfield County', 'UT', 1.1794276875483374)
# ('Lamar County', 'MS', 1.1786266125265012)
# ('Otero County', 'NM', 1.1740363966957694)
# ('Steuben County', 'NY', 1.1728457419941407)
# ('Windham County', 'CT', 1.1720201303745736)
# ('Shawnee County', 'KS', 1.1717827958681308)
# ('Putnam County', 'TN', 1.1697847098353176)
# ('Wayne County', 'NC', 1.1669915105649022)
# ('Beaufort County', 'SC', 1.164374695653782)
# ('Jackson County', 'OR', 1.1633514758422487)
# ('Belknap County', 'NH', 1.1632938357076288)
# ('King George County', 'VA', 1.1618046132971505)
# ('Union County', 'PA', 1.1613678332257993)
# ('Nantucket County', 'MA', 1.1600471883602046)
# ('Santa Fe County', 'NM', 1.159741971283901)
# ('Hays County', 'TX', 1.1590826634077411)
# ('Glynn County', 'GA', 1.1566573732198027)
# ('Jefferson County', 'WV', 1.1551833713409847)
# ('San Juan County', 'WA', 1.1478216754391528)
# ('Lebanon County', 'PA', 1.1477299952084332)
# ('Gallatin County', 'MT', 1.1473193837766582)
# ('San Juan County', 'CO', 1.144492131616595)
# ('Walton County', 'GA', 1.1412472543214593)
# ('Mahaska County', 'IA', 1.1393592779589832)
# ('Kenai Peninsula Borough', 'AK', 1.1389891696750902)
# ('Marion County', 'IA', 1.1378306163499354)
# ('Lake County', 'OH', 1.1350150625323312)
# ('Missoula County', 'MT', 1.130842917135564)
# ('Fond du Lac County', 'WI', 1.1295543770232108)
# ('Faulkner County', 'AR', 1.127723270662416)
# ('Fairfield County', 'OH', 1.1255097293303045)
# ('Lake County', 'CA', 1.1196164849609527)
# ('Wilson County', 'TN', 1.1193669786741292)
# ('Mariposa County', 'CA', 1.1177469727686156)
# ('Rankin County', 'MS', 1.1170975236023923)
# ('Pasquotank County', 'NC', 1.1165490273234795)
# ('Limestone County', 'AL', 1.1161846778285134)
# ('Craighead County', 'AR', 1.1146480304428523)
# ('Vanderburgh County', 'IN', 1.1146168956556095)
# ('Worcester County', 'MD', 1.1136160453997745)
# ('Mineral County', 'NV', 1.1106454316848282)
# ('Chatham County', 'NC', 1.1069994488622943)
# ('Monroe County', 'FL', 1.1068545628676973)
# ('Sumter County', 'SC', 1.1055687909469922)
# ('Benton County', 'MN', 1.105302852981717)
# ('Teton County', 'WY', 1.1035972574434112)
# ('Gregg County', 'TX', 1.1032613160272735)
# ('Amador County', 'CA', 1.0999973747079363)
# ('Erie County', 'PA', 1.0967116471703628)
# ('Clinton County', 'NY', 1.0934151568283654)
# ('Collier County', 'FL', 1.0907564070664344)
# ('Washington County', 'OK', 1.0867859384808538)
# ('Racine County', 'WI', 1.0854212724146401)
# ('Cecil County', 'MD', 1.084978438897021)
# ('Otsego County', 'NY', 1.0825744069130567)
# ('Moody County', 'SD', 1.0792476102374344)
# ('Hernando County', 'FL', 1.0759471691997824)
# ('Calcasieu Parish', 'LA', 1.075385956175299)
# ('Cass County', 'IN', 1.0752964122568394)
# ('Hardee County', 'FL', 1.0746096426382028)
# ('Winneshiek County', 'IA', 1.0733282674772038)
# ('Washington County', 'WI', 1.0728881542532622)
# ('Rogers County', 'OK', 1.0724354179851563)
# ('Anderson County', 'TN', 1.0688282820215895)
# ('Lincoln County', 'OR', 1.068775253073815)
# ('Anson County', 'NC', 1.068724951758943)
# ('St. Croix County', 'WI', 1.0670460608216255)
# ('Portsmouth city', 'VA', 1.0666247971947453)
# ('Doña Ana County', 'NM', 1.064363652005181)
# ('Carter County', 'OK', 1.0639863742456421)
# ('Laramie County', 'WY', 1.0638993655845996)
# ('Hunt County', 'TX', 1.0635209975734072)
# ('York County', 'ME', 1.0632523550329476)
# ('Dale County', 'AL', 1.06266541959364)
# ('Barnstable County', 'MA', 1.0593455866004595)
# ('Beaver County', 'UT', 1.0559662090813093)
# ('Saginaw County', 'MI', 1.0531101219469547)
# ('Martin County', 'FL', 1.0525020845008817)
# ('Yakima County', 'WA', 1.0524974201479254)
# ('Caddo Parish', 'LA', 1.0522847875624095)
# ('Weakley County', 'TN', 1.0507980925730276)
# ('Mohave County', 'AZ', 1.0505230135973544)
# ('Coos County', 'OR', 1.0469044937582284)
# ('Horry County', 'SC', 1.0457089171193987)
# ('Ontario County', 'NY', 1.0432591192521148)
# ('Pennington County', 'SD', 1.0421206958037803)
# ('Pike County', 'PA', 1.0406317000470637)
# ('Denali Borough', 'AK', 1.04052573932092)
# ('Windham County', 'VT', 1.0401455754498685)
# ('Goochland County', 'VA', 1.0360547036883547)
# ('Kanawha County', 'WV', 1.035931276319129)
# ('Victoria County', 'TX', 1.0357978177963663)
# ('Hall County', 'NE', 1.0357124575562646)
# ('El Paso County', 'TX', 1.0346632161239597)
# ('Dawes County', 'NE', 1.0346329775648007)
# ('Tehama County', 'CA', 1.033673163890771)
# ('Tuolumne County', 'CA', 1.033143682832114)
# ('Hoke County', 'NC', 1.030840006815471)
# ('Lincoln County', 'SD', 1.0306058713304185)
# ('Bedford County', 'VA', 1.0294717222901741)
# ('Stewart County', 'TN', 1.0282197538276794)
# ('Lanier County', 'GA', 1.022028180194483)
# ('Lampasas County', 'TX', 1.0214971794480867)
# ('Lassen County', 'CA', 1.0202034675454936)
# ('Sumner County', 'TN', 1.0196395779513834)
# ('Christian County', 'KY', 1.0195389087958895)
# ('Terrebonne Parish', 'LA', 1.0191310566779903)
# ('Rock County', 'WI', 1.0166468119078655)
# ('Tom Green County', 'TX', 1.0142981564813471)
# ('Buncombe County', 'NC', 1.0141911227855218)
# ('Crowley County', 'CO', 1.0132234243517086)
# ('Hardy County', 'WV', 1.0124777183600713)
# ('Eagle County', 'CO', 1.0115523880682797)
# ('Nome Census Area', 'AK', 1.0113780025284451)
# ('Randolph County', 'NC', 1.0095095660025961)
# ('Macon County', 'IL', 1.0093167701863355)
# ('Custer County', 'OK', 1.0084094797772034)
# ('Rowan County', 'NC', 1.0012425231889504)
# ('Culberson County', 'TX', 1.0008340283569641)
# ('Butler County', 'PA', 0.9996627905711892)
# ('Laurens County', 'GA', 0.9972333484742123)
# ('Campbell County', 'VA', 0.9955873235841144)
# ('Jasper County', 'MO', 0.9940036114612791)
# ('Summit County', 'CO', 0.9930699435593342)
# ('Coles County', 'IL', 0.9856514394965938)
# ('Sussex County', 'DE', 0.9855689974384336)
# ('Orange County', 'TX', 0.9824407053044467)
# ("Queen Anne's County", 'MD', 0.981212603037784)
# ('Pope County', 'AR', 0.9796936230851443)
# ('Gordon County', 'GA', 0.9785090421483709)
# ('Jessamine County', 'KY', 0.9776478821059564)
# ('Luzerne County', 'PA', 0.9768850609813098)
# ('Cabell County', 'WV', 0.9759237533612267)
# ('Quay County', 'NM', 0.9733436566751466)
# ('Clermont County', 'OH', 0.972826720307251)
# ('Delaware County', 'IN', 0.9722021568610788)
# ('Presidio County', 'TX', 0.9721156305960604)
# ('Brown County', 'SD', 0.9717773945416222)
# ('Garfield County', 'OK', 0.9706173654671508)
# ('Elkhart County', 'IN', 0.9693306809611305)
# ('St. Lawrence County', 'NY', 0.9692346173086542)
# ('Alexander County', 'NC', 0.967793967417603)
# ('White Pine County', 'NV', 0.9670987038883351)
# ('Douglas County', 'OR', 0.9659412819155359)
# ('Chambers County', 'TX', 0.9659220423979941)
# ('Hidalgo County', 'TX', 0.965190914969494)
# ('Costilla County', 'CO', 0.9648127128263337)
# ('Medina County', 'OH', 0.963256969106144)
# ('Alamosa County', 'CO', 0.9582389122693429)
# ('Warren County', 'VA', 0.9580838323353293)
# ('Henderson County', 'NC', 0.9574667416151397)
# ('Bent County', 'CO', 0.9539929219879981)
# ('Hancock County', 'MS', 0.9538118327300872)
# ('Linn County', 'OR', 0.9522421832144816)
# ('Ascension Parish', 'LA', 0.949494007368372)
# ('Ouachita Parish', 'LA', 0.9465261514441843)
# ('Ward County', 'ND', 0.945277665180381)
# ('Floyd County', 'IN', 0.943978116870927)
# ('Bethel Census Area', 'AK', 0.9404572973608418)
# ('Stonewall County', 'TX', 0.9395973154362416)
# ('Caldwell County', 'TX', 0.9378447958808385)
# ('Madison County', 'ID', 0.937766410912191)
# ('Dubuque County', 'IA', 0.9375033367857943)
# ('Danville city', 'VA', 0.9360120775751944)
# ('Deschutes County', 'OR', 0.93575852865285)
# ('Klamath County', 'OR', 0.9355227478156071)
# ('Madison County', 'TN', 0.9339328951919751)
# ('Windsor County', 'VT', 0.9334745014999118)
# ('Martinsville city', 'VA', 0.9333622747992185)
# ('Lorain County', 'OH', 0.9327838171464979)
# ('Morrow County', 'OR', 0.9308153584534145)
# ('Watauga County', 'NC', 0.9299320660153879)
# ('Walker County', 'TX', 0.9298418826719322)
# ('Kankakee County', 'IL', 0.9272889139613395)
# ('Columbia County', 'OR', 0.9260197361755587)
# ('Richmond County', 'NC', 0.92411929929887)
# ('Penobscot County', 'ME', 0.9238385426479473)
# ('Allegany County', 'NY', 0.9234666775630287)
# ('Dorchester County', 'MD', 0.9228033601079159)
# ('Columbia County', 'FL', 0.92105847684767)
# ('Madison County', 'KY', 0.914178204447875)
# ('Genesee County', 'MI', 0.9110124709363772)
# ('Southeast Fairbanks Census Area', 'AK', 0.9105135865699245)
# ('Raleigh County', 'WV', 0.9104858037763603)
# ('Grant County', 'WA', 0.9088868940754039)
# ('Walton County', 'FL', 0.9065639590865324)
# ('Newton County', 'GA', 0.9063806798855519)
# ('Kenton County', 'KY', 0.9059604307538192)
# ('Eureka County', 'NV', 0.9058882737795673)
# ('Elko County', 'NV', 0.9054037445204638)
# ('Angelina County', 'TX', 0.904680135068168)
# ('Kidder County', 'ND', 0.9034907597535934)
# ('Dickens County', 'TX', 0.900163666121113)
# ('Tillamook County', 'OR', 0.8990099009900989)
# ('Clarke County', 'VA', 0.8978195810175289)
# ('Harnett County', 'NC', 0.8972950347930728)
# ('Banks County', 'GA', 0.8969828757814623)
# ('Harris County', 'GA', 0.896202847864102)
# ('Union County', 'SD', 0.8958955483019655)
# ('Spalding County', 'GA', 0.8958531674808421)
# ('Louisa County', 'IA', 0.8957583208922456)
# ('Howard County', 'IN', 0.8942382057231244)
# ('Murray County', 'MN', 0.8939828080229226)
# ('Franklin County', 'AR', 0.8937931034482758)
# ('Paulding County', 'GA', 0.8930327984036424)
# ('Washington County', 'ID', 0.8923318297705433)
# ('Marion County', 'GA', 0.8922443376801648)
# ('Chisago County', 'MN', 0.8870414014511848)
# ('Box Elder County', 'UT', 0.8864432216108054)
# ('St. Louis County', 'MN', 0.885998821331895)
# ('Scott County', 'KY', 0.8818603862378904)
# ('Roosevelt County', 'NM', 0.8817897813161342)
# ('Lewis County', 'WA', 0.8799946988271156)
# ('New Kent County', 'VA', 0.8790493244343155)
# ('Okeechobee County', 'FL', 0.8775877587758776)
# ('Prince Edward County', 'VA', 0.8772680588839439)
# ('Franklin County', 'PA', 0.8755631006964403)
# ('Umatilla County', 'OR', 0.8749621157216461)
# ('Pulaski County', 'GA', 0.8742714404662781)
# ('Kaufman County', 'TX', 0.8737300435413643)
# ('Carteret County', 'NC', 0.8725872211105928)
# ('Nassau County', 'FL', 0.8715934200834765)
# ('Indiana County', 'PA', 0.8708370837083708)
# ('Saline County', 'AR', 0.8691349726469875)
# ('Autauga County', 'AL', 0.8685932088471898)
# ('Skamania County', 'WA', 0.867522139887945)
# ('Woods County', 'OK', 0.8673124577607568)
# ('Grayson County', 'TX', 0.865342455553993)
# ('Hart County', 'GA', 0.8646333240788482)
# ('Jackson County', 'NC', 0.8641454148146309)
# ('Reeves County', 'TX', 0.8633824276282377)
# ('Sevier County', 'TN', 0.8610619764376064)
# ('Cape May County', 'NJ', 0.8574512928597131)
# ('Coffee County', 'TN', 0.8561254640503068)
# ('Blaine County', 'ID', 0.8561002994011977)
# ('Shelby County', 'OH', 0.8558768184853205)
# ('Moore County', 'NC', 0.8544199802826159)
# ('Cerro Gordo County', 'IA', 0.8538877941609476)
# ('Douglas County', 'WI', 0.851468556806087)
# ('Jackson County', 'IN', 0.8471776477251274)
# ('Warren County', 'MS', 0.8467799807270415)
# ('Yavapai County', 'AZ', 0.8458392763217127)
# ('Bradley County', 'TN', 0.8457706415529035)
# ('Williamson County', 'IL', 0.8454270084542701)
# ('Lee County', 'NC', 0.8450558186154219)
# ('Butler County', 'AL', 0.844989736000382)
# ('Washington County', 'VT', 0.8432156414821782)
# ('Cortland County', 'NY', 0.8431976649910815)
# ('Salem County', 'NJ', 0.8428794092277894)
# ('Berkeley County', 'WV', 0.842861119910914)
# ('Niagara County', 'NY', 0.8421529179697786)
# ('Grand County', 'CO', 0.8421478137842754)
# ('Bleckley County', 'GA', 0.8420730306973896)
# ('Cascade County', 'MT', 0.8410490980855067)
# ('Kosciusko County', 'IN', 0.8402492308487809)
# ('Madison County', 'IL', 0.8370407231081172)
# ('Columbia County', 'PA', 0.8366149045248532)
# ('Payette County', 'ID', 0.8354329664500729)
# ('Grand County', 'UT', 0.8346883468834689)
# ('St. Charles Parish', 'LA', 0.8336491095111784)
# ('Campbell County', 'KY', 0.8335547290116896)
# ('Ohio County', 'WV', 0.8325270571293567)
# ('McDonald County', 'MO', 0.8317809643460554)
# ('Aiken County', 'SC', 0.8301113685906846)
# ('San Patricio County', 'TX', 0.8286525523115857)
# ('Oldham County', 'TX', 0.8284600389863548)
# ('Walworth County', 'WI', 0.8265837148335095)
# ('Petersburg city', 'VA', 0.8235657001850709)
# ('Josephine County', 'OR', 0.8233288600340939)
# ('Wilson County', 'NC', 0.8223157791072704)
# ('Bonneville County', 'ID', 0.8212291574726096)
# ('Greenwood County', 'SC', 0.8211194211969395)
# ('Hancock County', 'ME', 0.8195817560366055)
# ('Muscatine County', 'IA', 0.8188092174523336)
# ('Effingham County', 'GA', 0.8172248803827751)
# ('Isanti County', 'MN', 0.817114448910514)
# ('Kent County', 'MD', 0.8169530128236867)
# ('Lake of the Woods County', 'MN', 0.8158220024721878)
# ('Orangeburg County', 'SC', 0.812964184170982)
# ('Union County', 'OR', 0.8117135311480503)
# ('Chelan County', 'WA', 0.8115605979048486)
# ('Boyd County', 'NE', 0.8099094807050977)
# ('Monroe County', 'GA', 0.8098698153194066)
# ('Winnebago County', 'IA', 0.8098656359285845)
# ('Buchanan County', 'MO', 0.8094079662784048)
# ('Houston County', 'AL', 0.8075078535062582)
# ('Sioux County', 'IA', 0.8070258723000238)
# ('Modoc County', 'CA', 0.8052859797646087)
# ('Peach County', 'GA', 0.8051994944935909)
# ('Beckham County', 'OK', 0.80473800804738)
# ('Canyon County', 'ID', 0.8040312719997035)
# ('Caledonia County', 'VT', 0.8037915906106894)
# ('McCracken County', 'KY', 0.8037825059101654)
# ('Bristol Bay Borough', 'AK', 0.802407221664995)
# ('Hopewell city', 'VA', 0.8012040192997212)
# ('Hancock County', 'IN', 0.7971200822833634)
# ('Isle of Wight County', 'VA', 0.7967110859087042)
# ('Long County', 'GA', 0.7950774336283186)
# ('McKinley County', 'NM', 0.7944944888938623)
# ('Greene County', 'NY', 0.7943763840637127)
# ('Watonwan County', 'MN', 0.7938631701007939)
# ('Madison County', 'NY', 0.7938236976117208)
# ('Clark County', 'IN', 0.7937803904492344)
# ('Bowie County', 'TX', 0.7929563009776914)
# ('Pueblo County', 'CO', 0.7908816003721796)
# ('Ector County', 'TX', 0.7875738350470356)
# ('Livingston County', 'MI', 0.7868837964932833)
# ('Lincoln County', 'CO', 0.786537406255716)
# ('Comal County', 'TX', 0.7826904638985176)
# ('Crisp County', 'GA', 0.7807500319979521)
# ('McDowell County', 'NC', 0.7800693394968442)
# ('Nash County', 'NC', 0.7794240400667779)
# ('Staunton city', 'VA', 0.7790785816558579)
# ('Dougherty County', 'GA', 0.7783006397715857)
# ('Lonoke County', 'AR', 0.7782784247176546)
# ('Bedford County', 'TN', 0.7767765990501132)
# ('Jefferson County', 'AR', 0.7761348227545684)
# ('Gloucester County', 'VA', 0.7759509468772045)
# ('San Miguel County', 'NM', 0.7756948933419522)
# ('Dukes County', 'MA', 0.7741155125491381)
# ('Carroll County', 'GA', 0.7717571272177839)
# ('Rowan County', 'KY', 0.7714395919941713)
# ('Essex County', 'VA', 0.7712312797058559)
# ('Cleveland County', 'NC', 0.7708150655600644)
# ('Saguache County', 'CO', 0.7694826457105435)
# ('Wasatch County', 'UT', 0.7692307692307693)
# ('Ware County', 'GA', 0.7683410442828817)
# ('Steele County', 'MN', 0.7682633420822397)
# ('Clark County', 'KS', 0.7674943566591422)
# ('Sweetwater County', 'WY', 0.7670182166826461)
# ('Delaware County', 'NY', 0.7649020425177157)
# ('Merrick County', 'NE', 0.7648183556405354)
# ('Wayne County', 'IN', 0.7646879579784378)
# ('Mesa County', 'CO', 0.7640247268662718)
# ('Hinds County', 'MS', 0.7640092137717349)
# ('Scotland County', 'NC', 0.7633376662886855)
# ('Wayne County', 'OH', 0.7631854697869368)
# ('Howard County', 'TX', 0.7625956814806353)
# ('Sagadahoc County', 'ME', 0.7621908027087524)
# ('Wasco County', 'OR', 0.7615119184547654)
# ('Freeborn County', 'MN', 0.761478163493841)
# ('St. Martin Parish', 'LA', 0.7611196319018405)
# ('Tallahatchie County', 'MS', 0.760827155676941)
# ('Boyle County', 'KY', 0.7597073719752392)
# ('Otero County', 'CO', 0.759386118634167)
# ('Independence County', 'AR', 0.7585886975741535)
# ('Allegany County', 'MD', 0.7564558445536511)
# ('Iron County', 'UT', 0.7560167233498689)
# ('Cooke County', 'TX', 0.7544813591071103)
# ('Kerr County', 'TX', 0.7516372795969773)
# ('Anderson County', 'SC', 0.7508309908831483)
# ('Elbert County', 'CO', 0.7493719137139392)
# ('Lincoln County', 'NV', 0.7483629560336763)
# ('Franklin city', 'VA', 0.745746912141692)
# ('Hamblen County', 'TN', 0.7450754668713225)
# ('Licking County', 'OH', 0.742978641616414)
# ('McMinn County', 'TN', 0.7423564076072399)
# ('King William County', 'VA', 0.7405083150298086)
# ('Westmoreland County', 'PA', 0.7404790658571785)
# ('Robeson County', 'NC', 0.7401168684037922)
# ('Baldwin County', 'AL', 0.7395824760650701)
# ('Putnam County', 'WV', 0.7389251342681037)
# ('Lauderdale County', 'AL', 0.7388710912640628)
# ('Harvey County', 'KS', 0.7380924922154307)
# ('Tazewell County', 'IL', 0.7378465810892654)
# ('Archuleta County', 'CO', 0.7365110890433632)
# ('Douglas County', 'WA', 0.7363846894434181)
# ('Lafourche Parish', 'LA', 0.7361033244045765)
# ('Stark County', 'OH', 0.7359166742104338)
# ('Piscataquis County', 'ME', 0.7356715141146278)
# ('Adams County', 'PA', 0.7356494127624326)
# ('Putnam County', 'IN', 0.7349261122672076)
# ('Montgomery County', 'NY', 0.734781656345208)
# ('Orange County', 'VA', 0.7347450792987068)
# ('Toombs County', 'GA', 0.7346728868971091)
# ('Pierce County', 'WI', 0.733806284892367)
# ('Waynesboro city', 'VA', 0.733123869370656)
# ('Richland County', 'IL', 0.733074601121173)
# ('Titus County', 'TX', 0.7329745778437557)
# ('Kennebec County', 'ME', 0.7302437147465023)
# ('McLeod County', 'MN', 0.7284930834083654)
# ('Franklin County', 'TN', 0.7283445386339277)
# ('Page County', 'IA', 0.7280944012051218)
# ('Tioga County', 'NY', 0.7276283618581907)
# ('Phillips County', 'KS', 0.7266926621765332)
# ('Stewart County', 'GA', 0.7263123142951469)
# ('Humboldt County', 'NV', 0.7260406582768635)
# ('Emporia city', 'VA', 0.7254935043023452)
# ...
# ('Pontotoc County', 'MS', 0.18693460626898556)
# ('Duval County', 'TX', 0.1867255134951621)
# ('Crawford County', 'IN', 0.18668906935498927)
# ('Morgan County', 'TN', 0.1864738254423068)
# ('Sullivan County', 'IN', 0.18626309662398138)
# ('Lincoln County', 'KS', 0.18512804689910523)
# ('Carter County', 'KY', 0.183982683982684)
# ('Russell County', 'VA', 0.18341004256497215)
# ('Bullock County', 'AL', 0.1832508704416346)
# ('Marshall County', 'OK', 0.1830808080808081)
# ('Poinsett County', 'AR', 0.1830533295366717)
# ('Ashley County', 'AR', 0.18304123003706585)
# ('Crittenden County', 'KY', 0.18250134192163178)
# ('Arenac County', 'MI', 0.18240140889364112)
# ('Pickens County', 'AL', 0.18231540565177756)
# ('Ballard County', 'KY', 0.1818402230573403)
# ('Smith County', 'KS', 0.18167661562418894)
# ('Scott County', 'MS', 0.18044155108972543)
# ('Perry County', 'MS', 0.17959183673469387)
# ('Reynolds County', 'MO', 0.17921146953405018)
# ('Red River County', 'TX', 0.17884914463452567)
# ('Reagan County', 'TX', 0.1782001782001782)
# ('Randolph County', 'AR', 0.17808447882464246)
# ('Shannon County', 'MO', 0.17770406349958537)
# ('Edgar County', 'IL', 0.1776485788113695)
# ('Perry County', 'TN', 0.17687934301958305)
# ('Northampton County', 'NC', 0.17647857369111725)
# ('Carroll County', 'VA', 0.17641967911590442)
# ('Greer County', 'OK', 0.1763103061388043)
# ('Wayne County', 'TN', 0.17625286410904176)
# ('Larue County', 'KY', 0.17614316916789968)
# ('Starke County', 'IN', 0.17549116123785471)
# ('Marion County', 'AL', 0.1754613984923317)
# ('Grundy County', 'TN', 0.1751441290228417)
# ('Johnson County', 'IL', 0.17485296455253535)
# ('Gallatin County', 'KY', 0.17464198393293748)
# ('Mason County', 'TX', 0.1744765702891326)
# ('Pepin County', 'WI', 0.174052751372339)
# ('Clarke County', 'MS', 0.17332058331341144)
# ('Butte County', 'ID', 0.17295053614666206)
# ('Holt County', 'NE', 0.17249640632486823)
# ('Highland County', 'VA', 0.17233950883239982)
# ('Clay County', 'AL', 0.17226528854435832)
# ('Braxton County', 'WV', 0.17214074227088066)
# ('Powder River County', 'MT', 0.17211703958691912)
# ('Jackson Parish', 'LA', 0.17205358240137644)
# ('Crockett County', 'TN', 0.17139723022075964)
# ('Tensas Parish', 'LA', 0.17136329017517135)
# ('Brule County', 'SD', 0.17126546146527116)
# ('Keokuk County', 'IA', 0.17124916753876893)
# ('Vinton County', 'OH', 0.17119464086341646)
# ('Doddridge County', 'WV', 0.17069007559131918)
# ('Floyd County', 'TX', 0.17064846416382254)
# ('Stoddard County', 'MO', 0.1701815269620929)
# ('Martin County', 'KY', 0.1701601051898832)
# ('Sherman County', 'OR', 0.16997167138810199)
# ('Sanborn County', 'SD', 0.16985138004246286)
# ('Switzerland County', 'IN', 0.1696033166870819)
# ('Union County', 'MS', 0.16952900420137096)
# ('Kearney County', 'NE', 0.16951764524580057)
# ('Wayne County', 'WV', 0.16948753560415245)
# ('Benton County', 'IN', 0.169414953693246)
# ('Emmons County', 'ND', 0.16901408450704225)
# ('Coal County', 'OK', 0.16877637130801687)
# ('Lucas County', 'IA', 0.16857720836142953)
# ('Perkins County', 'NE', 0.16835016835016833)
# ('Mississippi County', 'MO', 0.1671541997492687)
# ('Dixon County', 'NE', 0.16666666666666669)
# ('Aitkin County', 'MN', 0.16664609307492903)
# ('Hickory County', 'MO', 0.1661992313285551)
# ('Greene County', 'AL', 0.16583747927031509)
# ('Griggs County', 'ND', 0.1652892561983471)
# ('Pierce County', 'NE', 0.16515276630883566)
# ('Pocahontas County', 'IA', 0.16415868673050615)
# ('Okfuskee County', 'OK', 0.1640554507423509)
# ('Lawrence County', 'KY', 0.16393442622950818)
# ('Wayne County', 'MS', 0.16387911505277872)
# ('Unicoi County', 'TN', 0.163818052749413)
# ('Hutchinson County', 'SD', 0.16342094511779928)
# ('Burleson County', 'TX', 0.1629138302205155)
# ('Grant County', 'NE', 0.16286644951140067)
# ('Harper County', 'OK', 0.16282225237449116)
# ('Perry County', 'AR', 0.1627573001436094)
# ('McPherson County', 'SD', 0.16266775111834078)
# ('Ontonagon County', 'MI', 0.16224188790560473)
# ('Lincoln County', 'KY', 0.16166841807452914)
# ('Broadwater County', 'MT', 0.1603706343549537)
# ('Gilliam County', 'OR', 0.16034206306787815)
# ('Mingo County', 'WV', 0.16021461306307985)
# ('Hocking County', 'OH', 0.15997277059223963)
# ('Cochran County', 'TX', 0.1598976654940838)
# ('Grant County', 'WV', 0.15916897042808076)
# ('Letcher County', 'KY', 0.15906032056772298)
# ('Baca County', 'CO', 0.15839493136219643)
# ('Bates County', 'MO', 0.15836705965159248)
# ('Atchison County', 'MO', 0.15831134564643798)
# ('Yalobusha County', 'MS', 0.15775358889414734)
# ('Butler County', 'KY', 0.15760441292356187)
# ('De Soto Parish', 'LA', 0.15756302521008403)
# ('Calhoun County', 'WV', 0.1573357807788121)
# ('Owen County', 'KY', 0.15681210220459368)
# ('Holmes County', 'MS', 0.15626627773726431)
# ('Borden County', 'TX', 0.15600624024961)
# ('Forest County', 'PA', 0.15552099533437014)
# ('Walthall County', 'MS', 0.15541021822184808)
# ('Allen County', 'KY', 0.15534175185407897)
# ('Scott County', 'VA', 0.15532640117357724)
# ('Crook County', 'WY', 0.15530142594945645)
# ('Twiggs County', 'GA', 0.1551590380139643)
# ('Sac County', 'IA', 0.15458937198067632)
# ('Craig County', 'VA', 0.15414258188824664)
# ('Cleburne County', 'AL', 0.15362009083622763)
# ('Montmorency County', 'MI', 0.15360983102918588)
# ('Schoolcraft County', 'MI', 0.15321154979375368)
# ('Meigs County', 'TN', 0.15315238662469158)
# ('Tippah County', 'MS', 0.15293270960777258)
# ('Clay County', 'NE', 0.1528584530724549)
# ('Fillmore County', 'NE', 0.15280135823429541)
# ('Sheridan County', 'ND', 0.1514004542013626)
# ('Green County', 'KY', 0.15100373068040504)
# ('Dewey County', 'SD', 0.15091492171288434)
# ('Coke County', 'TX', 0.15060240963855423)
# ('Blackford County', 'IN', 0.1488328372238759)
# ('Pembina County', 'ND', 0.14838796708485094)
# ('Bath County', 'VA', 0.14796026210103572)
# ('Ottawa County', 'KS', 0.14775898867181086)
# ('Nemaha County', 'KS', 0.14737669483199056)
# ('Lake County', 'MI', 0.14732645809862208)
# ('Baraga County', 'MI', 0.14672686230248305)
# ('Bath County', 'KY', 0.14666551634889138)
# ('Lafayette County', 'FL', 0.14656144306651636)
# ('Frontier County', 'NE', 0.14513788098693758)
# ('LaMoure County', 'ND', 0.1449625513409036)
# ('Van Buren County', 'TN', 0.14419610670511895)
# ('Jefferson Davis County', 'MS', 0.14414991591254905)
# ('Carter County', 'MO', 0.14365522745411013)
# ('Preston County', 'WV', 0.1431980906921241)
# ('Lamb County', 'TX', 0.14309222293768334)
# ('Polk County', 'TN', 0.1426448736998514)
# ('McCook County', 'SD', 0.1423994304022784)
# ('Wabaunsee County', 'KS', 0.1417836381681554)
# ('Bon Homme County', 'SD', 0.14144271570014144)
# ('Union Parish', 'LA', 0.14083887152854188)
# ('Mineral County', 'CO', 0.1404494382022472)
# ('Lake County', 'TN', 0.1404494382022472)
# ('St. James Parish', 'LA', 0.14025880010858746)
# ('Forest County', 'WI', 0.13972484952708514)
# ('Lee County', 'KY', 0.1394700139470014)
# ('Gates County', 'NC', 0.13937853570550135)
# ('Harrison County', 'OH', 0.13867876954109937)
# ('Coosa County', 'AL', 0.13866019585752665)
# ('Metcalfe County', 'KY', 0.13862758688979107)
# ('Cannon County', 'TN', 0.13767118324759076)
# ('Custer County', 'NE', 0.13712405155864338)
# ('McCreary County', 'KY', 0.1365672457117885)
# ('Noble County', 'OH', 0.13656538067599863)
# ('Muhlenberg County', 'KY', 0.13651227023080098)
# ('Dallas County', 'AR', 0.13553474618038444)
# ('Lynn County', 'TX', 0.1352493660185968)
# ('Stanley County', 'SD', 0.13486176668914363)
# ('Powell County', 'KY', 0.13478157456592404)
# ('Pendleton County', 'KY', 0.1344357061235464)
# ('Wichita County', 'KS', 0.13428827215756492)
# ('Searcy County', 'AR', 0.1342281879194631)
# ('Stanton County', 'KS', 0.1342281879194631)
# ('Perkins County', 'SD', 0.1341381623071764)
# ('McLean County', 'ND', 0.13389868332961394)
# ('Menard County', 'TX', 0.13380909901873325)
# ('Quitman County', 'MS', 0.13377112975799585)
# ('Ozark County', 'MO', 0.13370358942713156)
# ('Leslie County', 'KY', 0.1326259946949602)
# ('Bledsoe County', 'TN', 0.13202858030444237)
# ('Red River Parish', 'LA', 0.13199868001319986)
# ('Greene County', 'MS', 0.13194444444444445)
# ('Teton County', 'MT', 0.13173061090070806)
# ('Cumberland County', 'KY', 0.13127187864644108)
# ('Talbot County', 'GA', 0.13109978150036417)
# ('Logan County', 'NE', 0.1310615989515072)
# ('Collingsworth County', 'TX', 0.13084723585214264)
# ('Prentiss County', 'MS', 0.13055863269504667)
# ('Tyler County', 'WV', 0.13032145960034752)
# ('Carroll County', 'MO', 0.129101667563206)
# ('Ness County', 'KS', 0.1287415513356936)
# ('Conecuh County', 'AL', 0.12851527063804052)
# ('Liberty County', 'MT', 0.12825994014536127)
# ('Fulton County', 'PA', 0.12798922196025597)
# ('Swisher County', 'TX', 0.12732365673542145)
# ('Clinton County', 'KY', 0.1265576323987539)
# ('Lawrence County', 'AR', 0.12632787826586275)
# ('Grant County', 'ND', 0.12531328320802004)
# ('Clay County', 'AR', 0.12435490891002923)
# ('Beaver County', 'OK', 0.1242015613910575)
# ('Lowndes County', 'AL', 0.12390477033365785)
# ('Garza County', 'TX', 0.12381984212970129)
# ('Edmunds County', 'SD', 0.12281994595922378)
# ('St. Clair County', 'MO', 0.1223865374808771)
# ('Lawrence County', 'AL', 0.1223099100148519)
# ('Keya Paha County', 'NE', 0.12135922330097086)
# ('Clay County', 'KY', 0.11965025310630466)
# ('Schuyler County', 'IL', 0.11930010604453871)
# ('Sullivan County', 'MO', 0.11915400655347036)
# ('Franklin County', 'ID', 0.11731581417175035)
# ('Holmes County', 'OH', 0.115658782986357)
# ('Adams County', 'OH', 0.11558669001751315)
# ('Schleicher County', 'TX', 0.11557353366079169)
# ('McCone County', 'MT', 0.11534025374855825)
# ('Greene County', 'IL', 0.11522396658504969)
# ('Cleveland County', 'AR', 0.11508804235239958)
# ('Rolette County', 'ND', 0.11480232474707613)
# ('Washington County', 'AL', 0.11375917183322906)
# ('Dickenson County', 'VA', 0.11318619128466327)
# ('Morgan County', 'OH', 0.1129267968646207)
# ('Traverse County', 'MN', 0.11242270938729623)
# ('Tucker County', 'WV', 0.11202912757316903)
# ('Haywood County', 'TN', 0.11177942194070369)
# ('Monroe County', 'WV', 0.11109465264405273)
# ('Menifee County', 'KY', 0.11100539169045354)
# ('Polk County', 'NE', 0.11098779134295228)
# ('Lincoln County', 'WV', 0.11049723756906078)
# ('Monroe County', 'OH', 0.10927468925010243)
# ('Spink County', 'SD', 0.10911925175370225)
# ('Baylor County', 'TX', 0.10735373054213634)
# ('Webster County', 'MS', 0.10728567248610163)
# ('Tishomingo County', 'MS', 0.10718113612004287)
# ('Calhoun County', 'MS', 0.10693757519048255)
# ('Grainger County', 'TN', 0.10592752791631725)
# ('Pleasants County', 'WV', 0.10519395134779749)
# ('Wyoming County', 'WV', 0.10505967389477222)
# ('McLean County', 'KY', 0.10492078480747037)
# ('Carroll County', 'IN', 0.1041925080625155)
# ('Iron County', 'MO', 0.10348071495766699)
# ('Hitchcock County', 'NE', 0.10316368638239339)
# ('Shannon County', 'SD', 0.10304725452671869)
# ('Grayson County', 'VA', 0.10300650228545678)
# ('Hancock County', 'TN', 0.10265434814488929)
# ('Perry County', 'OH', 0.10261245770702757)
# ('La Salle County', 'TX', 0.10165553296543713)
# ('Steele County', 'ND', 0.10126582278481014)
# ('Osage County', 'MO', 0.10087908920593745)
# ('Chase County', 'NE', 0.10085728693898136)
# ('Douglas County', 'SD', 0.09993337774816789)
# ('Dundy County', 'NE', 0.099601593625498)
# ('Union County', 'TN', 0.0994295881521796)
# ('Crosby County', 'TX', 0.09902624195411786)
# ('Stanton County', 'NE', 0.09789525208027411)
# ('Red Lake County', 'MN', 0.09782342871117633)
# ('Garfield County', 'NE', 0.09760858955588092)
# ('Granite County', 'MT', 0.0974342318934719)
# ('Dolores County', 'CO', 0.09689922480620156)
# ('Judith Basin County', 'MT', 0.09652509652509653)
# ('Sioux County', 'ND', 0.0963159162051529)
# ('Todd County', 'KY', 0.09630818619582665)
# ('Bibb County', 'AL', 0.09600698232598735)
# ('Nelson County', 'ND', 0.09596928982725528)
# ('Ritchie County', 'WV', 0.09570293808019906)
# ('Kemper County', 'MS', 0.0956388676358072)
# ('Estill County', 'KY', 0.09541984732824427)
# ('Wells County', 'ND', 0.09507962918944615)
# ('Jackson County', 'TN', 0.0945179584120983)
# ('Jasper County', 'MS', 0.0937756417770484)
# ('Choctaw County', 'MS', 0.09360009360009361)
# ('Franklin County', 'NE', 0.09302325581395349)
# ('Blaine County', 'MT', 0.09243568017254661)
# ('Deuel County', 'SD', 0.09165902841429881)
# ('Amite County', 'MS', 0.09138679460817913)
# ('Foster County', 'ND', 0.08973975471133712)
# ('Camas County', 'ID', 0.08952551477170993)
# ('Hall County', 'TX', 0.08947211452430659)
# ('Gallatin County', 'IL', 0.08946144211844695)
# ('Chariton County', 'MO', 0.08938832843825821)
# ('Clay County', 'TN', 0.08904719501335707)
# ('Cameron Parish', 'LA', 0.0877321245796169)
# ('Robertson County', 'KY', 0.0876424189307625)
# ('Choctaw County', 'AL', 0.08658633379031676)
# ('Thurston County', 'NE', 0.08645533141210375)
# ('Carter County', 'MT', 0.08620689655172414)
# ('Knott County', 'KY', 0.08564786492108162)
# ('Boone County', 'WV', 0.0852653376101344)
# ('Faulk County', 'SD', 0.08460236886632826)
# ('Garfield County', 'MT', 0.08291873963515754)
# ('Harper County', 'KS', 0.08286377195889957)
# ('Rockcastle County', 'KY', 0.08208255159474673)
# ('Chautauqua County', 'KS', 0.08176614881439084)
# ('Glasscock County', 'TX', 0.08156606851549755)
# ('Jackson County', 'KY', 0.08151771157551504)
# ('Oscoda County', 'MI', 0.08101851851851852)
# ('St. Helena Parish', 'LA', 0.08033562438632509)
# ('Harding County', 'SD', 0.0796812749003984)
# ('Quitman County', 'GA', 0.07958615200955034)
# ('Cedar County', 'NE', 0.07907817442385902)
# ('Smith County', 'MS', 0.07883087744830514)
# ('Greeley County', 'NE', 0.07880220646178093)
# ('Pickett County', 'TN', 0.07878668505022651)
# ('Sioux County', 'NE', 0.07627765064836003)
# ('Big Stone County', 'MN', 0.07591573353577528)
# ('Clay County', 'WV', 0.07457916045173663)
# ('Monroe County', 'KY', 0.07297272644349174)
# ('Jackson County', 'CO', 0.07173601147776185)
# ('Ziebach County', 'SD', 0.07140307033202428)
# ('Pierce County', 'ND', 0.06885471654808355)
# ('Prairie County', 'AR', 0.06884681583476765)
# ('Benton County', 'MS', 0.0687363959216405)
# ('McDowell County', 'WV', 0.0678334011667345)
# ('Wallace County', 'KS', 0.06734006734006734)
# ('Nowata County', 'OK', 0.06643887623386484)
# ('Elliott County', 'KY', 0.06367804381049415)
# ('Bowman County', 'ND', 0.06347191367819739)
# ('Franklin County', 'MS', 0.06159152500615915)
# ('Woodson County', 'KS', 0.060441220912662436)
# ('Real County', 'TX', 0.060441220912662436)
# ('Magoffin County', 'KY', 0.06000150003750093)
# ('Golden Valley County', 'ND', 0.05952380952380953)
# ('Daviess County', 'MO', 0.059290881062492584)
# ('Bracken County', 'KY', 0.058906691800188496)
# ('Lewis County', 'KY', 0.05767844268204759)
# ('Mahnomen County', 'MN', 0.05542213190467394)
# ('Webster County', 'WV', 0.05462093074065982)
# ('Maries County', 'MO', 0.05448997384481255)
# ('Clark County', 'SD', 0.0541858574911948)
# ('Nance County', 'NE', 0.0535475234270415)
# ('Buffalo County', 'SD', 0.05230125523012552)
# ('De Baca County', 'NM', 0.04945598417408506)
# ('Keweenaw County', 'MI', 0.0463821892393321)
# ('Pocahontas County', 'WV', 0.045876820736322974)
# ('Benson County', 'ND', 0.04504504504504504)
# ('Towner County', 'ND', 0.04452359750667854)
# ('Owsley County', 'KY', 0.042060988433228176)
# ('Wolfe County', 'KY', 0.04078857919782461)
# ('Hettinger County', 'ND', 0.04037141703673799)
# ('Wilcox County', 'AL', 0.03427592116538132)
# ('Zavala County', 'TX', 0.03425537381176672)
# ('Jackson County', 'SD', 0.03299241174529858)
# ('Glascock County', 'GA', 0.03244646333549643)
# ('Catahoula Parish', 'LA', 0.028826751225136928)
# ('Lamar County', 'AL', 0.027464982147761604)
# ('Jefferson County', 'MS', 0.025886616619207874)
# ('Menominee County', 'WI', 0.023629489603024575)
# ('Wilkinson County', 'MS', 0.020247013565499086)
# ('Kiowa County', 'CO', 0.0)
# ('Petroleum County', 'MT', 0.0)
# ('Banner County', 'NE', 0.0)
# ('Blaine County', 'NE', 0.0)
# ('Garden County', 'NE', 0.0)
# ('Hooker County', 'NE', 0.0)
# ('Loup County', 'NE', 0.0)
# ('McPherson County', 'NE', 0.0)
# ('Harding County', 'NM', 0.0)
# ('Slope County', 'ND', 0.0)
# ('Jones County', 'SD', 0.0)
# ('Sully County', 'SD', 0.0)
# ('Armstrong County', 'TX', 0.0)
# ('Briscoe County', 'TX', 0.0)
# ('Cottle County', 'TX', 0.0)
# ('Kent County', 'TX', 0.0)
# ('King County', 'TX', 0.0)
# ('Loving County', 'TX', 0.0)
# ('Motley County', 'TX', 0.0)
# ('Sterling County', 'TX', 0.0)
# ('Upton County', 'TX', 0.0)

# %% [markdown]
# #### Aggregate Functions
#
# SQL also lets you calculate a result from values within a column with aggregate functions.
#
# For example, what is the total population of all counties or average population of all counties.

# %%
pretty_print_sql(conn, """
SELECT sum(P0010001) AS "County Sum",
       round(avg(P0010001), 0) AS "County Average"
FROM us_counties_2010;
""")
# Out:
# >
# SELECT sum(P0010001) AS "County Sum",
#        round(avg(P0010001), 0) AS "County Average"
# FROM us_counties_2010;
#    County Sum  County Average
# 0   308745538         98233.0

# %% [markdown]
# ### Close Database Connections
#
# When you are done executing your scripts you want to close the database connection.

# %%
conn.close()
conn2.close()

# %%
# Create two empty lists to store ham and spam data
ham_data = []
spam_data = []
# Specify the file path
file_path = "/home/campus19/trkosire/PycharmProjects/pythonProject/SMSSpamCollection"

import re
# Read the file line by line and separate ham and spam
try:
    with open(file_path, 'r') as file:
        for line in file:
            # Split each line into label and message
            parts = line.strip().split('\t')
            if len(parts) == 2:
                label, message = parts
                if label == "ham":
                    ham_data.append(message.split())
                    word_pattern = re.compile(r'\b\w+\b')
                    ham_data = [word for sublist in ham_data for text in sublist for word in word_pattern.findall(text)]              
                elif label == "spam":
                    spam_data.append(message.split())
                    spam_data = [word for sublist in spam_data for text in sublist for word in word_pattern.findall(text)]
except FileNotFoundError:
    print(f"The file '{file_path}' does not exist.")
except Exception as e:
    print(f"An error occurred: {e}")

# Now you have 'ham_data' and 'spam_data' lists containing the respective messages
print(f"Total ham messages: {len(ham_data)}")
print(f"Total spam messages: {len(spam_data)}")

# %%
ham_data
# Out:
# [['Go',
#   'until',
#   'jurong',
#   'point,',
#   'crazy..',
#   'Available',
#   'only',
#   'in',
#   'bugis',
#   'n',
#   'great',
#   'world',
#   'la',
#   'e',
#   'buffet...',
#   'Cine',
#   'there',
#   'got',
#   'amore',
#   'wat...']]
